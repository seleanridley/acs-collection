# %%
import psycopg2
from config import config
import pandas as pd
import os
import pickle
import re

# %%
#Postgres Connection Setup
def connect(server):
    """ Connect to the PostgreSQL database server """
    conn = None
    try:
        # read connection parameters
        params = config(section=server)

        # connect to the PostgreSQL server
        #print('Connecting to the PostgreSQL database...')
        conn = psycopg2.connect(**params)

        # create a cursor
        cur = conn.cursor()
        
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
    
    return cur

def close():
    if conn is not None:
        conn.close()
        print('Database connection closed.')

# %%
def get_acs_table_metadata():
    """
    Searches existing tables in metadata schema that are sourced from the ACS to aggregate census variables and titles.
    
    Returns:
    -------------
    
    """
    
    #Establish connection to Postgres server
    cur = connect('sdvm') 

    #Matches on tables in metadata schema that include the string 'acs'.
    cur.execute(
        """
        SELECT table_name
        FROM information_schema.tables
        WHERE table_schema = 'metadata' AND table_name LIKE '%acs_m'
        ORDER BY table_name;
        """)

    #Assigns query results
    table_names = cur.fetchall()

    table_meta = pd.DataFrame(columns=['title', 'tbl_name', 'tbl_num', 'geography'])
    
    for idx, table in enumerate(table_names): 
        proc_table = table[0].replace("'", '')
        
        query = \
        """
        SELECT details 
        FROM metadata.{0}
        WHERE orderid IN (2, 4, 5, 6);
        """.format(proc_table)
        
        cur.execute(query)
        metadata = cur.fetchall()
        try:
            table_meta.loc[idx] = [x[0] for x in metadata]
        except ValueError:
            print("Error at " + str(table_names[idx]))
            continue

    cur.close()
    return table_meta

# %%
table_meta = get_acs_table_metadata()
# Out:
# Error at ('b16002_hh_linguistic_isolation_acs_m',)

# %%
#Uncomment to save new pickle of table_meta Dataframe
#pickle.dump(table_meta, open('pickles/table_meta.p', 'wb'))

# %%
#census_vars = pd.read_json('census_variables/variables.json', orient='index')
#census_vars

# %%
set(table_meta['title'])
# Out:
# {'Aggregate Gross Rent by Units in Structure',
#  'Aggregate travel time to work (in minutes) of workers by travel time',
#  'American Indian And Alaska Native Alone Population by Age and Gender',
#  'Asian Alone Population by Age and Gender',
#  'Average Household Size',
#  'Black Or African American Alone Population by Age and Gender',
#  'Children in Poverty by Family Type',
#  'Citizenship Status by Native and Foreign born',
#  'Citizenship Status by Native and Foreign born with Place of Birth',
#  'Citizenship and Foreign Born by Age and Gender',
#  'Contract Rent',
#  'Disability Status by Age and Gender',
#  'Disability Status by Age and Race/Ethnicity',
#  'Disability Status by Difficulty Type',
#  'Educational Attainment Overall and by Gender',
#  'Educational Attainment by Age',
#  'Educational Attainment by Employment',
#  'Educational Attainment by Place of Birth',
#  'Educational Attainment by Race/Ethinicity',
#  'Employment',
#  'Employment Status by Disability Status',
#  'Employment Status by Race and Age',
#  'Families Ratio Of Income To Poverty Level',
#  'Families receiving Food Stamps/SNAP by presence of Family Type',
#  'Families with Children in Poverty by Family Type and Race',
#  'Geographic Mobility: Current Residence by Age',
#  'Geographic Mobility: In Migration',
#  'Geographic Mobility: In Migration by Age',
#  'Geographic Mobility: Out Migration',
#  'Geographic Mobility: Out Migration by Age',
#  'Gini Index',
#  'Grandparents living with/responsible for own Grandchildren by Poverty',
#  'Health Insurance Coverage by Disability Status',
#  'Health Insurance Coverage by Gender and Age',
#  'Hearing Difficulty by Age',
#  'Hispanic Or Latino Population by Age and Gender',
#  'Household Income',
#  'Household Income by Age',
#  'Household Income by Race',
#  'Household Income by Tenure',
#  'Household Occupancy by Race',
#  'Household Size by Vehicles Available',
#  'Household Tenure by Age',
#  'Households receiving Food Stamps/SNAP by Race',
#  'Households receiving Food Stamps/SNAP by presence of children and household type',
#  'Households receiving Food Stamps/SNAP by presence of people 60 years or over',
#  'Households with Children Under 18',
#  'Households with Seniors',
#  'Housing Cost Burden by Age',
#  'Housing Cost Burden by Income',
#  'Housing Cost Burden by Tenure',
#  'Housing Cost Burden for Renters by Income',
#  'Housing Tenure by Heating Fuel',
#  'Housing Tenure by Year Built',
#  'Language Spoken at Home by Ability to Speak English',
#  'Means of Transporation to Work by Travel Time',
#  'Means of Transportation to work by Gender',
#  'Means of Transportation to work by Residence by Race',
#  'Median Age by Gender and Race/Ethnicity',
#  'Median Household Income by Family Type',
#  'Median Household Income by Race',
#  'Median Household Income by Tenure',
#  'Median Household Income for Households receiving Food Stamps/SNAP',
#  'Median Rent by Number of Bedrooms',
#  'Median Value by Mortgage Status',
#  'Mortgage Status for Households with Aggregate Values',
#  'Native Hawaiian And Other Pacific Islander Alone Population by Age and Gender',
#  'Nativity and English Ability by Race',
#  None,
#  'POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE',
#  'Per Capita Income',
#  'Place of Birth for Foreign Born Population',
#  'Population by Age and Gender',
#  'Population by Race/Ethnicity',
#  'Population in Poverty',
#  'Poverty by Age and Gender',
#  'Poverty by Household Type',
#  'Poverty by Race and Age',
#  'Public Assistance',
#  'Rent',
#  'Reported Ancestry',
#  'Some Other Race Alone Population by Age and Gender',
#  'Tenure by Housing Units',
#  'Time Period of Naturalization',
#  'Transportation to Work by Residence',
#  'Transportation to Work by Residence by Age',
#  'Transportation to Work from Workplace ',
#  'Travel Time to Work',
#  'Travel Time to Work by Place of Work ',
#  'Two Or More Races Population by Age and Gender',
#  'Units in Structures',
#  'Unmarried Households by Gender',
#  'Vehicles by Households',
#  'Vehicles by Households with aggregations',
#  'Vision Difficulty by Age',
#  'White Alone Not Hispanic Or Latino Population Population by Age and Gender',
#  'White Alone Population by Age and Gender '}

# %%
len(list(table_meta['tbl_name']))
# Out:
# 102

# %%
def get_col_names(sql_name, visited_ids, lines):
    #IDEA: continously add ids from visited_ids set and use "as" as a delimiter. Get all ids that came before delimiter
    #save what comes after delimiter as a hash map key and what comes before as values.
    
    hash_map = {}
    hash_map[sql_name] = {}
    list_ = []
    for line in lines:
        if "SELECT" in line:
            continue
        if "e._" in line:
            there = re.search('e._(.+?)]', line)
            if there:
                ids = [x for x in re.findall(r'\d+', there.group()) if len(x) == 3]
                list_ += ids
        
        #Once "as" is in line, hash the list of ids with the key of the term after the "as"
        if "as" in line: 
            there2 = re.search('as (.+?),', line)
            
            if there2:
                col_name = there2.group(1)
                if col_name.endswith(('m', 'me', 'mep')):
                    hash_map[sql_name][col_name] = {'ids':set(list_), 'moe': True}
                else:
                    hash_map[sql_name][col_name] = {'ids':set(list_), 'moe': False}  
                    
                if col_name.endswith(('p')):
                    hash_map[sql_name][col_name]['percent'] = True
                else:
                    hash_map[sql_name][col_name]['percent'] = False
            list_ = []
                
    return hash_map

# %%
list(table_meta['tbl_name'])
# Out:
# ['b01001_population_by_age_gender_acs_m',
#  'b01001a_whi_population_by_age_gender_acs_m',
#  'b01001b_aa_population_by_age_gender_acs_m',
#  'b01001c_na_population_by_age_gender_acs_m',
#  'b01001d_as_population_by_age_gender_acs_m',
#  'b01001e_pi_population_by_age_gender_acs_m',
#  'b01001f_oth_population_by_age_gender_acs_m',
#  'b01001g_mlt_population_by_age_gender_acs_m',
#  'b01001h_nhw_population_by_age_gender_acs_m',
#  'b01001i_lat_population_by_age_gender_acs_m',
#  'b01002_med_age_acs_m',
#  'b03002_race_ethnicity_acs_m',
#  'b04001_first_reported_ancestry_acs_m',
#  'b04006_reported_ancestry_acs_m',
#  'b05002_citizenship_nativity_acs_m',
#  'b05002_place_of_birth_citizenship_nativity_acs_m',
#  'b05003_citizenship_nativity_by_age_gender_acs_m',
#  'b05006_foreign_born_place_of_birth_acs_m',
#  'b05011_naturalization_by_year_acs_m',
#  'b06009_educational_attainment_by_placeofbirth_acs_m',
#  'b07001_geomobility_in_migration_by_age_acs_m',
#  'b07001_geomobility_migration_curr_res_by_age_acs_m',
#  'b07204_geomobility_in_migration_acs_m',
#  'b07401_geomobility_out_migration_by_age_acs_m',
#  'b07403_geomobility_out_migration_acs_m',
#  'b08006_means_transportation_to_work_by_residence_gender_acs_m',
#  'b08101_means_transportation_to_work_by_residence_age_acs_m',
#  'b08105_means_transportation_to_work_by_residence_race_acs_m',
#  'b08134_means_by_traveltime_to_work_acs_m',
#  'b08135_agg_traveltime_to_work_acs_m',
#  'b08201_hhsize_by_vehicles_acs_m',
#  'b08301_means_transportation_to_work_by_residence_acs_m',
#  'b08303_traveltime_to_work_by_residence_acs_m',
#  'b08601_means_transportation_to_work_by_workplace_acs_m',
#  'b08603_traveltime_to_work_by_placeofwork_acs_m',
#  'b10059_grandparents_grandkids_by_poverty_acs_m',
#  'b11005_hh_with_kids_acs_m',
#  'b11007_hh_with_seniors_acs_m',
#  'b11009_unmarried_partners_hh_acs_m',
#  'b15001_educational_attainment_by_age_acs_m',
#  'b15002_educational_attainment_acs_m',
#  'b16004_home_language_english_ability_acs_m',
#  'b16005_nativity_english_ability_by_race_acs_m',
#  'b17001_poverty_by_age_gender_acs_m',
#  'b17001_poverty_by_population_acs_m',
#  'Economy',
#  'b17006_child_poverty_by_familytype_acs_m',
#  'b17010_families_with_children_in_poverty_race_acs_m',
#  'b17017_poverty_by_hh_type_acs_m',
#  'b17020_poverty_by_race_age_acs_m',
#  'b17026_income_to_poverty_by_families_acs_m',
#  'b18101_disability_by_gender_age_acs_bm',
#  'b18101_thru_b18107_disability_status_acs_m',
#  'b18101ai_disability_by_age_race_acs_m',
#  'b18102_hearing_difficulty_by_age_acs_m',
#  'b18103_vision_difficulty_by_age_acs_m',
#  'b18135_health_insurance_by_disability_status_acs_m',
#  'b18140_median_earning_by_disability_status_acs_m',
#  'b19001_hh_income_acs_m',
#  'b19001_hh_income_race_acs_m',
#  'b19013_b19113_b19202_mhi_fam_acs_m',
#  'b19013_mhi_race_acs_m',
#  'b19037_hh_income_by_age_acs_m',
#  'b19037_hh_income_by_age_race_acs_m',
#  'b19058_public_assist_acs_m',
#  'b19083_gini_index_acs_m',
#  'b19301_per_capita_income_acs_m',
#  'b22001_hh_foodstamps_snap_60yrs_acs_m',
#  'b22002_hh_foodstamps_snap_hhtype_kids_acs_m',
#  'b22003_b22005_hh_foodstamps_snap_by_race_acs_m',
#  'b22007_fam_foodstamps_snap_famtype_acs_m',
#  'b22008_mhi_foodstamps_snap_acs_m',
#  'b23006_educational_attainment_by_laborforce_acs_m',
#  'b23025_employment_acs_m',
#  'b25002_b25003_hu_occupancy_by_tenure_race_acs_m',
#  'b25007_hh_tenure_by_age_acs_m',
#  'b25010_avg_hhsize_by_tenure_acs_m',
#  'b25024_hu_units_in_structure_acs_m',
#  'b25031_median_rent_by_bedrooms_acs_m',
#  'b25032_hu_tenure_by_units_acs_m',
#  'b25044_hu_vehicles_acs_m',
#  'b25046_b25044_b01003_hh_vehicle_ownership_acs_m',
#  'b25056_b25058_contract_rent_acs_m',
#  'b25063_b25064_b25065_rent_acs_m',
#  None,
#  'b25065_b25066_aggregate_rent_by_units_acs_m',
#  'b25072_b25093_costburden_by_age_acs_m',
#  'b25074_costburden_renters_by_income_acs_m',
#  'b25081_b25082_b25089_b25090_mortgage_status_aggregate_acs_m',
#  'b25091_b25070_costburden_acs_m',
#  'b25097_median_value_by_mortgage_status_acs_m',
#  'b25106_costburden_by_income_acs_m',
#  'b25117_hu_tenure_by_fuel_acs_m',
#  'b25118_hh_income_by_tenure_acs_m',
#  'b25119_mhi_tenure_acs_m',
#  'b25127_hu_tenure_year_built_units_acs_m',
#  'b27001_healthinsurance_by_gender_age_acs_m',
#  'c15002_educational_attainment_by_race_acs_m',
#  'c18120_emp_status_by_disability_status_acs_m',
#  'c18130_poverty_status_by_disability_status_acs_m',
#  'c23002_employment_by_race_age_acs_m',
#  'demo_foreign_born_place_of_birth_acs_m']

# %%
uni_dict = []

for root, dir, files in os.walk('K:\DataServices\Code\SQL\ACS\Tables', topdown=False):
    
    for name in files:
        name_wo_ext = name[:-4]
        
        if name_wo_ext not in list(table_meta['tbl_name']):
            continue
        if name.endswith(".sql"):
            start = False
            #uni_dict[name_wo_ext] = {}
            with open(os.path.join(root, name)) as sql_file:
                lines = sql_file.readlines()
                visited_ids = set()
                f = ''
                temp_dict = {'estimate': [], 'universe': []}
                for i, line in enumerate(lines):
                    
                    
                    if('acs_est_pct(' in line):
                        start = True
                        
                    if start:
                        f += line
                        
                    if f.count(']') == 2:
                        start = False
                        if 'as' not in f and 'as' in lines[i+1]:
                            #Get strings within square brackets
                            w_bracs = re.findall(r'\[.*?\]', f)
                            
                            print(w_bracs)
                            try:
                                estimate = [w_bracs[0]] 
                                universe = [w_bracs[1]] 
                            except:
                                continue
                            final_list = []
                            #Split any strings with commas
                            for idx, s in enumerate(estimate):
                                if ',' in s:
                                    new_strings = s.split(',')
                                    estimate.extend(new_strings)
                                    estimate.pop(idx)
                                temp_dict['estimate'].append(''.join([x for x in estimate[idx] if x.isdigit()]))

                            for idx, s in enumerate(universe):
                                if ',' in s:
                                    new_strings = s.split(',')
                                    universe.extend(new_strings)
                                    universe.pop(idx)
                                temp_dict['universe'].append(''.join([x for x in universe[idx] if x.isdigit()]))
                                
                            print(temp_dict)
                            temp_dict = {'estimate': [], 'universe': []}
                            col = re.findall(r'as (.+?),', lines[i+1])[0]
                            #uni_dict[name_wo_ext][col] = temp_dict
                            uni_dict.append({'table'
                                            
                                            })
                            print(re.findall(r'as (.+?),', lines[i+1]))
                        print(f, f.count(']'), '\n')
                        f = ''                    
            sql_file.close()      


            #ids_dict[name_wo_ext] = list(filter(None, ids_dict[name_wo_ext]))
            #ids_dict_wo_names[name_wo_ext] = list(filter(None, ids_dict_wo_names[name_wo_ext]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-a17cea4b5f79> in <module>
#       1 uni_dict = []
#       2
# ----> 3 for root, dir, files in os.walk('K:\DataServices\Code\SQL\ACS\Tables', topdown=False):
#       4
#       5     for name in files:
#
# NameError: name 'os' is not defined

# %%
uni_dict
# Out:
# {'b25046_b25044_b01003_hh_vehicle_ownership_acs_m': {'c0_p': {'estimate': ['25044004',
#     '25044005',
#     '25044006',
#     '25044007',
#     '25044008',
#     '25044011',
#     '25044012',
#     '25044013',
#     '25044014',
#     '25044015'],
#    'universe': ['25044002', '25044009']},
#   'car_p': {'estimate': ['25044004', '25044011'],
#    'universe': ['25044002', '25044009']},
#   'c1_p': {'estimate': ['25044005', '25044012'],
#    'universe': ['25044002', '25044009']},
#   'c2_p': {'estimate': ['25044006',
#     '25044007',
#     '25044008',
#     '25044013',
#     '25044014',
#     '25044015'],
#    'universe': ['25044002', '25044009']},
#   'c3p_p': {'estimate': ['25044003'], 'universe': ['25044002']},
#   'oo_c0_p': {'estimate': ['25044010'], 'universe': ['25044009']},
#   'r_c0_p': {'estimate': [], 'universe': []}},
#  'b01002_med_age_acs_m': {},
#  'b04006_reported_ancestry_acs_m': {'afghan_p': {'estimate': ['003'],
#    'universe': ['001']},
#   'alban_p': {'estimate': ['004'], 'universe': ['001']},
#   'alsat_p': {'estimate': ['005'], 'universe': ['001']},
#   'amrica_p': {'estimate': ['006'], 'universe': ['001']},
#   'arab_p': {'estimate': ['015'], 'universe': ['001']},
#   'egypt_p': {'estimate': ['008'], 'universe': ['001']},
#   'iraqi_p': {'estimate': ['009'], 'universe': ['001']},
#   'jordan_p': {'estimate': ['010'], 'universe': ['001']},
#   'leban_p': {'estimate': ['011'], 'universe': ['001']},
#   'mroccn_p': {'estimate': ['012'], 'universe': ['001']},
#   'palest_p': {'estimate': ['013'], 'universe': ['001']},
#   'syrian_p': {'estimate': ['014'], 'universe': ['001']},
#   'o_arab_p': {'estimate': ['016'], 'universe': ['001']},
#   'armen_p': {'estimate': ['017'], 'universe': ['001']},
#   'assyr_p': {'estimate': ['018'], 'universe': ['001']},
#   'austrl_p': {'estimate': ['019'], 'universe': ['001']},
#   'austrn_p': {'estimate': ['020'], 'universe': ['001']},
#   'basque_p': {'estimate': ['021'], 'universe': ['001']},
#   'belgn_p': {'estimate': ['022'], 'universe': ['001']},
#   'brazil_p': {'estimate': ['023'], 'universe': ['001']},
#   'britsh_p': {'estimate': ['024'], 'universe': ['001']},
#   'bulgrn_p': {'estimate': ['025'], 'universe': ['001']},
#   'cajun_p': {'estimate': ['026'], 'universe': ['001']},
#   'canada_p': {'estimate': ['027'], 'universe': ['001']},
#   'crpth_p': {'estimate': ['028'], 'universe': ['001']},
#   'celtic_p': {'estimate': ['029'], 'universe': ['001']},
#   'croatn_p': {'estimate': ['030'], 'universe': ['001']},
#   'cyprit_p': {'estimate': ['031'], 'universe': ['001']},
#   'czech_p': {'estimate': ['032'], 'universe': ['001']},
#   'czcslv_p': {'estimate': ['033'], 'universe': ['001']},
#   'danish_p': {'estimate': ['034'], 'universe': ['001']},
#   'dutch_p': {'estimate': ['035'], 'universe': ['001']},
#   'e_eurp_p': {'estimate': ['036'], 'universe': ['001']},
#   'eng_p': {'estimate': ['037'], 'universe': ['001']},
#   'eston_p': {'estimate': ['038'], 'universe': ['001']},
#   'europe_p': {'estimate': ['039'], 'universe': ['001']},
#   'finnsh_p': {'estimate': ['040'], 'universe': ['001']},
#   'french_p': {'estimate': ['041'], 'universe': ['001']},
#   'frcand_p': {'estimate': ['042'], 'universe': ['001']},
#   'german_p': {'estimate': ['043'], 'universe': ['001']},
#   'grmrsn_p': {'estimate': ['044'], 'universe': ['001']},
#   'greek_p': {'estimate': ['045'], 'universe': ['001']},
#   'guyan_p': {'estimate': ['046'], 'universe': ['001']},
#   'hungar_p': {'estimate': ['047'], 'universe': ['001']},
#   'icelnd_p': {'estimate': ['048'], 'universe': ['001']},
#   'iran_p': {'estimate': ['049'], 'universe': ['001']},
#   'irish_p': {'estimate': ['050'], 'universe': ['001']},
#   'israel_p': {'estimate': ['051'], 'universe': ['001']},
#   'italia_p': {'estimate': ['052'], 'universe': ['001']},
#   'latv_p': {'estimate': ['053'], 'universe': ['001']},
#   'lthuan_p': {'estimate': ['054'], 'universe': ['001']},
#   'lxmbrg_p': {'estimate': ['055'], 'universe': ['001']},
#   'maced_p': {'estimate': ['056'], 'universe': ['001']},
#   'malt_p': {'estimate': ['057'], 'universe': ['001']},
#   'n_zlnd_p': {'estimate': ['058'], 'universe': ['001']},
#   'n_eurp_p': {'estimate': ['059'], 'universe': ['001']},
#   'norwgn_p': {'estimate': ['060'], 'universe': ['001']},
#   'pengrm_p': {'estimate': ['061'], 'universe': ['001']},
#   'polish_p': {'estimate': ['062'], 'universe': ['001']},
#   'portug_p': {'estimate': ['063'], 'universe': ['001']},
#   'roman_p': {'estimate': ['064'], 'universe': ['001']},
#   'russia_p': {'estimate': ['065'], 'universe': ['001']},
#   'scand_p': {'estimate': ['066'], 'universe': ['001']},
#   'sct_ir_p': {'estimate': ['067'], 'universe': ['001']},
#   'scott_p': {'estimate': ['068'], 'universe': ['001']},
#   'serbia_p': {'estimate': ['069'], 'universe': ['001']},
#   'slavic_p': {'estimate': ['070'], 'universe': ['001']},
#   'slovak_p': {'estimate': ['071'], 'universe': ['001']},
#   'sloven_p': {'estimate': ['072'], 'universe': ['001']},
#   'svt_un_p': {'estimate': ['073'], 'universe': ['001']},
#   'subshr_p': {'estimate': ['074'], 'universe': ['001']},
#   'c_vrd_p': {'estimate': ['075'], 'universe': ['001']},
#   'ethiop_p': {'estimate': ['076'], 'universe': ['001']},
#   'ghana_p': {'estimate': ['077'], 'universe': ['001']},
#   'kenya_p': {'estimate': ['078'], 'universe': ['001']},
#   'libria_p': {'estimate': ['079'], 'universe': ['001']},
#   'nigria_p': {'estimate': ['080'], 'universe': ['001']},
#   'senegl_p': {'estimate': ['081'], 'universe': ['001']},
#   'sra_ln_p': {'estimate': ['082'], 'universe': ['001']},
#   'somal_p': {'estimate': ['083'], 'universe': ['001']},
#   's_afr_p': {'estimate': ['084'], 'universe': ['001']},
#   'sudan_p': {'estimate': ['085'], 'universe': ['001']},
#   'uganda_p': {'estimate': ['086'], 'universe': ['001']},
#   'zimbab_p': {'estimate': ['087'], 'universe': ['001']},
#   'africa_p': {'estimate': ['088'], 'universe': ['001']},
#   'o_subs_p': {'estimate': ['089'], 'universe': ['001']},
#   'swed_p': {'estimate': ['090'], 'universe': ['001']},
#   'swiss_p': {'estimate': ['091'], 'universe': ['001']},
#   'turksh_p': {'estimate': ['092'], 'universe': ['001']},
#   'ukrain_p': {'estimate': ['093'], 'universe': ['001']},
#   'welsh_p': {'estimate': ['094'], 'universe': ['001']},
#   'w_ind_p': {'estimate': ['095'], 'universe': ['001']},
#   'baham_p': {'estimate': ['096'], 'universe': ['001']},
#   'barbad_p': {'estimate': ['097'], 'universe': ['001']},
#   'belize_p': {'estimate': ['098'], 'universe': ['001']},
#   'bermud_p': {'estimate': ['099'], 'universe': ['001']},
#   'brt_wi_p': {'estimate': ['100'], 'universe': ['001']},
#   'dch_wi_p': {'estimate': ['101'], 'universe': ['001']},
#   'haiti_p': {'estimate': ['102'], 'universe': ['001']},
#   'jamac_p': {'estimate': ['103'], 'universe': ['001']},
#   'trntbg_p': {'estimate': ['104'], 'universe': ['001']},
#   'v_isl_p': {'estimate': ['105'], 'universe': ['001']},
#   'w_indi_p': {'estimate': ['106'], 'universe': ['001']},
#   'ow_ind_p': {'estimate': ['107'], 'universe': ['001']},
#   'ygslav_p': {'estimate': ['108'], 'universe': ['001']},
#   'oth_p': {'estimate': ['109'], 'universe': ['001']},
#   'unclss_p': {'estimate': [], 'universe': []}},
#  'b05002_citizenship_nativity_acs_m': {'native_p': {'estimate': ['013'],
#    'universe': ['001']},
#   'fb_p': {'estimate': ['014'], 'universe': ['001']},
#   'natr_p': {'estimate': ['015'], 'universe': ['001']},
#   'noncitz_p': {'estimate': [], 'universe': []}},
#  'b05003_citizenship_nativity_by_age_gender_acs_m': {},
#  'b05011_naturalization_by_year_acs_m': {'noncitzp': {'estimate': ['003'],
#    'universe': ['001']},
#   'natrp': {'estimate': ['004'], 'universe': ['003']},
#   'nt10op': {'estimate': ['005'], 'universe': ['003']},
#   'nt0509p': {'estimate': ['006'], 'universe': ['003']},
#   'nt0004p': {'estimate': ['007'], 'universe': ['003']},
#   'nt9599p': {'estimate': ['008'], 'universe': ['003']},
#   'nt9094p': {'estimate': ['009'], 'universe': ['003']},
#   'nt8589p': {'estimate': ['010'], 'universe': ['003']},
#   'nt8084p': {'estimate': ['011'], 'universe': ['003']},
#   'ntpre80p': {'estimate': [], 'universe': []}},
#  'b06009_educational_attainment_by_placeofbirth_acs_m': {'bslh_p': {'estimate': ['009'],
#    'universe': ['007']},
#   'bshg_p': {'estimate': ['010'], 'universe': ['007']},
#   'bssc_p': {'estimate': ['011', '012'], 'universe': ['007']},
#   'bsbd_p': {'estimate': ['014', '020'], 'universe': ['013', '019']},
#   'bolh_p': {'estimate': ['015', '021'], 'universe': ['013', '019']},
#   'bohg_p': {'estimate': ['016', '022'], 'universe': ['013', '019']},
#   'bosc_p': {'estimate': ['017', '018', '023', '024'],
#    'universe': ['013', '019']},
#   'bobd_p': {'estimate': ['026'], 'universe': ['025']},
#   'fblh_p': {'estimate': ['027'], 'universe': ['025']},
#   'fbhg_p': {'estimate': ['028'], 'universe': ['025']},
#   'fbsc_p': {'estimate': ['029', '030'], 'universe': ['025']},
#   'fbbd_p': {'estimate': [], 'universe': []}},
#  'b08134_means_by_traveltime_to_work_acs_m': {'mlt15_p': {'estimate': ['004',
#     '005',
#     '006'],
#    'universe': ['001']},
#   'm15_29_p': {'estimate': ['002', '003', '004', '005', '006'],
#    'universe': ['001']},
#   'mlt30_p': {'estimate': ['007', '008'], 'universe': ['001']},
#   'm30_44_p': {'estimate': ['009'], 'universe': ['001']},
#   'm45_59_p': {'estimate': ['007', '008', '009'], 'universe': ['001']},
#   'm30_59_p': {'estimate': ['010'], 'universe': ['001']},
#   'm60o_p': {'estimate': ['011'], 'universe': ['001']},
#   'ctv_p': {'estimate': ['012', '013'], 'universe': ['011']},
#   'ctvlt15_p': {'estimate': ['014', '015', '016'], 'universe': ['011']},
#   'ctv15_29_p': {'estimate': ['012', '013', '014', '015', '016'],
#    'universe': ['011']},
#   'ctvlt30_p': {'estimate': ['017', '018'], 'universe': ['011']},
#   'ctv30_44_p': {'estimate': ['019'], 'universe': ['011']},
#   'ctv45_59_p': {'estimate': ['017', '018', '019'], 'universe': ['011']},
#   'ctv30_59_p': {'estimate': ['020'], 'universe': ['011']},
#   'ctv60o_p': {'estimate': ['021'], 'universe': ['011']},
#   'c1_p': {'estimate': ['022', '023'], 'universe': ['021']},
#   'c1_lt15_p': {'estimate': ['024', '025', '026'], 'universe': ['021']},
#   'c1_15_29_p': {'estimate': ['022', '023', '024', '025', '026'],
#    'universe': ['021']},
#   'c1_lt30_p': {'estimate': ['027', '028'], 'universe': ['021']},
#   'c1_30_44_p': {'estimate': ['029'], 'universe': ['021']},
#   'c1_45_59_p': {'estimate': ['027', '028', '029'], 'universe': ['021']},
#   'c1_30_59_p': {'estimate': ['030'], 'universe': ['021']},
#   'c1_60o_p': {'estimate': ['031'], 'universe': ['011']},
#   'cp_p': {'estimate': ['032', '033'], 'universe': ['031']},
#   'cp_lt15_p': {'estimate': ['034', '035', '036'], 'universe': ['031']},
#   'cp_15_29_p': {'estimate': ['032', '033', '034', '035', '036'],
#    'universe': ['031']},
#   'cp_lt30_p': {'estimate': ['037', '038'], 'universe': ['031']},
#   'cp_30_44_p': {'estimate': ['039'], 'universe': ['031']},
#   'cp_45_59_p': {'estimate': ['037', '038', '039'], 'universe': ['031']},
#   'cp_30_59_p': {'estimate': ['040'], 'universe': ['031']},
#   'cp_60o_p': {'estimate': ['061'], 'universe': ['001']},
#   'pub_p': {'estimate': ['062', '063'], 'universe': ['061']},
#   'publt15_p': {'estimate': ['064', '065', '066'], 'universe': ['061']},
#   'pub15_29_p': {'estimate': ['062', '063', '064', '065', '066'],
#    'universe': ['061']},
#   'publt30_p': {'estimate': ['067', '068'], 'universe': ['061']},
#   'pub30_44_p': {'estimate': ['069'], 'universe': ['061']},
#   'pub45_59_p': {'estimate': ['067', '068', '069'], 'universe': ['061']},
#   'pub30_59_p': {'estimate': ['070'], 'universe': ['061']},
#   'pub60o_p': {'estimate': ['101'], 'universe': ['001']},
#   'walk_p': {'estimate': ['102', '103'], 'universe': ['101']},
#   'wlklt15_p': {'estimate': ['104', '105', '106'], 'universe': ['101']},
#   'wlk15_29_p': {'estimate': ['102', '103', '104', '105', '106'],
#    'universe': ['101']},
#   'wlklt30_p': {'estimate': ['107', '108'], 'universe': ['101']},
#   'wlk30_44_p': {'estimate': ['109'], 'universe': ['101']},
#   'wlk45_59_p': {'estimate': ['107', '108', '109'], 'universe': ['101']},
#   'wlk30_59_p': {'estimate': ['110'], 'universe': ['101']},
#   'wlk60o_p': {'estimate': ['111'], 'universe': ['001']},
#   'other_p': {'estimate': ['112', '113'], 'universe': ['111']},
#   'othlt15_p': {'estimate': ['114', '115', '116'], 'universe': ['111']},
#   'oth15_29_p': {'estimate': ['112', '113', '114', '115', '116'],
#    'universe': ['111']},
#   'othlt30_p': {'estimate': ['117', '118'], 'universe': ['111']},
#   'oth30_44_p': {'estimate': ['119'], 'universe': ['111']},
#   'oth45_59_p': {'estimate': ['117', '118', '119'], 'universe': ['111']},
#   'oth30_59_p': {'estimate': ['120'], 'universe': ['111']},
#   'oth60o_p': {'estimate': [], 'universe': []}},
#  'b08135_agg_traveltime_to_work_acs_m': {},
#  'b08201_hhsize_by_vehicles_acs_m': {'hh_0c_p': {'estimate': ['003',
#     '004',
#     '005',
#     '006'],
#    'universe': ['001']},
#   'hh_car_p': {'estimate': ['003'], 'universe': ['001']},
#   'hh_1c_p': {'estimate': ['004'], 'universe': ['001']},
#   'hh_2c_p': {'estimate': ['005'], 'universe': ['001']},
#   'hh_3c_p': {'estimate': ['006'], 'universe': ['001']},
#   'hh_4oc_p': {'estimate': ['007'], 'universe': ['001']},
#   'hh1_p': {'estimate': ['008'], 'universe': ['007']},
#   'hh1_0c_p': {'estimate': ['009', '010', '011', '012'], 'universe': ['007']},
#   'hh1_car_p': {'estimate': ['009'], 'universe': ['007']},
#   'hh1_1c_p': {'estimate': ['010'], 'universe': ['007']},
#   'hh1_2c_p': {'estimate': ['011'], 'universe': ['007']},
#   'hh1_3c_p': {'estimate': ['012'], 'universe': ['007']},
#   'hh1_4oc_p': {'estimate': ['013'], 'universe': ['001']},
#   'hh2_p': {'estimate': ['014'], 'universe': ['013']},
#   'hh2_0c_p': {'estimate': ['015', '016', '017', '018'], 'universe': ['013']},
#   'hh2_car_p': {'estimate': ['015'], 'universe': ['013']},
#   'hh2_1c_p': {'estimate': ['016'], 'universe': ['013']},
#   'hh2_2c_p': {'estimate': ['017'], 'universe': ['013']},
#   'hh2_3c_p': {'estimate': ['018'], 'universe': ['013']},
#   'hh2_4oc_p': {'estimate': ['019'], 'universe': ['001']},
#   'hh3_p': {'estimate': ['020'], 'universe': ['019']},
#   'hh3_0c_p': {'estimate': ['021', '022', '023', '024'], 'universe': ['019']},
#   'hh3_car_p': {'estimate': ['021'], 'universe': ['019']},
#   'hh3_1c_p': {'estimate': ['022'], 'universe': ['019']},
#   'hh3_2c_p': {'estimate': ['023'], 'universe': ['019']},
#   'hh3_3c_p': {'estimate': ['024'], 'universe': ['019']},
#   'hh3_4oc_p': {'estimate': ['025'], 'universe': ['001']},
#   'hh4_p': {'estimate': ['026'], 'universe': ['025']},
#   'hh4_0c_p': {'estimate': ['027', '028', '029', '030'], 'universe': ['025']},
#   'hh4_car_p': {'estimate': ['027'], 'universe': ['025']},
#   'hh4_1c_p': {'estimate': ['028'], 'universe': ['025']},
#   'hh4_2c_p': {'estimate': ['029'], 'universe': ['025']},
#   'hh4_3c_p': {'estimate': ['030'], 'universe': ['025']},
#   'hh4_4oc_p': {'estimate': [], 'universe': []}},
#  'b08301_means_transportation_to_work_by_residence_acs_m': {'ctv_p': {'estimate': ['003'],
#    'universe': ['002']},
#   'ctvsngl_p': {'estimate': ['004'], 'universe': ['002']},
#   'carpool_p': {'estimate': ['010'], 'universe': ['001']},
#   'pub_p': {'estimate': ['016'], 'universe': ['001']},
#   'taxi_p': {'estimate': ['017'], 'universe': ['001']},
#   'mcycle_p': {'estimate': ['018'], 'universe': ['001']},
#   'bicycle_p': {'estimate': ['019'], 'universe': ['001']},
#   'walk_p': {'estimate': ['020'], 'universe': ['001']},
#   'other_p': {'estimate': ['021'], 'universe': ['001']},
#   'home_p': {'estimate': [], 'universe': []}},
#  'b08303_traveltime_to_work_by_residence_acs_m': {'mlt15_p': {'estimate': ['005',
#     '006',
#     '007'],
#    'universe': ['001']},
#   'm15_30_p': {'estimate': ['008', '009', '010'], 'universe': ['001']},
#   'm30_45_p': {'estimate': ['011'], 'universe': ['001']},
#   'm45_60_p': {'estimate': ['012'], 'universe': ['001']},
#   'm60_90_p': {'estimate': ['012', '013'], 'universe': ['001']},
#   'm60ovr_p': {'estimate': ['013'], 'universe': ['001']},
#   'm90ovr_p': {'estimate': [], 'universe': []}},
#  'b08601_means_transportation_to_work_by_workplace_acs_m': {'ctv_p': {'estimate': ['010'],
#    'universe': ['001']},
#   'pub_p': {'estimate': ['016'], 'universe': ['001']},
#   'taxi_p': {'estimate': ['017'], 'universe': ['001']},
#   'mcycle_p': {'estimate': ['018'], 'universe': ['001']},
#   'bicycle_p': {'estimate': ['019'], 'universe': ['001']},
#   'walk_p': {'estimate': ['020'], 'universe': ['001']},
#   'other_p': {'estimate': ['021'], 'universe': ['001']},
#   'home_p': {'estimate': [], 'universe': []}},
#  'b08603_traveltime_to_work_by_placeofwork_acs_m': {'mlt15_p': {'estimate': ['005',
#     '006',
#     '007'],
#    'universe': ['001']},
#   'm15_30_p': {'estimate': ['008', '009', '010'], 'universe': ['001']},
#   'm30_45_p': {'estimate': ['011'], 'universe': ['001']},
#   'm45_60_p': {'estimate': ['012'], 'universe': ['001']},
#   'm60_90_p': {'estimate': ['012', '013'], 'universe': ['001']},
#   'm60ovr_p': {'estimate': ['013'], 'universe': ['001']},
#   'm90ovr_p': {'estimate': [], 'universe': []}},
#  'b11005_hh_with_kids_acs_m': {'hhkids_p': {'estimate': ['003'],
#    'universe': ['003', '012']},
#   'famhh_p': {'estimate': ['004'], 'universe': ['004', '013']},
#   'mfamhh_p': {'estimate': ['005'], 'universe': ['005', '014']},
#   'ofamhh_p': {'estimate': ['006'], 'universe': ['006', '015']},
#   'omale_p': {'estimate': ['007'], 'universe': ['007', '016']},
#   'ofem_p': {'estimate': ['008'], 'universe': ['008', '017']},
#   'nonfam_p': {'estimate': ['009'], 'universe': ['009', '018']},
#   'nfmale_p': {'estimate': ['010'], 'universe': ['010', '019']},
#   'nfem_p': {'estimate': [], 'universe': []}},
#  'b11007_hh_with_seniors_acs_m': {'hh65o_p': {'estimate': ['003'],
#    'universe': ['003', '008']},
#   'hh1_p': {'estimate': ['004'], 'universe': ['004', '009']},
#   'hh2o_p': {'estimate': ['005'], 'universe': ['005', '010']},
#   'famhh_p': {'estimate': ['006'], 'universe': ['006', '011']},
#   'nonfam_p': {'estimate': [], 'universe': []}},
#  'b11009_unmarried_partners_hh_acs_m': {},
#  'b15001_educational_attainment_by_age_acs_m': {'pop1824_p': {'estimate': ['004',
#     '005',
#     '045',
#     '046'],
#    'universe': ['003', '044']},
#   'lh1824_p': {'estimate': ['006', '047'], 'universe': ['003', '044']},
#   'hs1824_p': {'estimate': ['007', '008', '048', '049'],
#    'universe': ['003', '044']},
#   'sc1824_p': {'estimate': ['009', '010', '050', '051'],
#    'universe': ['003', '044']},
#   'bd1824_p': {'estimate': ['011', '052'], 'universe': ['001']},
#   'pop2534_p': {'estimate': ['012', '013', '053', '054'],
#    'universe': ['011', '052']},
#   'lh2534_p': {'estimate': ['014', '055'], 'universe': ['011', '052']},
#   'hs2534_p': {'estimate': ['015', '016', '056', '057'],
#    'universe': ['011', '052']},
#   'sc2534_p': {'estimate': ['017', '018', '058', '059'],
#    'universe': ['011', '052']},
#   'bd2534_p': {'estimate': ['019', '060'], 'universe': ['001']},
#   'pop3544_p': {'estimate': ['020', '021', '061', '062'],
#    'universe': ['019', '060']},
#   'lh3544_p': {'estimate': ['022', '063'], 'universe': ['019', '060']},
#   'hs3544_p': {'estimate': ['023', '024', '064', '065'],
#    'universe': ['019', '060']},
#   'sc3544_p': {'estimate': ['025', '026', '066', '067'],
#    'universe': ['019', '060']},
#   'bd3544_p': {'estimate': ['027', '068'], 'universe': ['001']},
#   'pop4564_p': {'estimate': ['028', '029', '060', '070'],
#    'universe': ['027', '068']},
#   'lh4564_p': {'estimate': ['030', '071'], 'universe': ['027', '068']},
#   'hs4564_p': {'estimate': ['031', '032', '072', '073'],
#    'universe': ['027', '068']},
#   'sc4564_p': {'estimate': ['033', '034', '074', '075'],
#    'universe': ['027', '068']},
#   'bd4564_p': {'estimate': ['011', '052', '019', '060', '027', '068'],
#    'universe': ['001']},
#   'pop2564_p': {'estimate': ['012',
#     '013',
#     '053',
#     '054',
#     '020',
#     '021',
#     '061',
#     '062',
#     '028',
#     '029',
#     '069',
#     '070'],
#    'universe': ['011', '052', '019', '060', '027', '068']},
#   'lh2564_p': {'estimate': ['014', '055', '022', '063', '030', '071'],
#    'universe': ['011', '052', '019', '060', '027', '068']},
#   'hs2564_p': {'estimate': ['015',
#     '016',
#     '056',
#     '057',
#     '023',
#     '024',
#     '064',
#     '065',
#     '031',
#     '032',
#     '072',
#     '073'],
#    'universe': ['011', '052', '019', '060', '027', '068']},
#   'sc2564_p': {'estimate': ['017',
#     '018',
#     '058',
#     '059',
#     '025',
#     '026',
#     '066',
#     '067',
#     '033',
#     '034',
#     '074',
#     '075'],
#    'universe': ['011', '052', '019', '060', '027', '068']},
#   'bd2564_p': {'estimate': ['035', '076'], 'universe': ['001']},
#   'pop65o_p': {'estimate': ['036', '037', '077', '078'],
#    'universe': ['035', '076']},
#   'lh65o_p': {'estimate': ['038', '079'], 'universe': ['035', '076']},
#   'hs65o_p': {'estimate': ['039', '040', '080', '081'],
#    'universe': ['035', '076']},
#   'sc65o_p': {'estimate': ['041', '042', '082', '083'],
#    'universe': ['035', '076']},
#   'bd65o_p': {'estimate': [], 'universe': []}},
#  'b15002_educational_attainment_acs_m': {'nohs_p': {'estimate': ['011', '028'],
#    'universe': ['001']},
#   'hs_p': {'estimate': ['012', '013', '029', '030'], 'universe': ['001']},
#   'sc_p': {'estimate': ['014', '031'], 'universe': ['001']},
#   'assoc_p': {'estimate': ['014', '015', '031', '032'], 'universe': ['001']},
#   'asba_p': {'estimate': ['014',
#     '015',
#     '016',
#     '017',
#     '018',
#     '031',
#     '032',
#     '033',
#     '034',
#     '035'],
#    'universe': ['001']},
#   'aspl_p': {'estimate': ['015', '032'], 'universe': ['001']},
#   'ba_p': {'estimate': ['015',
#     '016',
#     '017',
#     '018',
#     '032',
#     '033',
#     '034',
#     '035'],
#    'universe': ['001']},
#   'bapl_p': {'estimate': ['016', '033'], 'universe': ['001']},
#   'mast_p': {'estimate': ['017', '034'], 'universe': ['001']},
#   'prof_p': {'estimate': ['018', '035'], 'universe': ['001']},
#   'doc_p': {'estimate': ['016', '017', '018', '033', '034', '035'],
#    'universe': ['001']},
#   'mpl_p': {'estimate': ['003', '004', '005', '006'], 'universe': ['002']},
#   'm_nohs_p': {'estimate': ['003',
#     '004',
#     '005',
#     '006',
#     '007',
#     '008',
#     '009',
#     '010'],
#    'universe': ['002']},
#   'm_lths_p': {'estimate': ['011'], 'universe': ['002']},
#   'm_hs_p': {'estimate': ['012', '013'], 'universe': ['002']},
#   'm_sc_p': {'estimate': ['014'], 'universe': ['002']},
#   'm_assoc_p': {'estimate': ['014', '015'], 'universe': ['002']},
#   'm_asba_p': {'estimate': ['014', '015', '016', '017', '018'],
#    'universe': ['002']},
#   'm_aspl_p': {'estimate': ['015'], 'universe': ['002']},
#   'm_ba_p': {'estimate': ['015', '016', '017', '018'], 'universe': ['002']},
#   'm_bapl_p': {'estimate': ['016'], 'universe': ['002']},
#   'm_mast_p': {'estimate': ['017'], 'universe': ['002']},
#   'm_prof_p': {'estimate': ['018'], 'universe': ['002']},
#   'm_doc_p': {'estimate': ['016', '017', '018'], 'universe': ['002']},
#   'm_mpl_p': {'estimate': ['020', '021', '022', '023'], 'universe': ['019']},
#   'f_nohs_p': {'estimate': ['020',
#     '021',
#     '022',
#     '023',
#     '024',
#     '025',
#     '026',
#     '027'],
#    'universe': ['019']},
#   'f_lths_p': {'estimate': ['028'], 'universe': ['019']},
#   'f_hs_p': {'estimate': ['029', '030'], 'universe': ['019']},
#   'f_sc_p': {'estimate': ['031'], 'universe': ['019']},
#   'f_assoc_p': {'estimate': ['031', '032'], 'universe': ['019']},
#   'f_asba_p': {'estimate': ['031', '032', '033', '034', '035'],
#    'universe': ['019']},
#   'f_aspl_p': {'estimate': ['032'], 'universe': ['019']},
#   'f_ba_p': {'estimate': ['032', '033', '034', '035'], 'universe': ['019']},
#   'f_bapl_p': {'estimate': ['033'], 'universe': ['019']},
#   'f_mast_p': {'estimate': ['034'], 'universe': ['019']},
#   'f_prof_p': {'estimate': ['035'], 'universe': ['019']},
#   'f_doc_p': {'estimate': ['033', '034', '035'], 'universe': ['019']},
#   'f_mpl_p': {'estimate': [], 'universe': []}},
#  'b16004_home_language_english_ability_acs_m': {'english_p': {'estimate': ['007',
#     '012',
#     '017',
#     '022',
#     '029',
#     '034',
#     '039',
#     '044',
#     '051',
#     '056',
#     '061',
#     '066'],
#    'universe': ['001']},
#   'en_nw_p': {'estimate': ['008',
#     '013',
#     '018',
#     '023',
#     '030',
#     '035',
#     '040',
#     '045',
#     '052',
#     '057',
#     '062',
#     '067'],
#    'universe': ['001']},
#   'en_na_p': {'estimate': ['004', '026', '048'], 'universe': ['001']},
#   ' span_p': {'estimate': ['007', '029', '051'],
#    'universe': ['004', '026', '048']},
#   'sp_nw_p': {'estimate': ['008', '030', '052'],
#    'universe': ['004', '026', '048']},
#   'sp_na_p': {'estimate': ['009', '031', '053'], 'universe': ['001']},
#   'euro_p': {'estimate': ['012', '034', '056'],
#    'universe': ['009', '031', '053']},
#   'eu_nw_p': {'estimate': ['013', '035', '057'],
#    'universe': ['009', '031', '053']},
#   'eu_na_p': {'estimate': ['014', '036', '058'], 'universe': ['001']},
#   'asian_p': {'estimate': ['017', '039', '061'],
#    'universe': ['014', '036', '058']},
#   'as_nw_p': {'estimate': ['018', '040', '062'],
#    'universe': ['014', '036', '058']},
#   'as_na_p': {'estimate': ['019', '041', '063'], 'universe': ['001']},
#   'other_p': {'estimate': ['022', '044', '066'],
#    'universe': ['019', '041', '063']},
#   'ot_nw_p': {'estimate': ['023', '045', '067'],
#    'universe': ['019', '041', '063']},
#   'ot_na_p': {'estimate': [], 'universe': []}},
#  'b16005_nativity_english_ability_by_race_acs_m': {'whi_nw_p': {'estimate': ['002'],
#    'universe': ['001']},
#   'nwhipop_p': {'estimate': ['006'], 'universe': ['002']},
#   'nwhi_nw_p': {'estimate': ['007'], 'universe': ['001']},
#   'fwhipop_p': {'estimate': ['011'], 'universe': ['007']},
#   'fwhi_nw_p': {'estimate': ['006', '011'], 'universe': ['001']},
#   'aa_nw_p': {'estimate': ['002'], 'universe': ['001']},
#   'naapop_p': {'estimate': ['006'], 'universe': ['002']},
#   'naa_nw_p': {'estimate': ['007'], 'universe': ['001']},
#   'faapop_p': {'estimate': ['011'], 'universe': ['007']},
#   'faa_nw_p': {'estimate': ['006', '011'], 'universe': ['001']},
#   'na_nw_p': {'estimate': ['002'], 'universe': ['001']},
#   'nnapop_p': {'estimate': ['006'], 'universe': ['002']},
#   'nna_nw_p': {'estimate': ['007'], 'universe': ['001']},
#   'fnapop_p': {'estimate': ['011'], 'universe': ['007']},
#   'fna_nw_p': {'estimate': ['006', '011'], 'universe': ['001']},
#   'pi_nw_p': {'estimate': ['002'], 'universe': ['001']},
#   'npipop_p': {'estimate': ['006'], 'universe': ['002']},
#   'npi_nw_p': {'estimate': ['007'], 'universe': ['001']},
#   'fpipop_p': {'estimate': ['011'], 'universe': ['007']},
#   'fpi_nw_p': {'estimate': ['006', '011'], 'universe': ['001']},
#   'oth_nw_p': {'estimate': ['002'], 'universe': ['001']},
#   'nothpop_p': {'estimate': ['006'], 'universe': ['002']},
#   'noth_nw_p': {'estimate': ['007'], 'universe': ['001']},
#   'fothpop_p': {'estimate': ['011'], 'universe': ['007']},
#   'foth_nw_p': {'estimate': ['006', '011'], 'universe': ['001']},
#   'mlt_nw_p': {'estimate': ['002'], 'universe': ['001']},
#   'nmltpop_p': {'estimate': ['006'], 'universe': ['002']},
#   'nmlt_nw_p': {'estimate': ['007'], 'universe': ['001']},
#   'fmltpop_p': {'estimate': ['011'], 'universe': ['007']},
#   'fmlt_nw_p': {'estimate': ['006', '011'], 'universe': ['001']},
#   'nhw_nw_p': {'estimate': ['002'], 'universe': ['001']},
#   'nnhwpop_p': {'estimate': ['006'], 'universe': ['002']},
#   'nnhw_nw_p': {'estimate': ['007'], 'universe': ['001']},
#   'fnhwpop_p': {'estimate': ['011'], 'universe': ['007']},
#   'fnhw_nw_p': {'estimate': ['006', '011'], 'universe': ['001']},
#   'lat_nw_p': {'estimate': ['002'], 'universe': ['001']},
#   'nlatpop_p': {'estimate': ['006'], 'universe': ['002']},
#   'nlat_nw_p': {'estimate': ['007'], 'universe': ['001']},
#   'flatpop_p': {'estimate': ['011'], 'universe': ['007']},
#   'flat_nw_p': {'estimate': [], 'universe': []}},
#  'b17001_poverty_by_age_gender_acs_m': {'pov_p': {'estimate': ['004',
#     '005',
#     '018',
#     '019'],
#    'universe': ['004', '005', '018', '019', '033', '034', '047', '048']},
#   'pov_u6_p': {'estimate': ['004',
#     '005',
#     '006',
#     '007',
#     '008',
#     '009',
#     '018',
#     '019',
#     '020',
#     '021',
#     '022',
#     '023'],
#    'universe': ['004',
#     '005',
#     '006',
#     '007',
#     '008',
#     '009',
#     '018',
#     '019',
#     '020',
#     '021',
#     '022',
#     '023',
#     '033',
#     '034',
#     '035',
#     '036',
#     '037',
#     '038',
#     '047',
#     '048',
#     '049',
#     '050',
#     '051',
#     '052']},
#   'pov_u18_p': {'estimate': ['010', '024'],
#    'universe': ['010', '024', '039', '053']},
#   'pov1824_p': {'estimate': ['011', '025'],
#    'universe': ['011', '025', '040', '054']},
#   'pov2534_p': {'estimate': ['012', '026'],
#    'universe': ['012', '026', '041', '055']},
#   'pov3544_p': {'estimate': ['013', '027'],
#    'universe': ['013', '027', '042', '056']},
#   'pov4554_p': {'estimate': ['014', '028'],
#    'universe': ['014', '028', '043', '057']},
#   'pov5564_p': {'estimate': ['011',
#     '012',
#     '013',
#     '014',
#     '025',
#     '026',
#     '027',
#     '028'],
#    'universe': ['011',
#     '012',
#     '013',
#     '014',
#     '025',
#     '026',
#     '027',
#     '028',
#     '040',
#     '041',
#     '042',
#     '043',
#     '054',
#     '055',
#     '056',
#     '057']},
#   'pov2564_p': {'estimate': ['015', '016', '029', '030'],
#    'universe': ['015', '016', '029', '030', '044', '045', '058', '059']},
#   'pov_65o_p': {'estimate': ['017'], 'universe': ['017', '046']},
#   'fpv_p': {'estimate': ['018', '019'],
#    'universe': ['018', '019', '047', '048']},
#   'fpv_u6_p': {'estimate': ['018', '019', '020', '021', '022', '023'],
#    'universe': ['018',
#     '019',
#     '020',
#     '021',
#     '022',
#     '023',
#     '047',
#     '048',
#     '049',
#     '050',
#     '051',
#     '052']},
#   'fpv_u18_p': {'estimate': ['024'], 'universe': ['024', '053']},
#   'fpv1824_p': {'estimate': ['025'], 'universe': ['025', '054']},
#   'fpv2534_p': {'estimate': ['026'], 'universe': ['026', '055']},
#   'fpv3544_p': {'estimate': ['027'], 'universe': ['027', '056']},
#   'fpv4554_p': {'estimate': ['028'], 'universe': ['028', '057']},
#   'fpv5564_p': {'estimate': ['025', '026', '027', '028'],
#    'universe': ['025', '026', '027', '028', '054', '055', '056', '057']},
#   'fpv2564_p': {'estimate': ['029', '030'],
#    'universe': ['029', '030', '058', '059']},
#   'fpv_65o_p': {'estimate': ['003'], 'universe': ['003', '032']},
#   'mpv_p': {'estimate': ['004', '005'],
#    'universe': ['004', '005', '033', '034']},
#   'mpv_u6_p': {'estimate': ['004', '005', '006', '007', '008', '009'],
#    'universe': ['004',
#     '005',
#     '006',
#     '007',
#     '008',
#     '009',
#     '033',
#     '034',
#     '035',
#     '036',
#     '037',
#     '038',
#     '039']},
#   'mpv_u18_p': {'estimate': ['010'], 'universe': ['010', '039']},
#   'mpv1824_p': {'estimate': ['011'], 'universe': ['011', '040']},
#   'mpv2534_p': {'estimate': ['012'], 'universe': ['012', '041']},
#   'mpv3544_p': {'estimate': ['013'], 'universe': ['013', '042']},
#   'mpv4554_p': {'estimate': ['014'], 'universe': ['014', '043']},
#   'mpv5564_p': {'estimate': ['011', '012', '013', '014'],
#    'universe': ['011', '012', '013', '014', '040', '041', '042', '043']},
#   'mpv2564_p': {'estimate': ['015', '016'],
#    'universe': ['015', '016', '044', '045']},
#   'mpv_65o_p': {'estimate': [], 'universe': []}},
#  'b17001_poverty_by_population_acs_m': {},
#  'b17006_child_poverty_by_familytype_acs_m': {'m_u6p': {'estimate': ['006'],
#    'universe': ['006', '020']},
#   'm_6_17p': {'estimate': ['003'], 'universe': ['003', '017']},
#   'm_u18p': {'estimate': ['009', '010', '013', '014'],
#    'universe': ['009', '010', '013', '014', '023', '024', '027', '028']},
#   'o_u6p': {'estimate': ['011', '015'],
#    'universe': ['011', '015', '025', '029']},
#   'o_6_17p': {'estimate': ['007'], 'universe': ['007', '021']},
#   'o_u18p': {'estimate': [], 'universe': []}},
#  'b17010_families_with_children_in_poverty_race_acs_m': {},
#  'b17017_poverty_by_hh_type_acs_m': {'pov_hh_p': {'estimate': ['003'],
#    'universe': ['003', '032']},
#   'pov_f_p': {'estimate': ['004'], 'universe': ['004', '033']},
#   'pov_mf_p': {'estimate': ['020'], 'universe': ['020', '049']},
#   'pov_nf_p': {'estimate': ['031'], 'universe': ['001']},
#   'np_hh_p': {'estimate': ['032'], 'universe': ['003', '032']},
#   'np_f_p': {'estimate': ['033'], 'universe': ['004', '033']},
#   'np_mf_p': {'estimate': ['038'], 'universe': ['009', '038']},
#   'np_of_p': {'estimate': ['049'], 'universe': ['020', '049']},
#   'np_nf_p': {'estimate': [], 'universe': []}},
#  'b17020_poverty_by_race_age_acs_m': {},
#  'b17026_income_to_poverty_by_families_acs_m': {'f_u50p': {'estimate': ['003'],
#    'universe': ['001']},
#   'f_5074p': {'estimate': ['003', '004'], 'universe': ['001']},
#   'f_u75p': {'estimate': ['004'], 'universe': ['001']},
#   'f_7599p': {'estimate': ['002', '003', '004'], 'universe': ['001']},
#   'f_u100p': {'estimate': ['005'], 'universe': ['001']},
#   'f100124p': {'estimate': ['002', '003', '004', '005'], 'universe': ['001']},
#   'f_u125p': {'estimate': ['006'], 'universe': ['001']},
#   'f125149p': {'estimate': ['002', '003', '004', '005', '006'],
#    'universe': ['001']},
#   'f_u150p': {'estimate': ['007'], 'universe': ['001']},
#   'f150174p': {'estimate': ['008'], 'universe': ['001']},
#   'f175184p': {'estimate': ['009'], 'universe': ['001']},
#   'f185199p': {'estimate': ['002',
#     '003',
#     '004',
#     '005',
#     '006',
#     '007',
#     '008',
#     '009'],
#    'universe': ['001']},
#   'f_u200p': {'estimate': ['010'], 'universe': ['001']},
#   'f200299p': {'estimate': ['011'], 'universe': ['001']},
#   'f300399p': {'estimate': ['012'], 'universe': ['001']},
#   'f400499p': {'estimate': ['013'], 'universe': ['001']},
#   'f500ovrp': {'estimate': [], 'universe': []}},
#  'b19001_hh_income_acs_m': {'incu20_p': {'estimate': ['005',
#     '006',
#     '007',
#     '008'],
#    'universe': ['001']},
#   'inc2039_p': {'estimate': ['009', '010', '011'], 'universe': ['001']},
#   'inc4059_p': {'estimate': ['012'], 'universe': ['001']},
#   'inc6074_p': {'estimate': ['013'], 'universe': ['001']},
#   'inc7599_p': {'estimate': ['014', '015', '016', '017'], 'universe': ['001']},
#   'in100o_p': {'estimate': ['002', '003'], 'universe': ['001']},
#   'incu15p': {'estimate': ['004', '005', '006', '007'], 'universe': ['001']},
#   'inc1535p': {'estimate': ['008', '009', '010', '011', '012'],
#    'universe': ['001']},
#   'inc3575p': {'estimate': ['013', '014', '015'], 'universe': ['001']},
#   'in75150p': {'estimate': ['016', '017'], 'universe': ['001']},
#   'in150op': {'estimate': ['002'], 'universe': ['001']},
#   'incu10p': {'estimate': ['003'], 'universe': ['001']},
#   'inc1015p': {'estimate': ['004'], 'universe': ['001']},
#   'inc1520p': {'estimate': ['005'], 'universe': ['001']},
#   'inc2025p': {'estimate': ['006'], 'universe': ['001']},
#   'inc2530p': {'estimate': ['007'], 'universe': ['001']},
#   'inc3035p': {'estimate': ['008'], 'universe': ['001']},
#   'inc3540p': {'estimate': ['009'], 'universe': ['001']},
#   'inc4045p': {'estimate': ['010'], 'universe': ['001']},
#   'inc4550p': {'estimate': ['011'], 'universe': ['001']},
#   'inc5060p': {'estimate': ['012'], 'universe': ['001']},
#   'inc6075p': {'estimate': ['013'], 'universe': ['001']},
#   'i7599p': {'estimate': ['014'], 'universe': ['001']},
#   'i100125p': {'estimate': ['015'], 'universe': ['001']},
#   'i125150p': {'estimate': ['016'], 'universe': ['001']},
#   'i150200cp': {'estimate': ['017'], 'universe': ['001']},
#   'in200op': {'estimate': [], 'universe': []}},
#  'b19013_b19113_b19202_mhi_fam_acs_m': {},
#  'b19013_mhi_race_acs_m': {},
#  'b19037_hh_income_by_age_acs_m': {'iu25_p': {'estimate': ['003',
#     '004',
#     '005'],
#    'universe': ['002']},
#   'iu25u20_p': {'estimate': ['006', '007', '008', '009'], 'universe': ['002']},
#   'iu252039_p': {'estimate': ['010', '011', '012'], 'universe': ['002']},
#   'iu254059_p': {'estimate': ['013'], 'universe': ['002']},
#   'iu256074_p': {'estimate': ['014'], 'universe': ['002']},
#   'iu257599_p': {'estimate': ['015', '016', '017', '018'],
#    'universe': ['002']},
#   'iu25100o_p': {'estimate': ['019'], 'universe': ['001']},
#   'i25_44p': {'estimate': ['020', '021', '022'], 'universe': ['019']},
#   'i25u20_p': {'estimate': ['023', '024', '025', '026'], 'universe': ['019']},
#   'i252039_p': {'estimate': ['027', '028', '029'], 'universe': ['019']},
#   'i254059_p': {'estimate': ['030'], 'universe': ['019']},
#   'i256074_p': {'estimate': ['031'], 'universe': ['019']},
#   'i257599_p': {'estimate': ['032', '033', '034', '035'], 'universe': ['019']},
#   'i25100o_p': {'estimate': ['036'], 'universe': ['001']},
#   'i45_44_p': {'estimate': ['037', '038', '039'], 'universe': ['036']},
#   'i45u20_p': {'estimate': ['040', '041', '042', '043'], 'universe': ['036']},
#   'i452039_p': {'estimate': ['044', '045', '046'], 'universe': ['036']},
#   'i454059_p': {'estimate': ['047'], 'universe': ['036']},
#   'i456074_p': {'estimate': ['048'], 'universe': ['036']},
#   'i457599_p': {'estimate': ['049', '050', '051', '052'], 'universe': ['036']},
#   'i45100o_p': {'estimate': ['053'], 'universe': ['001']},
#   'i65_64_p': {'estimate': ['054', '055', '056'], 'universe': ['053']},
#   'i65u20_p': {'estimate': ['057', '058', '059', '060'], 'universe': ['053']},
#   'i652039_p': {'estimate': ['061', '062', '063'], 'universe': ['053']},
#   'i654059_p': {'estimate': ['064'], 'universe': ['053']},
#   'i656074_p': {'estimate': ['065'], 'universe': ['053']},
#   'i657599_p': {'estimate': ['066', '067', '068', '069'], 'universe': ['053']},
#   'i65100o_p': {'estimate': [], 'universe': []}},
#  'b19058_public_assist_acs_m': {'assist_p': {'estimate': ['003'],
#    'universe': ['001']},
#   'noasst_p': {'estimate': [], 'universe': []}},
#  'b19083_gini_index_acs_m': {},
#  'b19301_per_capita_income_acs_m': {},
#  'b22003_b22005_hh_foodstamps_snap_by_race_acs_m': {},
#  'b23006_educational_attainment_by_laborforce_acs_m': {'lths_p': {'estimate': ['003'],
#    'universe': ['002']},
#   'lthslf_p': {'estimate': ['006'], 'universe': ['005']},
#   'lhs_e_p': {'estimate': ['007'], 'universe': ['005']},
#   'lhs_ue_p': {'estimate': ['009'], 'universe': ['001']},
#   'hs_p': {'estimate': ['010'], 'universe': ['009']},
#   'hslf_p': {'estimate': ['013'], 'universe': ['012']},
#   'hs_e_p': {'estimate': ['014'], 'universe': ['012']},
#   'hs_ue_p': {'estimate': ['016'], 'universe': ['001']},
#   'sc_p': {'estimate': ['017'], 'universe': ['016']},
#   'sclf_p': {'estimate': ['020'], 'universe': ['019']},
#   'sc_e_p': {'estimate': ['021'], 'universe': ['019']},
#   'sc_ue_p': {'estimate': ['023'], 'universe': ['001']},
#   'bap_p': {'estimate': ['024'], 'universe': ['023']},
#   'baplf_p': {'estimate': ['027'], 'universe': ['026']},
#   'bap_e_p': {'estimate': ['028'], 'universe': ['026']},
#   'bap_ue_p': {'estimate': [], 'universe': []}},
#  'b23025_employment_acs_m': {'lf_p': {'estimate': ['003'],
#    'universe': ['001']},
#   'clf_p': {'estimate': ['004'], 'universe': ['003']},
#   'emp_p': {'estimate': ['005'], 'universe': ['003']},
#   'unemp_p': {'estimate': ['006'], 'universe': ['002']},
#   'aflf_p': {'estimate': ['007'], 'universe': ['001']},
#   'nlf_p': {'estimate': [], 'universe': []}},
#  'b25002_b25003_hu_occupancy_by_tenure_race_acs_m': {'occ_hu_p': {'estimate': ['25002003'],
#    'universe': ['25002001']},
#   'vac_hu_p': {'estimate': [], 'universe': []}},
#  'b25010_avg_hhsize_by_tenure_acs_m': {},
#  'b25024_hu_units_in_structure_acs_m': {'u1_p': {'estimate': ['002'],
#    'universe': ['001']},
#   'u1d_p': {'estimate': ['003'], 'universe': ['001']},
#   'u1a_p': {'estimate': ['004'], 'universe': ['001']},
#   'u2_p': {'estimate': ['004', '005', '006', '007', '008', '009'],
#    'universe': ['001']},
#   'u2ov_p': {'estimate': ['004', '005'], 'universe': ['001']},
#   'u2_4_p': {'estimate': ['005'], 'universe': ['001']},
#   'u3_4_p': {'estimate': ['006'], 'universe': ['001']},
#   'u5_9_p': {'estimate': ['007'], 'universe': ['001']},
#   'u10_19_p': {'estimate': ['008', '009'], 'universe': ['001']},
#   'u20ov_p': {'estimate': ['008'], 'universe': ['001']},
#   'u20_49_p': {'estimate': ['009'], 'universe': ['001']},
#   'u50ov_p': {'estimate': ['010', '011'], 'universe': ['001']},
#   'u_oth_p': {'estimate': [], 'universe': []}},
#  'b25032_hu_tenure_by_units_acs_m': {'sf_p': {'estimate': ['003', '014'],
#    'universe': ['001']},
#   'u1dp': {'estimate': ['004', '015'], 'universe': ['001']},
#   'u1ap': {'estimate': ['005',
#     '006',
#     '007',
#     '008',
#     '009',
#     '010',
#     '016',
#     '017',
#     '018',
#     '019',
#     '020',
#     '021'],
#    'universe': ['001']},
#   'mfp': {'estimate': ['005', '016'], 'universe': ['001']},
#   'u2p': {'estimate': ['005', '006', '016', '017'], 'universe': ['001']},
#   'u2_4p': {'estimate': ['006', '017'], 'universe': ['001']},
#   'u3_4p': {'estimate': ['007',
#     '008',
#     '009',
#     '010',
#     '018',
#     '019',
#     '020',
#     '021'],
#    'universe': ['001']},
#   'u5ovp': {'estimate': ['007', '018'], 'universe': ['001']},
#   'u5_9p': {'estimate': ['008', '009', '010', '019', '020', '021'],
#    'universe': ['001']},
#   'u10ovp': {'estimate': ['008', '019'], 'universe': ['001']},
#   'u10_19p': {'estimate': ['009', '010', '020', '021'], 'universe': ['001']},
#   'u20ovp': {'estimate': ['009', '020'], 'universe': ['001']},
#   'u20_49p': {'estimate': ['010', '021'], 'universe': ['001']},
#   'u50ovp': {'estimate': ['011', '022'], 'universe': ['001']},
#   'moblp': {'estimate': ['012', '023'], 'universe': ['001']},
#   'othp': {'estimate': ['002'], 'universe': ['001']},
#   'o_hhp': {'estimate': ['003', '004'], 'universe': ['002']},
#   'o_sfp': {'estimate': ['003'], 'universe': ['002']},
#   'o_u1dp': {'estimate': ['004'], 'universe': ['002']},
#   'o_u1ap': {'estimate': ['005', '006', '007', '008', '009', '010'],
#    'universe': ['002']},
#   'o_mfp': {'estimate': ['005'], 'universe': ['002']},
#   'o_u2p': {'estimate': ['005', '006'], 'universe': ['002']},
#   'o_u2_4p': {'estimate': ['006'], 'universe': ['002']},
#   'o_u3_4p': {'estimate': ['007', '008', '009', '010'], 'universe': ['002']},
#   'o_u5ovp': {'estimate': ['007'], 'universe': ['002']},
#   'o_u5_9p': {'estimate': ['008', '009', '010'], 'universe': ['002']},
#   'o_u10ovp': {'estimate': ['008'], 'universe': ['002']},
#   'o_u10_19p': {'estimate': ['009', '010'], 'universe': ['002']},
#   'o_u20ovp': {'estimate': ['009'], 'universe': ['002']},
#   'o_u20_49p': {'estimate': ['010'], 'universe': ['002']},
#   'o_u50ovp': {'estimate': ['011'], 'universe': ['002']},
#   'o_moblp': {'estimate': ['012'], 'universe': ['002']},
#   'o_othp': {'estimate': ['013'], 'universe': ['001']},
#   'r_hhp': {'estimate': ['014', '015'], 'universe': ['013']},
#   'r_sf_p': {'estimate': ['014'], 'universe': ['013']},
#   'r_u1dp': {'estimate': ['015'], 'universe': ['013']},
#   'r_u1ap': {'estimate': ['016', '017', '018', '019', '020', '021'],
#    'universe': ['013']},
#   'r_mf_p': {'estimate': ['016'], 'universe': ['013']},
#   'r_u2p': {'estimate': ['016', '017'], 'universe': ['013']},
#   'r_u2_4p': {'estimate': ['017'], 'universe': ['013']},
#   'r_u3_4p': {'estimate': ['018', '019', '020', '021'], 'universe': ['013']},
#   'r_u5ovp': {'estimate': ['018'], 'universe': ['013']},
#   'r_u5_9p': {'estimate': ['019', '020', '021'], 'universe': ['013']},
#   'r_u10ovp': {'estimate': ['019'], 'universe': ['013']},
#   'r_u10_19p': {'estimate': ['020', '021'], 'universe': ['013']},
#   'r_u20ovp': {'estimate': ['020'], 'universe': ['013']},
#   'r_u20_49p': {'estimate': ['021'], 'universe': ['013']},
#   'r_u50ovp': {'estimate': ['022'], 'universe': ['013']},
#   'r_moblp': {'estimate': ['023'], 'universe': ['013']},
#   'r_othp': {'estimate': [], 'universe': []}},
#  'b25056_b25058_contract_rent_acs_m': {},
#  'b25063_b25064_b25065_rent_acs_m': {},
#  'b25072_b25093_costburden_by_age_acs_m': {'ncb1524mep': {'estimate': ['006',
#     '007',
#     '006',
#     '007'],
#    'universe': ['003',
#     '004',
#     '005',
#     '006',
#     '007',
#     '003',
#     '004',
#     '005',
#     '006',
#     '007']},
#   'cb1524p': {'estimate': ['010', '011', '012', '010', '011', '012'],
#    'universe': ['010',
#     '011',
#     '012',
#     '013',
#     '014',
#     '010',
#     '011',
#     '012',
#     '013',
#     '014']},
#   'ncb2534p': {'estimate': ['013', '014', '013', '014'],
#    'universe': ['010',
#     '011',
#     '012',
#     '013',
#     '014',
#     '010',
#     '011',
#     '012',
#     '013',
#     '014']},
#   'cb2534p': {'estimate': ['017', '018', '019', '017', '018', '019'],
#    'universe': ['017',
#     '018',
#     '019',
#     '020',
#     '021',
#     '017',
#     '018',
#     '019',
#     '020',
#     '021']},
#   'ncb3564p': {'estimate': ['020', '021', '020', '021'],
#    'universe': ['017',
#     '018',
#     '019',
#     '020',
#     '021',
#     '017',
#     '018',
#     '019',
#     '020',
#     '021']},
#   'cb3564p': {'estimate': ['024', '025', '026', '024', '025', '026'],
#    'universe': ['024',
#     '025',
#     '026',
#     '027',
#     '028',
#     '024',
#     '025',
#     '026',
#     '027',
#     '028']},
#   'ncb65_p': {'estimate': ['027', '028', '027', '028'],
#    'universe': ['024',
#     '025',
#     '026',
#     '027',
#     '028',
#     '024',
#     '025',
#     '026',
#     '027',
#     '028']},
#   'cb65_p': {'estimate': ['003', '004', '005', '006', '007'],
#    'universe': ['003',
#     '004',
#     '005',
#     '006',
#     '007',
#     '010',
#     '011',
#     '012',
#     '013',
#     '014',
#     '017',
#     '018',
#     '019',
#     '020',
#     '021',
#     '024',
#     '025',
#     '026',
#     '027',
#     '028']},
#   'o1524_p': {'estimate': ['003', '004', '005'],
#    'universe': ['003', '004', '005', '006', '007']},
#   'o1524ncbp': {'estimate': ['006', '007'],
#    'universe': ['003', '004', '005', '006', '007']},
#   'o1524cbp': {'estimate': ['010', '011', '012', '013', '014'],
#    'universe': ['003',
#     '004',
#     '005',
#     '006',
#     '007',
#     '010',
#     '011',
#     '012',
#     '013',
#     '014',
#     '017',
#     '018',
#     '019',
#     '020',
#     '021',
#     '024',
#     '025',
#     '026',
#     '027',
#     '028']},
#   'o2534_p': {'estimate': ['010', '011', '012'],
#    'universe': ['010', '011', '012', '013', '014']},
#   'o2534ncbp': {'estimate': ['013', '014'],
#    'universe': ['010', '011', '012', '013', '014']},
#   'o2534cbp': {'estimate': ['017', '018', '019', '020', '021'],
#    'universe': ['003',
#     '004',
#     '005',
#     '006',
#     '007',
#     '010',
#     '011',
#     '012',
#     '013',
#     '014',
#     '017',
#     '018',
#     '019',
#     '020',
#     '021',
#     '024',
#     '025',
#     '026',
#     '027',
#     '028']},
#   'o3564_p': {'estimate': ['017', '018', '019'],
#    'universe': ['017', '018', '019', '020', '021']},
#   'o3564ncbp': {'estimate': ['020', '021'],
#    'universe': ['017', '018', '019', '020', '021']},
#   'o3564cbp': {'estimate': ['024', '025', '026', '027', '028'],
#    'universe': ['003',
#     '004',
#     '005',
#     '006',
#     '007',
#     '010',
#     '011',
#     '012',
#     '013',
#     '014',
#     '017',
#     '018',
#     '019',
#     '020',
#     '021',
#     '024',
#     '025',
#     '026',
#     '027',
#     '028']},
#   'o65ovr_p': {'estimate': ['024', '025', '026'],
#    'universe': ['024', '025', '026', '027', '028']},
#   'o65p_ncbp': {'estimate': ['027', '028'],
#    'universe': ['024', '025', '026', '027', '028']},
#   'o65p_cbp': {'estimate': ['003', '004', '005', '006', '007'],
#    'universe': ['003',
#     '004',
#     '005',
#     '006',
#     '007',
#     '010',
#     '011',
#     '012',
#     '013',
#     '014',
#     '017',
#     '018',
#     '019',
#     '020',
#     '021',
#     '024',
#     '025',
#     '026',
#     '027',
#     '028']},
#   'r1524_p': {'estimate': ['003', '004', '005'],
#    'universe': ['003', '004', '005', '006', '007']},
#   'r1524ncbp': {'estimate': ['006', '007'],
#    'universe': ['003', '004', '005', '006', '007']},
#   'r1524cbp': {'estimate': ['010', '011', '012', '013', '014'],
#    'universe': ['003',
#     '004',
#     '005',
#     '006',
#     '007',
#     '010',
#     '011',
#     '012',
#     '013',
#     '014',
#     '017',
#     '018',
#     '019',
#     '020',
#     '021',
#     '024',
#     '025',
#     '026',
#     '027',
#     '028']},
#   'r2534_p': {'estimate': ['010', '011', '012'],
#    'universe': ['010', '011', '012', '013', '014']},
#   'r2534ncbp': {'estimate': ['013', '014'],
#    'universe': ['010', '011', '012', '013', '014']},
#   'r2534cbp': {'estimate': ['017', '018', '019', '020', '021'],
#    'universe': ['003',
#     '004',
#     '005',
#     '006',
#     '007',
#     '010',
#     '011',
#     '012',
#     '013',
#     '014',
#     '017',
#     '018',
#     '019',
#     '020',
#     '021',
#     '024',
#     '025',
#     '026',
#     '027',
#     '028']},
#   'r3564_p': {'estimate': ['017', '018', '019'],
#    'universe': ['017', '018', '019', '020', '021']},
#   'r3564ncbp': {'estimate': ['020', '021'],
#    'universe': ['017', '018', '019', '020', '021']},
#   'r3564cbp': {'estimate': ['024', '025', '026', '027', '028'],
#    'universe': ['003',
# ...
#   'na4475_p': {'estimate': ['031'], 'universe': ['019']},
#   'na4499_p': {'estimate': ['032', '033', '034', '035'], 'universe': ['019']},
#   'na44100_p': {'estimate': ['036'], 'universe': ['001']},
#   'na45_64_p': {'estimate': ['037', '038', '039'], 'universe': ['036']},
#   'na6420_p': {'estimate': ['040', '041', '042', '043'], 'universe': ['036']},
#   'na6440_p': {'estimate': ['044', '045', '046'], 'universe': ['036']},
#   'na6460_p': {'estimate': ['047'], 'universe': ['036']},
#   'na6475_p': {'estimate': ['048'], 'universe': ['036']},
#   'na6499_p': {'estimate': ['049', '050', '051', '052'], 'universe': ['036']},
#   'na64100_p': {'estimate': ['053'], 'universe': ['001']},
#   'na65o_p': {'estimate': ['054', '055', '056'], 'universe': ['053']},
#   'na6520_p': {'estimate': ['057', '058', '059', '060'], 'universe': ['053']},
#   'na6540_p': {'estimate': ['061', '062', '063'], 'universe': ['053']},
#   'na6560_p': {'estimate': ['064'], 'universe': ['053']},
#   'na6575_p': {'estimate': ['065'], 'universe': ['053']},
#   'na6599_p': {'estimate': ['066', '067', '068', '069'], 'universe': ['053']},
#   'na65100_p': {'estimate': ['002'], 'universe': ['001']},
#   'pi24_p': {'estimate': ['003', '004', '005'], 'universe': ['002']},
#   'pi2420_p': {'estimate': ['006', '007', '008', '009'], 'universe': ['002']},
#   'pi2440_p': {'estimate': ['010', '011', '012'], 'universe': ['002']},
#   'pi2460_p': {'estimate': ['013'], 'universe': ['002']},
#   'pi2475_p': {'estimate': ['014'], 'universe': ['002']},
#   'pi2499_p': {'estimate': ['015', '016', '017', '018'], 'universe': ['002']},
#   'pi24100_p': {'estimate': ['019'], 'universe': ['001']},
#   'pi25_44_p': {'estimate': ['020', '021', '022'], 'universe': ['019']},
#   'pi4420_p': {'estimate': ['023', '024', '025', '026'], 'universe': ['019']},
#   'pi4440_p': {'estimate': ['027', '028', '029'], 'universe': ['019']},
#   'pi4460_p': {'estimate': ['030'], 'universe': ['019']},
#   'pi4475_p': {'estimate': ['031'], 'universe': ['019']},
#   'pi4499_p': {'estimate': ['032', '033', '034', '035'], 'universe': ['019']},
#   'pi44100_p': {'estimate': ['036'], 'universe': ['001']},
#   'pi45_64_p': {'estimate': ['037', '038', '039'], 'universe': ['036']},
#   'pi6420_p': {'estimate': ['040', '041', '042', '043'], 'universe': ['036']},
#   'pi6440_p': {'estimate': ['044', '045', '046'], 'universe': ['036']},
#   'pi6460_p': {'estimate': ['047'], 'universe': ['036']},
#   'pi6475_p': {'estimate': ['048'], 'universe': ['036']},
#   'pi6499_p': {'estimate': ['049', '050', '051', '052'], 'universe': ['036']},
#   'pi64100_p': {'estimate': ['053'], 'universe': ['001']},
#   'pi65o_p': {'estimate': ['054', '055', '056'], 'universe': ['053']},
#   'pi6520_p': {'estimate': ['057', '058', '059', '060'], 'universe': ['053']},
#   'pi6540_p': {'estimate': ['061', '062', '063'], 'universe': ['053']},
#   'pi6560_p': {'estimate': ['064'], 'universe': ['053']},
#   'pi6575_p': {'estimate': ['065'], 'universe': ['053']},
#   'pi6599_p': {'estimate': ['066', '067', '068', '069'], 'universe': ['053']},
#   'pi65100_p': {'estimate': ['002'], 'universe': ['001']},
#   'oth24_p': {'estimate': ['003', '004', '005'], 'universe': ['002']},
#   'oth2420_p': {'estimate': ['006', '007', '008', '009'], 'universe': ['002']},
#   'oth2440_p': {'estimate': ['010', '011', '012'], 'universe': ['002']},
#   'oth2460_p': {'estimate': ['013'], 'universe': ['002']},
#   'oth2475_p': {'estimate': ['014'], 'universe': ['002']},
#   'oth2499_p': {'estimate': ['015', '016', '017', '018'], 'universe': ['002']},
#   'oth24100_p': {'estimate': ['019'], 'universe': ['001']},
#   'oth25_44_p': {'estimate': ['020', '021', '022'], 'universe': ['019']},
#   'oth4420_p': {'estimate': ['023', '024', '025', '026'], 'universe': ['019']},
#   'oth4440_p': {'estimate': ['027', '028', '029'], 'universe': ['019']},
#   'oth4460_p': {'estimate': ['030'], 'universe': ['019']},
#   'oth4475_p': {'estimate': ['031'], 'universe': ['019']},
#   'oth4499_p': {'estimate': ['032', '033', '034', '035'], 'universe': ['019']},
#   'oth44100_p': {'estimate': ['036'], 'universe': ['001']},
#   'oth45_64_p': {'estimate': ['037', '038', '039'], 'universe': ['036']},
#   'oth6420_p': {'estimate': ['040', '041', '042', '043'], 'universe': ['036']},
#   'oth6440_p': {'estimate': ['044', '045', '046'], 'universe': ['036']},
#   'oth6460_p': {'estimate': ['047'], 'universe': ['036']},
#   'oth6475_p': {'estimate': ['048'], 'universe': ['036']},
#   'oth6499_p': {'estimate': ['049', '050', '051', '052'], 'universe': ['036']},
#   'oth64100_p': {'estimate': ['053'], 'universe': ['001']},
#   'oth65o_p': {'estimate': ['054', '055', '056'], 'universe': ['053']},
#   'oth6520_p': {'estimate': ['057', '058', '059', '060'], 'universe': ['053']},
#   'oth6540_p': {'estimate': ['061', '062', '063'], 'universe': ['053']},
#   'oth6560_p': {'estimate': ['064'], 'universe': ['053']},
#   'oth6575_p': {'estimate': ['065'], 'universe': ['053']},
#   'oth6599_p': {'estimate': ['066', '067', '068', '069'], 'universe': ['053']},
#   'oth65100_p': {'estimate': ['002'], 'universe': ['001']},
#   'mlt24_p': {'estimate': ['003', '004', '005'], 'universe': ['002']},
#   'mlt2420_p': {'estimate': ['006', '007', '008', '009'], 'universe': ['002']},
#   'mlt2440_p': {'estimate': ['010', '011', '012'], 'universe': ['002']},
#   'mlt2460_p': {'estimate': ['013'], 'universe': ['002']},
#   'mlt2475_p': {'estimate': ['014'], 'universe': ['002']},
#   'mlt2499_p': {'estimate': ['015', '016', '017', '018'], 'universe': ['002']},
#   'mlt24100_p': {'estimate': ['019'], 'universe': ['001']},
#   'mlt25_44_p': {'estimate': ['020', '021', '022'], 'universe': ['019']},
#   'mlt4420_p': {'estimate': ['023', '024', '025', '026'], 'universe': ['019']},
#   'mlt4440_p': {'estimate': ['027', '028', '029'], 'universe': ['019']},
#   'mlt4460_p': {'estimate': ['030'], 'universe': ['019']},
#   'mlt4475_p': {'estimate': ['031'], 'universe': ['019']},
#   'mlt4499_p': {'estimate': ['032', '033', '034', '035'], 'universe': ['019']},
#   'mlt44100_p': {'estimate': ['036'], 'universe': ['001']},
#   'mlt45_64_p': {'estimate': ['037', '038', '039'], 'universe': ['036']},
#   'mlt6420_p': {'estimate': ['040', '041', '042', '043'], 'universe': ['036']},
#   'mlt6440_p': {'estimate': ['044', '045', '046'], 'universe': ['036']},
#   'mlt6460_p': {'estimate': ['047'], 'universe': ['036']},
#   'mlt6475_p': {'estimate': ['048'], 'universe': ['036']},
#   'mlt6499_p': {'estimate': ['049', '050', '051', '052'], 'universe': ['036']},
#   'mlt64100_p': {'estimate': ['053'], 'universe': ['001']},
#   'mlt65o_p': {'estimate': ['054', '055', '056'], 'universe': ['053']},
#   'mlt6520_p': {'estimate': ['057', '058', '059', '060'], 'universe': ['053']},
#   'mlt6540_p': {'estimate': ['061', '062', '063'], 'universe': ['053']},
#   'mlt6560_p': {'estimate': ['064'], 'universe': ['053']},
#   'mlt6575_p': {'estimate': ['065'], 'universe': ['053']},
#   'mlt6599_p': {'estimate': ['066', '067', '068', '069'], 'universe': ['053']},
#   'mlt65100_p': {'estimate': ['002'], 'universe': ['001']},
#   'nhw24_p': {'estimate': ['003', '004', '005'], 'universe': ['002']},
#   'nhw2420_p': {'estimate': ['006', '007', '008', '009'], 'universe': ['002']},
#   'nhw2440_p': {'estimate': ['010', '011', '012'], 'universe': ['002']},
#   'nhw2460_p': {'estimate': ['013'], 'universe': ['002']},
#   'nhw2475_p': {'estimate': ['014'], 'universe': ['002']},
#   'nhw2499_p': {'estimate': ['015', '016', '017', '018'], 'universe': ['002']},
#   'nhw24100_p': {'estimate': ['019'], 'universe': ['001']},
#   'nhw25_44_p': {'estimate': ['020', '021', '022'], 'universe': ['019']},
#   'nhw4420_p': {'estimate': ['023', '024', '025', '026'], 'universe': ['019']},
#   'nhw4440_p': {'estimate': ['027', '028', '029'], 'universe': ['019']},
#   'nhw4460_p': {'estimate': ['030'], 'universe': ['019']},
#   'nhw4475_p': {'estimate': ['031'], 'universe': ['019']},
#   'nhw4499_p': {'estimate': ['032', '033', '034', '035'], 'universe': ['019']},
#   'nhw44100_p': {'estimate': ['036'], 'universe': ['001']},
#   'nhw45_64_p': {'estimate': ['037', '038', '039'], 'universe': ['036']},
#   'nhw6420_p': {'estimate': ['040', '041', '042', '043'], 'universe': ['036']},
#   'nhw6440_p': {'estimate': ['044', '045', '046'], 'universe': ['036']},
#   'nhw6460_p': {'estimate': ['047'], 'universe': ['036']},
#   'nhw6475_p': {'estimate': ['048'], 'universe': ['036']},
#   'nhw6499_p': {'estimate': ['049', '050', '051', '052'], 'universe': ['036']},
#   'nhw64100_p': {'estimate': ['053'], 'universe': ['001']},
#   'nhw65o_p': {'estimate': ['054', '055', '056'], 'universe': ['053']},
#   'nhw6520_p': {'estimate': ['057', '058', '059', '060'], 'universe': ['053']},
#   'nhw6540_p': {'estimate': ['061', '062', '063'], 'universe': ['053']},
#   'nhw6560_p': {'estimate': ['064'], 'universe': ['053']},
#   'nhw6575_p': {'estimate': ['065'], 'universe': ['053']},
#   'nhw6599_p': {'estimate': ['066', '067', '068', '069'], 'universe': ['053']},
#   'nhw65100_p': {'estimate': ['002'], 'universe': ['001']},
#   'lat24_p': {'estimate': ['003', '004', '005'], 'universe': ['002']},
#   'lat2420_p': {'estimate': ['006', '007', '008', '009'], 'universe': ['002']},
#   'lat2440_p': {'estimate': ['010', '011', '012'], 'universe': ['002']},
#   'lat2460_p': {'estimate': ['013'], 'universe': ['002']},
#   'lat2475_p': {'estimate': ['014'], 'universe': ['002']},
#   'lat2499_p': {'estimate': ['015', '016', '017', '018'], 'universe': ['002']},
#   'lat24100_p': {'estimate': ['019'], 'universe': ['001']},
#   'lat25_44_p': {'estimate': ['020', '021', '022'], 'universe': ['019']},
#   'lat4420_p': {'estimate': ['023', '024', '025', '026'], 'universe': ['019']},
#   'lat4440_p': {'estimate': ['027', '028', '029'], 'universe': ['019']},
#   'lat4460_p': {'estimate': ['030'], 'universe': ['019']},
#   'lat4475_p': {'estimate': ['031'], 'universe': ['019']},
#   'lat4499_p': {'estimate': ['032', '033', '034', '035'], 'universe': ['019']},
#   'lat44100_p': {'estimate': ['036'], 'universe': ['001']},
#   'lat45_64_p': {'estimate': ['037', '038', '039'], 'universe': ['036']},
#   'lat6420_p': {'estimate': ['040', '041', '042', '043'], 'universe': ['036']},
#   'lat6440_p': {'estimate': ['044', '045', '046'], 'universe': ['036']},
#   'lat6460_p': {'estimate': ['047'], 'universe': ['036']},
#   'lat6475_p': {'estimate': ['048'], 'universe': ['036']},
#   'lat6499_p': {'estimate': ['049', '050', '051', '052'], 'universe': ['036']},
#   'lat64100_p': {'estimate': ['053'], 'universe': ['001']},
#   'lat65o_p': {'estimate': ['054', '055', '056'], 'universe': ['053']},
#   'lat6520_p': {'estimate': ['057', '058', '059', '060'], 'universe': ['053']},
#   'lat6540_p': {'estimate': ['061', '062', '063'], 'universe': ['053']},
#   'lat6560_p': {'estimate': ['064'], 'universe': ['053']},
#   'lat6575_p': {'estimate': ['065'], 'universe': ['053']},
#   'lat6599_p': {'estimate': ['066', '067', '068', '069'], 'universe': ['053']},
#   'lat65100_p': {'estimate': [], 'universe': []}},
#  'b22001_hh_foodstamps_snap_60yrs_acs_m': {'snap_p': {'estimate': ['003'],
#    'universe': ['001']},
#   'snap60p': {'estimate': ['004'], 'universe': ['001']},
#   'snapno60p': {'estimate': ['005'], 'universe': ['001']},
#   'nsnp_p': {'estimate': ['006'], 'universe': ['001']},
#   'nsnp60p': {'estimate': ['007'], 'universe': ['001']},
#   'nsnpno60p': {'estimate': [], 'universe': []}},
#  'b22002_hh_foodstamps_snap_hhtype_kids_acs_m': {'snap_p': {'estimate': ['003'],
#    'universe': ['001']},
#   'snapkp': {'estimate': ['004'], 'universe': ['001']},
#   'snapkmcp': {'estimate': ['005'], 'universe': ['001']},
#   'snapkofp': {'estimate': ['006'], 'universe': ['001']},
#   'snapkmhp': {'estimate': ['007'], 'universe': ['001']},
#   'snapkfhp': {'estimate': ['008'], 'universe': ['001']},
#   'snapknfp': {'estimate': ['009'], 'universe': ['001']},
#   'snapnkp': {'estimate': ['010'], 'universe': ['001']},
#   'snapnkmcp': {'estimate': ['011'], 'universe': ['001']},
#   'snapnkofp': {'estimate': ['012'], 'universe': ['001']},
#   'snapnkmhp': {'estimate': ['013'], 'universe': ['001']},
#   'snapnkfhp': {'estimate': ['014'], 'universe': ['001']},
#   'snapnknfp': {'estimate': ['015'], 'universe': ['001']},
#   'nsnp_p': {'estimate': ['016'], 'universe': ['001']},
#   'nsnpkp': {'estimate': ['017'], 'universe': ['001']},
#   'nsnpkmcp': {'estimate': ['018'], 'universe': ['001']},
#   'nsnpkofp': {'estimate': ['019'], 'universe': ['001']},
#   'nsnpkmhp': {'estimate': ['020'], 'universe': ['001']},
#   'nsnpkfhp': {'estimate': ['021'], 'universe': ['001']},
#   'nsnpknfp': {'estimate': ['022'], 'universe': ['001']},
#   'nsnpnkp': {'estimate': ['023'], 'universe': ['001']},
#   'nsnpnkmcp': {'estimate': ['024'], 'universe': ['001']},
#   'nsnpnkofp': {'estimate': ['025'], 'universe': ['001']},
#   'nsnpnkmhp': {'estimate': ['026'], 'universe': ['001']},
#   'nsnpnkfhp': {'estimate': ['027'], 'universe': ['001']},
#   'nsnpnknfp': {'estimate': [], 'universe': []}},
#  'b22008_mhi_foodstamps_snap_acs_m': {},
#  'b25065_b25066_aggregate_rent_by_units_acs_m': {},
#  'c18120_emp_status_by_disability_status_acs_m': {'dis_p': {'estimate': ['005',
#     '008',
#     '011'],
#    'universe': ['001']},
#   'ndis_p': {'estimate': ['004', '007'], 'universe': ['004', '007', '010']},
#   'dislf_p': {'estimate': ['010'], 'universe': ['004', '007', '010']},
#   'disnlf_p': {'estimate': ['005', '008'], 'universe': ['005', '008', '011']},
#   'ndlf_p': {'estimate': ['011'], 'universe': ['005', '008', '011']},
#   'ndnlf_p': {'estimate': ['002'], 'universe': ['001']},
#   'lfp': {'estimate': ['004', '007'], 'universe': ['002']},
#   'lfdis_p': {'estimate': ['005', '008'], 'universe': ['002']},
#   'lfnd_p': {'estimate': ['003'], 'universe': ['002']},
#   'emp_p': {'estimate': ['004'], 'universe': ['003']},
#   'empdis_p': {'estimate': ['005'], 'universe': ['003']},
#   'empnd_p': {'estimate': ['006'], 'universe': ['002']},
#   'uemp_p': {'estimate': ['007'], 'universe': ['006']},
#   'uempdis_p': {'estimate': ['008'], 'universe': ['006']},
#   'uempnd_p': {'estimate': ['004'], 'universe': ['004', '007']},
#   'disemp_p': {'estimate': ['005'], 'universe': ['005', '008']},
#   'ndemp_p': {'estimate': ['007'], 'universe': ['004', '007']},
#   'disuemp_p': {'estimate': ['008'], 'universe': ['005', '008']},
#   'nduemp_p': {'estimate': ['009'], 'universe': ['001']},
#   'nlfp': {'estimate': ['010'], 'universe': ['009']},
#   'nlfdis_p': {'estimate': ['011'], 'universe': ['009']},
#   'nlfnd_p': {'estimate': [], 'universe': []}},
#  'c18130_poverty_status_by_disability_status_acs_m': {'disp': {'estimate': ['006',
#     '013',
#     '020'],
#    'universe': ['001']},
#   'ndp': {'estimate': ['004', '011', '018'],
#    'universe': ['003', '010', '017']},
#   'dispovp': {'estimate': ['007', '014', '021'],
#    'universe': ['006', '013', '020']},
#   'ndpovp': {'estimate': ['005', '012', '019'],
#    'universe': ['003', '010', '017']},
#   'disnpovp': {'estimate': ['008', '015', '022'],
#    'universe': ['006', '013', '020']},
#   'ndnpovp': {'estimate': ['002'], 'universe': ['001']},
#   'cnpopu18p': {'estimate': ['003'], 'universe': ['002']},
#   'du18p': {'estimate': ['004'], 'universe': ['003']},
#   'du18pvp': {'estimate': ['005'], 'universe': ['003']},
#   'du18npvp': {'estimate': ['006'], 'universe': ['002']},
#   'ndu18p': {'estimate': ['007'], 'universe': ['006']},
#   'ndu18pvp': {'estimate': ['008'], 'universe': ['006']},
#   'ndu18npvp': {'estimate': ['009'], 'universe': ['001']},
#   'cnp1864p': {'estimate': ['010'], 'universe': ['009']},
#   'd1864p': {'estimate': ['011'], 'universe': ['010']},
#   'd1864pvp': {'estimate': ['012'], 'universe': ['010']},
#   'd1864npvp': {'estimate': ['013'], 'universe': ['009']},
#   'nd1864p': {'estimate': ['014'], 'universe': ['013']},
#   'nd1864pvp': {'estimate': ['015'], 'universe': ['013']},
#   'nd1864npvp': {'estimate': ['016'], 'universe': ['001']},
#   'cnpop65op': {'estimate': ['017'], 'universe': ['016']},
#   'd65op': {'estimate': ['018'], 'universe': ['017']},
#   'd65opvp': {'estimate': ['019'], 'universe': ['017']},
#   'd65onpvp': {'estimate': ['020'], 'universe': ['016']},
#   'nd65op': {'estimate': ['021'], 'universe': ['020']},
#   'nd65opvp': {'estimate': ['022'], 'universe': ['020']},
#   'nd65onpvp': {'estimate': [], 'universe': []}}}

# %%
#pickle.dump(ids_dict, open('table_to_censusid.p', 'wb'))

# %%
#col_names_dict['b01001_population_by_age_gender_acs_m']
#pickle.dump(col_names_dict, open('cols_ids_dict.p', 'wb'))

# %%
table_ids = pd.DataFrame.from_dict(ids_dict, orient='index')

# %%
table_ids.dropna(how='all')
table_ids.sort_index()
# Out:
#                                                                                                 0    \
# b01001_population_by_age_gender_acs_m                [001, SEX BY AGE for Total Population  Total:]
# b01001a_whi_population_by_age_gender_acs_m        [001, SEX BY AGE (WHITE ALONE) for People Who ...
# b01001b_aa_population_by_age_gender_acs_m         [001, SEX BY AGE (BLACK OR AFRICAN AMERICAN AL...
# b01001c_na_population_by_age_gender_acs_m         [001, SEX BY AGE (AMERICAN INDIAN AND ALASKA N...
# b01001d_as_population_by_age_gender_acs_m         [001, SEX BY AGE (ASIAN ALONE) for People Who ...
# ...                                                                                             ...
# b25127_hu_tenure_year_built_units_acs_m                               [001, Occupied housing units]
# b27001_healthinsurance_by_gender_age_acs_m                                            [001, Total:]
# c15002_educational_attainment_by_race_acs_m         [001, White alone population 25 years and over]
# c18120_emp_status_by_disability_status_acs_m      [001, EMPLOYMENT STATUS BY DISABILITY STATUS f...
# c18130_poverty_status_by_disability_status_acs_m  [001, AGE BY DISABILITY STATUS BY POVERTY STAT...
#
#                                                                                                 1    \
# b01001_population_by_age_gender_acs_m                 [002, SEX BY AGE for Total Population  Male:]
# b01001a_whi_population_by_age_gender_acs_m        [002, SEX BY AGE (WHITE ALONE) for People Who ...
# b01001b_aa_population_by_age_gender_acs_m         [002, SEX BY AGE (BLACK OR AFRICAN AMERICAN AL...
# b01001c_na_population_by_age_gender_acs_m         [002, SEX BY AGE (AMERICAN INDIAN AND ALASKA N...
# b01001d_as_population_by_age_gender_acs_m         [002, SEX BY AGE (ASIAN ALONE) for People Who ...
# ...                                                                                             ...
# b25127_hu_tenure_year_built_units_acs_m               [002, Occupied housing units Owner occupied:]
# b27001_healthinsurance_by_gender_age_acs_m                                     [002, Total:  Male:]
# c15002_educational_attainment_by_race_acs_m       [002, White alone population 25 years and over...
# c18120_emp_status_by_disability_status_acs_m      [002, EMPLOYMENT STATUS BY DISABILITY STATUS f...
# c18130_poverty_status_by_disability_status_acs_m  [002, AGE BY DISABILITY STATUS BY POVERTY STAT...
#
#                                                                                                 2    \
# b01001_population_by_age_gender_acs_m             [003, SEX BY AGE for Total Population  Male:  ...
# b01001a_whi_population_by_age_gender_acs_m        [003, SEX BY AGE (WHITE ALONE) for People Who ...
# b01001b_aa_population_by_age_gender_acs_m         [003, SEX BY AGE (BLACK OR AFRICAN AMERICAN AL...
# b01001c_na_population_by_age_gender_acs_m         [003, SEX BY AGE (AMERICAN INDIAN AND ALASKA N...
# b01001d_as_population_by_age_gender_acs_m         [003, SEX BY AGE (ASIAN ALONE) for People Who ...
# ...                                                                                             ...
# b25127_hu_tenure_year_built_units_acs_m           [003, Occupied housing units Owner occupied: B...
# b27001_healthinsurance_by_gender_age_acs_m                     [003, Total:  Male:  Under 6 years:]
# c15002_educational_attainment_by_race_acs_m       [003, White alone population 25 years and over...
# c18120_emp_status_by_disability_status_acs_m      [003, EMPLOYMENT STATUS BY DISABILITY STATUS f...
# c18130_poverty_status_by_disability_status_acs_m  [003, AGE BY DISABILITY STATUS BY POVERTY STAT...
#
#                                                                                                 3    \
# b01001_population_by_age_gender_acs_m             [004, SEX BY AGE for Total Population  Male:  ...
# b01001a_whi_population_by_age_gender_acs_m        [004, SEX BY AGE (WHITE ALONE) for People Who ...
# b01001b_aa_population_by_age_gender_acs_m         [004, SEX BY AGE (BLACK OR AFRICAN AMERICAN AL...
# b01001c_na_population_by_age_gender_acs_m         [004, SEX BY AGE (AMERICAN INDIAN AND ALASKA N...
# b01001d_as_population_by_age_gender_acs_m         [004, SEX BY AGE (ASIAN ALONE) for People Who ...
# ...                                                                                             ...
# b25127_hu_tenure_year_built_units_acs_m           [004, Occupied housing units Owner occupied: B...
# b27001_healthinsurance_by_gender_age_acs_m        [004, Total:  Male:  Under 6 years:  With heal...
# c15002_educational_attainment_by_race_acs_m       [004, White alone population 25 years and over...
# c18120_emp_status_by_disability_status_acs_m      [004, EMPLOYMENT STATUS BY DISABILITY STATUS f...
# c18130_poverty_status_by_disability_status_acs_m  [004, AGE BY DISABILITY STATUS BY POVERTY STAT...
#
#                                                                                                 4    \
# b01001_population_by_age_gender_acs_m             [005, SEX BY AGE for Total Population  Male:  ...
# b01001a_whi_population_by_age_gender_acs_m        [005, SEX BY AGE (WHITE ALONE) for People Who ...
# b01001b_aa_population_by_age_gender_acs_m         [005, SEX BY AGE (BLACK OR AFRICAN AMERICAN AL...
# b01001c_na_population_by_age_gender_acs_m         [005, SEX BY AGE (AMERICAN INDIAN AND ALASKA N...
# b01001d_as_population_by_age_gender_acs_m         [005, SEX BY AGE (ASIAN ALONE) for People Who ...
# ...                                                                                             ...
# b25127_hu_tenure_year_built_units_acs_m           [005, Occupied housing units Owner occupied: B...
# b27001_healthinsurance_by_gender_age_acs_m        [005, Total:  Male:  Under 6 years:  No health...
# c15002_educational_attainment_by_race_acs_m       [005, White alone population 25 years and over...
# c18120_emp_status_by_disability_status_acs_m      [005, EMPLOYMENT STATUS BY DISABILITY STATUS f...
# c18130_poverty_status_by_disability_status_acs_m  [005, AGE BY DISABILITY STATUS BY POVERTY STAT...
#
#                                                                                                 5    \
# b01001_population_by_age_gender_acs_m             [006, SEX BY AGE for Total Population  Male:  ...
# b01001a_whi_population_by_age_gender_acs_m        [006, SEX BY AGE (WHITE ALONE) for People Who ...
# b01001b_aa_population_by_age_gender_acs_m         [006, SEX BY AGE (BLACK OR AFRICAN AMERICAN AL...
# b01001c_na_population_by_age_gender_acs_m         [006, SEX BY AGE (AMERICAN INDIAN AND ALASKA N...
# b01001d_as_population_by_age_gender_acs_m         [006, SEX BY AGE (ASIAN ALONE) for People Who ...
# ...                                                                                             ...
# b25127_hu_tenure_year_built_units_acs_m           [006, Occupied housing units Owner occupied: B...
# b27001_healthinsurance_by_gender_age_acs_m                     [006, Total:  Male:  6 to 17 years:]
# c15002_educational_attainment_by_race_acs_m       [006, White alone population 25 years and over...
# c18120_emp_status_by_disability_status_acs_m      [006, EMPLOYMENT STATUS BY DISABILITY STATUS f...
# c18130_poverty_status_by_disability_status_acs_m  [006, AGE BY DISABILITY STATUS BY POVERTY STAT...
#
#                                                                                                 6    \
# b01001_population_by_age_gender_acs_m             [007, SEX BY AGE for Total Population  Male:  ...
# b01001a_whi_population_by_age_gender_acs_m        [007, SEX BY AGE (WHITE ALONE) for People Who ...
# b01001b_aa_population_by_age_gender_acs_m         [007, SEX BY AGE (BLACK OR AFRICAN AMERICAN AL...
# b01001c_na_population_by_age_gender_acs_m         [007, SEX BY AGE (AMERICAN INDIAN AND ALASKA N...
# b01001d_as_population_by_age_gender_acs_m         [007, SEX BY AGE (ASIAN ALONE) for People Who ...
# ...                                                                                             ...
# b25127_hu_tenure_year_built_units_acs_m           [007, Occupied housing units Owner occupied: B...
# b27001_healthinsurance_by_gender_age_acs_m        [007, Total:  Male:  6 to 17 years:  With heal...
# c15002_educational_attainment_by_race_acs_m       [007, White alone population 25 years and over...
# c18120_emp_status_by_disability_status_acs_m      [007, EMPLOYMENT STATUS BY DISABILITY STATUS f...
# c18130_poverty_status_by_disability_status_acs_m  [007, AGE BY DISABILITY STATUS BY POVERTY STAT...
#
#                                                                                                 7    \
# b01001_population_by_age_gender_acs_m             [008, SEX BY AGE for Total Population  Male:  ...
# b01001a_whi_population_by_age_gender_acs_m        [008, SEX BY AGE (WHITE ALONE) for People Who ...
# b01001b_aa_population_by_age_gender_acs_m         [008, SEX BY AGE (BLACK OR AFRICAN AMERICAN AL...
# b01001c_na_population_by_age_gender_acs_m         [008, SEX BY AGE (AMERICAN INDIAN AND ALASKA N...
# b01001d_as_population_by_age_gender_acs_m         [008, SEX BY AGE (ASIAN ALONE) for People Who ...
# ...                                                                                             ...
# b25127_hu_tenure_year_built_units_acs_m           [008, Occupied housing units Owner occupied: B...
# b27001_healthinsurance_by_gender_age_acs_m        [008, Total:  Male:  6 to 17 years:  No health...
# c15002_educational_attainment_by_race_acs_m       [008, White alone population 25 years and over...
# c18120_emp_status_by_disability_status_acs_m      [008, EMPLOYMENT STATUS BY DISABILITY STATUS f...
# c18130_poverty_status_by_disability_status_acs_m  [008, AGE BY DISABILITY STATUS BY POVERTY STAT...
#
#                                                                                                 8    \
# b01001_population_by_age_gender_acs_m             [009, SEX BY AGE for Total Population  Male:  ...
# b01001a_whi_population_by_age_gender_acs_m        [009, SEX BY AGE (WHITE ALONE) for People Who ...
# b01001b_aa_population_by_age_gender_acs_m         [009, SEX BY AGE (BLACK OR AFRICAN AMERICAN AL...
# b01001c_na_population_by_age_gender_acs_m         [009, SEX BY AGE (AMERICAN INDIAN AND ALASKA N...
# b01001d_as_population_by_age_gender_acs_m         [009, SEX BY AGE (ASIAN ALONE) for People Who ...
# ...                                                                                             ...
# b25127_hu_tenure_year_built_units_acs_m           [009, Occupied housing units Owner occupied: B...
# b27001_healthinsurance_by_gender_age_acs_m                    [009, Total:  Male:  18 to 24 years:]
# c15002_educational_attainment_by_race_acs_m       [009, White alone population 25 years and over...
# c18120_emp_status_by_disability_status_acs_m      [009, EMPLOYMENT STATUS BY DISABILITY STATUS f...
# c18130_poverty_status_by_disability_status_acs_m  [009, AGE BY DISABILITY STATUS BY POVERTY STAT...
#
#                                                                                                 9    \
# b01001_population_by_age_gender_acs_m             [010, SEX BY AGE for Total Population  Male:  ...
# b01001a_whi_population_by_age_gender_acs_m        [010, SEX BY AGE (WHITE ALONE) for People Who ...
# b01001b_aa_population_by_age_gender_acs_m         [010, SEX BY AGE (BLACK OR AFRICAN AMERICAN AL...
# b01001c_na_population_by_age_gender_acs_m         [010, SEX BY AGE (AMERICAN INDIAN AND ALASKA N...
# b01001d_as_population_by_age_gender_acs_m         [010, SEX BY AGE (ASIAN ALONE) for People Who ...
# ...                                                                                             ...
# b25127_hu_tenure_year_built_units_acs_m           [010, Occupied housing units Owner occupied: B...
# b27001_healthinsurance_by_gender_age_acs_m        [010, Total:  Male:  18 to 24 years:  With hea...
# c15002_educational_attainment_by_race_acs_m       [010, White alone population 25 years and over...
# c18120_emp_status_by_disability_status_acs_m      [010, EMPLOYMENT STATUS BY DISABILITY STATUS f...
# c18130_poverty_status_by_disability_status_acs_m  [010, AGE BY DISABILITY STATUS BY POVERTY STAT...
#
#                                                   ...   151   152   153   154  \
# b01001_population_by_age_gender_acs_m             ...  None  None  None  None
# b01001a_whi_population_by_age_gender_acs_m        ...  None  None  None  None
# b01001b_aa_population_by_age_gender_acs_m         ...  None  None  None  None
# b01001c_na_population_by_age_gender_acs_m         ...  None  None  None  None
# b01001d_as_population_by_age_gender_acs_m         ...  None  None  None  None
# ...                                               ...   ...   ...   ...   ...
# b25127_hu_tenure_year_built_units_acs_m           ...  None  None  None  None
# b27001_healthinsurance_by_gender_age_acs_m        ...  None  None  None  None
# c15002_educational_attainment_by_race_acs_m       ...  None  None  None  None
# c18120_emp_status_by_disability_status_acs_m      ...  None  None  None  None
# c18130_poverty_status_by_disability_status_acs_m  ...  None  None  None  None
#
#                                                    155   156   157   158  \
# b01001_population_by_age_gender_acs_m             None  None  None  None
# b01001a_whi_population_by_age_gender_acs_m        None  None  None  None
# b01001b_aa_population_by_age_gender_acs_m         None  None  None  None
# b01001c_na_population_by_age_gender_acs_m         None  None  None  None
# b01001d_as_population_by_age_gender_acs_m         None  None  None  None
# ...                                                ...   ...   ...   ...
# b25127_hu_tenure_year_built_units_acs_m           None  None  None  None
# b27001_healthinsurance_by_gender_age_acs_m        None  None  None  None
# c15002_educational_attainment_by_race_acs_m       None  None  None  None
# c18120_emp_status_by_disability_status_acs_m      None  None  None  None
# c18130_poverty_status_by_disability_status_acs_m  None  None  None  None
#
#                                                    159   160
# b01001_population_by_age_gender_acs_m             None  None
# b01001a_whi_population_by_age_gender_acs_m        None  None
# b01001b_aa_population_by_age_gender_acs_m         None  None
# b01001c_na_population_by_age_gender_acs_m         None  None
# b01001d_as_population_by_age_gender_acs_m         None  None
# ...                                                ...   ...
# b25127_hu_tenure_year_built_units_acs_m           None  None
# b27001_healthinsurance_by_gender_age_acs_m        None  None
# c15002_educational_attainment_by_race_acs_m       None  None
# c18120_emp_status_by_disability_status_acs_m      None  None
# c18130_poverty_status_by_disability_status_acs_m  None  None
#
# [87 rows x 161 columns]

# %%
#table_ids.sort_index().index.values
table_ids.loc['b01001_population_by_age_gender_acs_m', 0]
# Out:
# ['001', 'SEX BY AGE for Total Population  Total:']
