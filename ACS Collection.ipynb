# %%
"""
ACS Collection
Author: Dominic Ridley
"""
from builtins import any as b_any
import sphinx
import pandas as pd
pd.set_option("display.max_rows", None)
import requests
import pickle
import psycopg2
import sys
from psycopg2 import OperationalError, errorcodes, errors
from IPython.display import display 
import time
import numpy as np
import acs_functions
from config import config

# %%
class CensusAPI:
    """
    Contains methods for accessing Census API, loading geo ids of municipalities and retrieving Census tables.
    """
    
    def __init__(self, year): #
        """ Intializes API parameter variables """
        
        self.api_key = '766973dcdc26460a63ee43b8bfed1d1c4692486a'
        self.call = 'https://api.census.gov/data/2018/acs/acs5?get=group({4})&' \
                        + 'for=county%20subdivision:{2}&in=state:{0}%20county:{1}&key={3}'
        self.year = year
        
        """ Loads the census variables used for each table """
        self.ids_dict = pickle.load(open('table_to_censusid.p', "rb"))
        self.cols_dict = pickle.load(open('cols_ids_dict.p', "rb"))
        self.col_uni_dict = pickle.load(open('p_cols_dict.p', 'rb'))
        self.column_ids = pd.read_csv('column_ids.csv', index_col=[0,1], skipinitialspace=True)
        self.column_ids['ids'] = self.column_ids['ids'].apply(lambda x: set(str(x).zfill(3).replace(' ', '').split(',')))
        
    def load_table_censusvars(self, table):
        """ Loads the census variables used for table """
        
        dict_ = c.ids_dict[table]
        ids, names = list(map(list, zip(*dict_)))
        return ids, names
        
    def load_geoids(self):
        """ Loads geoids for geographical level (municipality, tract, block)"""
        
        full_table = pd.read_excel('K:\DataServices\Datasets\Data Keys\Census_MuniName_County_State_ID.xls', \
                                   dtype={'GEOID': str})
        return full_table[['GEOID', 'MUNI_ID', 'MUNI']]
    
    def connect_database(self, server):
        """ Connect to the PostgreSQL database server """
        
        conn = None
        cur = None
        try:
            # read connection parameters
            params = config(section=server)

            # connect to the PostgreSQL server
            #print('Connecting to the PostgreSQL database...')
            conn = psycopg2.connect(**params)
            print("Connected to " + params['database'])
            # create a cursor
            cur = conn.cursor()

        except (Exception, psycopg2.DatabaseError) as error:
            print(error)

        return conn, cur
    
    def call_api(self, table, group='B01001'):
        """ Calls Census API by table and group """
        
        #Loads GEOIDS to map to municipalities
        geoid_table = self.load_geoids()

        #Creates set of county codes to drop any duplicate values
        counties = set([str(x)[2:5] for x in geoid_table['GEOID']])
        
        #Intializes empty dataframe
        out_df = pd.DataFrame()
        
        col_names = []
        
        #Iterates through the counties, calls census api for pop. estimates and appends to dataframe
        for i in counties:
            
            #Calls Census API with state code: 25, county: i, subdivisions: *global and groups
            request_url = self.call.format('25', i, '*', self.api_key, group)
            out = requests.get(request_url).json()
            
            if out_df.empty:
                out_df = out_df.append(out[1:], ignore_index=True)
                col_names = out[0]
            else:
                out_df = out_df.append(out[1:], ignore_index=True)

        
        out_df.columns = col_names
        
        #display(out_df)
        e_m_columns = [i[-4:] for i in out_df.columns if (i[-1] in ['E', 'M']) & (i not in ['NAME'])]
        cols_to_rename = [i for i in out_df.columns if (i[-1] in ['E', 'M']) & (i not in ['NAME'])]
        
        out_df = out_df.rename(columns=dict(zip(cols_to_rename, e_m_columns)))
        out_df = out_df[['NAME', 'GEO_ID']+e_m_columns]
        
        out_df = out_df.rename(columns={'GEO_ID': 'GEOID'})
        
        out_df['GEOID'] = out_df['GEOID'].apply(lambda x: x[-10:])
        
        final_df = out_df.copy()
        
        
        #Joins tables on 'GEOID' to get municipality names
        final_df = final_df.merge(geoid_table, on='GEOID', how='inner')
        final_df = final_df[['MUNI_ID', 'MUNI', 'NAME']+e_m_columns].sort_values('MUNI_ID')
        return final_df

# %%
column_ids = pd.read_csv('column_ids.csv', index_col=[0,1], skipinitialspace=True)

# %%
ids = c.column_ids.loc['b01001_population_by_age_gender_acs_m'].to_dict(orient='index')
[idx + 'E' for idx in ids['pop']['ids']]
# Out:
# ['001E']

# %%
column_ids['ids'] = column_ids['ids'].apply(lambda x: set(str(x).zfill(3).replace(' ', '').split(',')))

# %%
column_ids.loc['b01001_population_by_age_gender_acs_m']
# Out:
#                                                           ids    moe  percent
# pop                                                     {001}  False    False
# popm                                                    {001}   True    False
# pop_u5                                             {003, 027}  False    False
# pop_u5m                                            {003, 027}   True    False
# pop_5_9                                            {028, 004}  False    False
# pop_5_9m                                           {028, 004}   True    False
# pop1014                                            {005, 029}  False    False
# pop1014m                                           {005, 029}   True    False
# pop1517                                            {030, 006}  False    False
# pop1517m                                           {030, 006}   True    False
# pop1819                                            {007, 031}  False    False
# pop1819m                                           {007, 031}   True    False
# pop20                                              {032, 008}  False    False
# pop20m                                             {032, 008}   True    False
# pop21                                              {009, 033}  False    False
# pop21m                                             {009, 033}   True    False
# pop2224                                            {034, 010}  False    False
# pop2224m                                           {034, 010}   True    False
# pop2529                                            {035, 011}  False    False
# pop2529m                                           {035, 011}   True    False
# pop3034                                            {012, 036}  False    False
# pop3034m                                           {012, 036}   True    False
# pop3539                                            {013, 037}  False    False
# pop3539m                                           {013, 037}   True    False
# pop4044                                            {038, 014}  False    False
# pop4044m                                           {038, 014}   True    False
# pop4549                                            {015, 039}  False    False
# pop4549m                                           {015, 039}   True    False
# pop5054                                            {040, 016}  False    False
# pop5054m                                           {040, 016}   True    False
# pop5559                                            {017, 041}  False    False
# pop5559m                                           {017, 041}   True    False
# pop6061                                            {042, 018}  False    False
# pop6061m                                           {042, 018}   True    False
# pop6264                                            {019, 043}  False    False
# pop6264m                                           {019, 043}   True    False
# pop6566                                            {044, 020}  False    False
# pop6566m                                           {044, 020}   True    False
# pop6769                                            {045, 021}  False    False
# pop6769m                                           {045, 021}   True    False
# pop7074                                            {022, 046}  False    False
# pop7074m                                           {022, 046}   True    False
# pop7579                                            {047, 023}  False    False
# pop7579m                                           {047, 023}   True    False
# pop8084                                            {024, 048}  False    False
# pop8084m                                           {024, 048}   True    False
# pop85o                                             {049, 025}  False    False
# pop85om                                            {049, 025}   True    False
# pop_u18              {005, 003, 030, 027, 029, 028, 006, 004}  False    False
# pop_u18m             {005, 003, 030, 027, 029, 028, 006, 004}   True    False
# pop1824              {007, 031, 010, 009, 008, 034, 032, 033}  False    False
# pop1824m             {007, 031, 010, 009, 008, 034, 032, 033}   True    False
# pop2534                                  {012, 035, 036, 011}  False    False
# pop2534m                                 {012, 035, 036, 011}   True    False
# pop3564     {019, 042, 038, 014, 040, 018, 017, 037, 039, ...  False    False
# pop3564m    {019, 042, 038, 014, 040, 018, 017, 037, 039, ...   True    False
# pop65ov     {021, 024, 047, 045, 046, 025, 049, 023, 022, ...  False    False
# pop65ovm    {021, 024, 047, 045, 046, 025, 049, 023, 022, ...   True    False
# pop1834     {007, 031, 010, 012, 009, 008, 034, 032, 035, ...  False    False
# pop1834m    {007, 031, 010, 012, 009, 008, 034, 032, 035, ...   True    False
# pop3544                                  {013, 037, 038, 014}  False    False
# pop3544m                                 {013, 037, 038, 014}   True    False
# pop4564     {019, 042, 040, 018, 017, 039, 043, 015, 016, ...  False    False
# pop4564m    {019, 042, 040, 018, 017, 039, 043, 015, 016, ...   True    False
# fpop                                                    {026}  False    False
# fpopm                                                   {026}   True    False
# fpop_u5                                                 {027}  False    False
# fpop_u5m                                                {027}   True    False
# fpop_5_9                                                {028}  False    False
# fpop_5_9m                                               {028}   True    False
# fpop1014                                                {029}  False    False
# fpop1014m                                               {029}   True    False
# fpop1517                                                {030}  False    False
# fpop1517m                                               {030}   True    False
# fpop1819                                                {031}  False    False
# fpop1819m                                               {031}   True    False
# fpop20                                                  {032}  False    False
# fpop20m                                                 {032}   True    False
# fpop21                                                  {033}  False    False
# fpop21m                                                 {033}   True    False
# fpop2224                                                {034}  False    False
# fpop2224m                                               {034}   True    False
# fpop2529                                                {035}  False    False
# fpop2529m                                               {035}   True    False
# fpop3034                                                {036}  False    False
# fpop3034m                                               {036}   True    False
# fpop3539                                                {037}  False    False
# fpop3539m                                               {037}   True    False
# fpop4044                                                {038}  False    False
# fpop4044m                                               {038}   True    False
# fpop4549                                                {039}  False    False
# fpop4549m                                               {039}   True    False
# fpop5054                                                {040}  False    False
# fpop5054m                                               {040}   True    False
# fpop5559                                                {041}  False    False
# fpop5559m                                               {041}   True    False
# fpop6061                                                {042}  False    False
# fpop6061m                                               {042}   True    False
# fpop6264                                                {043}  False    False
# fpop6264m                                               {043}   True    False
# fpop6566                                                {044}  False    False
# fpop6566m                                               {044}   True    False
# fpop6769                                                {045}  False    False
# fpop6769m                                               {045}   True    False
# fpop7074                                                {046}  False    False
# fpop7074m                                               {046}   True    False
# fpop7579                                                {047}  False    False
# fpop7579m                                               {047}   True    False
# fpop8084                                                {048}  False    False
# fpop8084m                                               {048}   True    False
# fpop85o                                                 {049}  False    False
# fpop85om                                                {049}   True    False
# fpop_u18                                 {028, 030, 029, 027}  False    False
# fpop_u18m                                {028, 030, 029, 027}   True    False
# fpop1824                                 {032, 034, 031, 033}  False    False
# fpop1824m                                {032, 034, 031, 033}   True    False
# fpop2534                                           {035, 036}  False    False
# fpop2534m                                          {035, 036}   True    False
# fpop3564                  {042, 038, 040, 037, 039, 043, 041}  False    False
# fpop3564m                 {042, 038, 040, 037, 039, 043, 041}   True    False
# fpop65ov                       {047, 045, 046, 049, 044, 048}  False    False
# fpop65ovm                      {047, 045, 046, 049, 044, 048}   True    False
# fpop1834                  {031, 012, 034, 032, 035, 036, 033}  False    False
# fpop1834m                 {031, 012, 034, 032, 035, 036, 033}   True    False
# fpop3544                                           {037, 038}  False    False
# fpop3544m                                          {037, 038}   True    False
# fpop4564                            {042, 040, 039, 043, 041}  False    False
# fpop4564m                           {042, 040, 039, 043, 041}   True    False
# mpop                                                    {002}  False    False
# mpopm                                                   {002}   True    False
# mpop_u5                                                 {003}  False    False
# mpop_u5m                                                {003}   True    False
# mpop_5_9                                                {004}  False    False
# mpop_5_9m                                               {004}   True    False
# mpop1014                                                {005}  False    False
# mpop1014m                                               {005}   True    False
# mpop1517                                                {006}  False    False
# mpop1517m                                               {006}   True    False
# mpop1819                                                {007}  False    False
# mpop1819m                                               {007}   True    False
# mpop20                                                  {008}  False    False
# mpop20m                                                 {008}   True    False
# mpop21                                                  {009}  False    False
# mpop21m                                                 {009}   True    False
# mpop2224                                                {010}  False    False
# mpop2224m                                               {010}   True    False
# mpop2529                                                {011}  False    False
# mpop2529m                                               {011}   True    False
# mpop3034                                                {012}  False    False
# mpop3034m                                               {012}   True    False
# mpop3539                                                {013}  False    False
# mpop3539m                                               {013}   True    False
# mpop4044                                                {014}  False    False
# mpop4044m                                               {014}   True    False
# mpop4549                                                {015}  False    False
# mpop4549m                                               {015}   True    False
# mpop5054                                                {016}  False    False
# mpop5054m                                               {016}   True    False
# mpop5559                                                {017}  False    False
# mpop5559m                                               {017}   True    False
# mpop6061                                                {018}  False    False
# mpop6061m                                               {018}   True    False
# mpop6264                                                {019}  False    False
# mpop6264m                                               {019}   True    False
# mpop6566                                                {020}  False    False
# mpop6566m                                               {020}   True    False
# mpop6769                                                {021}  False    False
# mpop6769m                                               {021}   True    False
# mpop7074                                                {022}  False    False
# mpop7074m                                               {022}   True    False
# mpop7579                                                {023}  False    False
# mpop7579m                                               {023}   True    False
# mpop8084                                                {024}  False    False
# mpop8084m                                               {024}   True    False
# mpop85o                                                 {025}  False    False
# mpop85om                                                {025}   True    False
# mpop_u18                                 {005, 003, 006, 004}  False    False
# mpop_u18m                                {005, 003, 006, 004}   True    False
# mpop1824                                 {009, 010, 007, 008}  False    False
# mpop1824m                                {009, 010, 007, 008}   True    False
# mpop2534                                           {012, 011}  False    False
# mpop2534m                                          {012, 011}   True    False
# mpop3564                  {019, 014, 018, 017, 015, 016, 013}  False    False
# mpop3564m                 {019, 014, 018, 017, 015, 016, 013}   True    False
# mpop65ov                       {021, 024, 025, 023, 022, 020}  False    False
# mpop65ovm                      {021, 024, 025, 023, 022, 020}   True    False
# mpop1834                       {007, 010, 012, 009, 008, 011}  False    False
# mpop1834m                      {007, 010, 012, 009, 008, 011}   True    False
# mpop3544                                           {013, 014}  False    False
# mpop3544m                                          {013, 014}   True    False
# mpop4564                            {019, 018, 017, 015, 016}  False    False
# mpop4564m                           {019, 018, 017, 015, 016}   True    False
# pop_u5p                                       {003, 001, 027}  False     True
# pop_u5mp                                      {003, 001, 027}   True     True
# pop_5_9p                                      {028, 001, 004}  False     True
# pop_5_9mp                                     {028, 001, 004}   True     True
# pop1014p                                      {005, 001, 029}  False     True
# pop1014mp                                     {005, 001, 029}   True     True
# pop1517p                                      {030, 001, 006}  False     True
# pop1517mp                                     {030, 001, 006}   True     True
# pop1819p                                      {007, 001, 031}  False     True
# pop1819mp                                     {007, 001, 031}   True     True
# pop20p                                        {032, 001, 008}  False     True
# pop20mp                                       {032, 001, 008}   True     True
# pop21p                                        {009, 001, 033}  False     True
# pop21mp                                       {009, 001, 033}   True     True
# pop2224p                                      {034, 001, 010}  False     True
# pop2224mp                                     {034, 001, 010}   True     True
# pop2529p                                      {035, 001, 011}  False     True
# pop2529mp                                     {035, 001, 011}   True     True
# pop3034p                                      {012, 001, 036}  False     True
# pop3034mp                                     {012, 001, 036}   True     True
# pop3539p                                      {013, 001, 037}  False     True
# pop3539mp                                     {013, 001, 037}   True     True
# pop4044p                                      {001, 038, 014}  False     True
# pop4044mp                                     {001, 038, 014}   True     True
# pop4549p                                      {015, 001, 039}  False     True
# pop4549mp                                     {015, 001, 039}   True     True
# pop5054p                                      {040, 001, 016}  False     True
# pop5054mp                                     {040, 001, 016}   True     True
# pop5559p                                      {001, 017, 041}  False     True
# pop5559mp                                     {001, 017, 041}   True     True
# pop6061p                                      {042, 001, 018}  False     True
# pop6061mp                                     {042, 001, 018}   True     True
# pop6264p                                      {019, 043, 001}  False     True
# pop6264mp                                     {019, 043, 001}   True     True
# pop6566p                                      {001, 044, 020}  False     True
# pop6566mp                                     {001, 044, 020}   True     True
# pop6769p                                      {045, 021, 001}  False     True
# pop6769mp                                     {045, 021, 001}   True     True
# pop7074p                                      {022, 001, 046}  False     True
# pop7074mp                                     {022, 001, 046}   True     True
# pop7579p                                      {047, 001, 023}  False     True
# pop7579mp                                     {047, 001, 023}   True     True
# pop8084p                                      {024, 001, 048}  False     True
# pop8084mp                                     {024, 001, 048}   True     True
# pop85op                                       {049, 001, 025}  False     True
# pop85omp                                      {049, 001, 025}   True     True
# pop_u18p        {005, 003, 030, 001, 027, 029, 028, 006, 004}  False     True
# pop_u18mp       {005, 003, 030, 001, 027, 029, 028, 006, 004}   True     True
# pop1824p        {007, 031, 010, 009, 001, 008, 034, 032, 033}  False     True
# pop1824mp       {007, 031, 010, 009, 001, 008, 034, 032, 033}   True     True
# pop2534p                            {012, 001, 035, 036, 011}  False     True
# pop2534mp                           {012, 001, 035, 036, 011}   True     True
# pop3564p    {019, 042, 038, 014, 040, 001, 018, 017, 037, ...  False     True
# pop3564mp   {019, 042, 038, 014, 040, 001, 018, 017, 037, ...   True     True
# pop65ovp    {021, 024, 047, 045, 001, 046, 025, 049, 023, ...  False     True
# pop65ovmp   {021, 024, 047, 045, 001, 046, 025, 049, 023, ...   True     True
# pop1834p    {007, 031, 010, 012, 009, 001, 008, 034, 032, ...  False     True
# pop1834mp   {007, 031, 010, 012, 009, 001, 008, 034, 032, ...   True     True
# pop3544p                            {038, 014, 001, 037, 013}  False     True
# pop3544mp                           {038, 014, 001, 037, 013}   True     True
# pop4564p    {019, 042, 040, 001, 018, 017, 039, 043, 015, ...  False     True
# pop4564mp   {019, 042, 040, 001, 018, 017, 039, 043, 015, ...   True     True
# fpop_p                                             {026, 001}  False     True
# fpop_mp                                            {026, 001}   True     True
# fpop_u5p                                           {001, 027}  False     True
# fpop_u5mp                                          {001, 027}   True     True
# fpop_5_9p                                          {028, 001}  False     True
# fpop_5_9mp                                         {028, 001}   True     True
# fpop1014p                                          {001, 029}  False     True
# fpop1014mp                                         {001, 029}   True     True
# fpop1517p                                          {030, 001}  False     True
# fpop1517mp                                         {030, 001}   True     True
# fpop1819p                                          {001, 031}  False     True
# fpop1819mp                                         {001, 031}   True     True
# fpop20p                                            {032, 001}  False     True
# fpop20mp                                           {032, 001}   True     True
# fpop21p                                            {001, 033}  False     True
# fpop21mp                                           {001, 033}   True     True
# fpop2224p                                          {034, 001}  False     True
# fpop2224mp                                         {034, 001}   True     True
# fpop2529p                                          {035, 001}  False     True
# fpop2529mp                                         {035, 001}   True     True
# fpop3034p                                          {001, 036}  False     True
# fpop3034mp                                         {001, 036}   True     True
# fpop3539p                                          {001, 037}  False     True
# fpop3539mp                                         {001, 037}   True     True
# fpop4044p                                          {001, 038}  False     True
# fpop4044mp                                         {001, 038}   True     True
# fpop4549p                                          {001, 039}  False     True
# fpop4549mp                                         {001, 039}   True     True
# fpop5054p                                          {040, 001}  False     True
# fpop5054mp                                         {040, 001}   True     True
# fpop5559p                                          {001, 041}  False     True
# fpop5559mp                                         {001, 041}   True     True
# fpop6061p                                          {042, 001}  False     True
# fpop6061mp                                         {042, 001}   True     True
# fpop6264p                                          {043, 001}  False     True
# fpop6264mp                                         {043, 001}   True     True
# fpop6566p                                          {001, 044}  False     True
# fpop6566mp                                         {001, 044}   True     True
# fpop6769p                                          {045, 001}  False     True
# fpop6769mp                                         {045, 001}   True     True
# fpop7074p                                          {001, 046}  False     True
# fpop7074mp                                         {001, 046}   True     True
# fpop7579p                                          {047, 001}  False     True
# fpop7579mp                                         {047, 001}   True     True
# fpop8084p                                          {001, 048}  False     True
# fpop8084mp                                         {001, 048}   True     True
# fpop85op                                           {049, 001}  False     True
# fpop85omp                                          {049, 001}   True     True
# fpop_u18p                           {030, 001, 027, 029, 028}  False     True
# fpop_u18mp                          {030, 001, 027, 029, 028}   True     True
# fpop1824p                           {031, 001, 032, 034, 033}  False     True
# fpop1824mp                          {031, 001, 032, 034, 033}   True     True
# fpop2534p                                     {035, 001, 036}  False     True
# fpop2534mp                                    {035, 001, 036}   True     True
# fpop3564p            {042, 038, 040, 001, 037, 039, 043, 041}  False     True
# fpop3564mp           {042, 038, 040, 001, 037, 039, 043, 041}   True     True
# fpop65ovp                 {047, 045, 001, 046, 049, 044, 048}  False     True
# fpop65ovmp                {047, 045, 001, 046, 049, 044, 048}   True     True
# fpop1834p                 {031, 001, 034, 032, 035, 036, 033}  False     True
# fpop1834mp                {031, 001, 034, 032, 035, 036, 033}   True     True
# fpop3544p                                     {001, 037, 038}  False     True
# fpop3544mp                                    {001, 037, 038}   True     True
# fpop4564p                      {042, 040, 001, 039, 043, 041}  False     True
# fpop4564mp                     {042, 040, 001, 039, 043, 041}   True     True
# mpop_p                                             {001, 002}  False     True
# mpop_mp                                            {001, 002}   True     True
# mpop_u5p                                           {003, 001}  False     True
# mpop_u5mp                                          {003, 001}   True     True
# mpop_5_9p                                          {001, 004}  False     True
# mpop_5_9mp                                         {001, 004}   True     True
# mpop1014p                                          {005, 001}  False     True
# mpop1014mp                                         {005, 001}   True     True
# mpop1517p                                          {001, 006}  False     True
# mpop1517mp                                         {001, 006}   True     True
# mpop1819p                                          {007, 001}  False     True
# mpop1819mp                                         {007, 001}   True     True
# mpop20p                                            {001, 008}  False     True
# mpop20mp                                           {001, 008}   True     True
# mpop21p                                            {009, 001}  False     True
# mpop21mp                                           {009, 001}   True     True
# mpop2224p                                          {001, 010}  False     True
# mpop2224mp                                         {001, 010}   True     True
# mpop2529p                                          {001, 011}  False     True
# mpop2529mp                                         {001, 011}   True     True
# mpop3034p                                          {012, 001}  False     True
# mpop3034mp                                         {012, 001}   True     True
# mpop3539p                                          {001, 013}  False     True
# mpop3539mp                                         {001, 013}   True     True
# mpop4044p                                          {001, 014}  False     True
# mpop4044mp                                         {001, 014}   True     True
# mpop4549p                                          {001, 015}  False     True
# mpop4549mp                                         {001, 015}   True     True
# mpop5054p                                          {001, 016}  False     True
# mpop5054mp                                         {001, 016}   True     True
# mpop5559p                                          {001, 017}  False     True
# mpop5559mp                                         {001, 017}   True     True
# mpop6061p                                          {001, 018}  False     True
# mpop6061mp                                         {001, 018}   True     True
# mpop6264p                                          {019, 001}  False     True
# mpop6264mp                                         {019, 001}   True     True
# mpop6566p                                          {001, 020}  False     True
# mpop6566mp                                         {001, 020}   True     True
# mpop6769p                                          {021, 001}  False     True
# mpop6769mp                                         {021, 001}   True     True
# mpop7074p                                          {022, 001}  False     True
# mpop7074mp                                         {022, 001}   True     True
# mpop7579p                                          {001, 023}  False     True
# mpop7579mp                                         {001, 023}   True     True
# mpop8084p                                          {024, 001}  False     True
# mpop8084mp                                         {024, 001}   True     True
# mpop85op                                           {001, 025}  False     True
# mpop85omp                                          {001, 025}   True     True
# mpop_u18p                           {005, 003, 001, 006, 004}  False     True
# mpop_u18mp                          {005, 003, 001, 006, 004}   True     True
# mpop1824p                           {007, 010, 009, 001, 008}  False     True
# mpop1824mp                          {007, 010, 009, 001, 008}   True     True
# mpop2534p                                     {012, 001, 011}  False     True
# mpop2534mp                                    {012, 001, 011}   True     True
# mpop3564p            {019, 014, 001, 018, 017, 015, 016, 013}  False     True
# mpop3564mp           {019, 014, 001, 018, 017, 015, 016, 013}   True     True
# mpop65ovp                 {021, 024, 001, 025, 023, 022, 020}  False     True
# mpop65ovmp                {021, 024, 001, 025, 023, 022, 020}   True     True
# mpop1834p                 {007, 010, 012, 009, 001, 008, 011}  False     True
# mpop1834mp                {007, 010, 012, 009, 001, 008, 011}   True     True
# mpop3544p                                     {001, 013, 014}  False     True
# mpop3544mp                                    {001, 013, 014}   True     True
# mpop4564p                      {019, 001, 018, 017, 015, 016}  False     True

# %%
c = CensusAPI('2018')

# %%
conn, cur = c.connect_database('sdvm')
# Out:
# Connected to ds

# %%
cur.callproc('acs_est_pct', ([1], [1]))
cur.fetchall()
# Out:
# [(Decimal('100.00'),)]

# %%
hello = c.call_api('b01001_population_by_age_gender_acs_m')

# %%
pickle.dump(hello, open('test_table.p', 'wb'))

# %%
hello.iloc[:, 3:] = hello.iloc[:, 3:].applymap(lambda x: float(x)).clip(lower=0)

# %%
hello.loc[144, :]
# Out:
# MUNI_ID                                               204
# MUNI                                            NEW SALEM
# NAME       New Salem town, Franklin County, Massachusetts
# 001E                                                 1036
# 001M                                                  109
# 002E                                                  591
# 002M                                                   76
# 003E                                                   55
# 003M                                                   32
# 004E                                                   28
# 004M                                                   13
# 005E                                                   31
# 005M                                                   13
# 006E                                                   14
# 006M                                                   10
# 007E                                                   21
# 007M                                                   17
# 008E                                                    8
# 008M                                                    7
# 009E                                                    0
# 009M                                                   12
# 010E                                                    8
# 010M                                                    8
# 011E                                                   18
# 011M                                                   10
# 012E                                                   15
# 012M                                                   12
# 013E                                                   12
# 013M                                                   10
# 014E                                                   34
# 014M                                                   19
# 015E                                                   29
# 015M                                                   11
# 016E                                                   42
# 016M                                                   18
# 017E                                                   88
# 017M                                                   28
# 018E                                                   25
# 018M                                                   19
# 019E                                                   40
# 019M                                                   25
# 020E                                                   27
# 020M                                                   15
# 021E                                                   16
# 021M                                                   11
# 022E                                                   36
# 022M                                                   26
# 023E                                                   17
# 023M                                                   10
# 024E                                                    5
# 024M                                                    7
# 025E                                                   22
# 025M                                                   15
# 026E                                                  445
# 026M                                                   55
# 027E                                                    0
# 027M                                                   12
# 028E                                                   15
# 028M                                                   10
# 029E                                                    9
# 029M                                                    8
# 030E                                                   25
# 030M                                                   18
# 031E                                                   11
# 031M                                                   10
# 032E                                                    0
# 032M                                                   12
# 033E                                                    0
# 033M                                                   12
# 034E                                                   12
# 034M                                                   17
# 035E                                                   17
# 035M                                                   10
# 036E                                                    7
# 036M                                                    7
# 037E                                                   20
# 037M                                                   12
# 038E                                                   36
# 038M                                                   18
# 039E                                                   29
# 039M                                                   12
# 040E                                                   35
# 040M                                                   17
# 041E                                                   72
# 041M                                                   21
# 042E                                                   27
# 042M                                                   23
# 043E                                                   24
# 043M                                                   11
# 044E                                                   11
# 044M                                                    9
# 045E                                                   25
# 045M                                                   13
# 046E                                                   29
# 046M                                                   20
# 047E                                                   13
# 047M                                                    9
# 048E                                                   25
# 048M                                                   17
# 049E                                                    3
# 049M                                                    6
# Name: 144, dtype: object

# %%
c.column_ids.loc['b01001_population_by_age_gender_acs_m']
# Out:
#                                                            ids    moe  percent
# pop                                                  {{'001'}}  False    False
# popm                                                 {{'001'}}   True    False
# pop_u5                                        {{'003', '027'}}  False    False
# pop_u5m                                       {{'003', '027'}}   True    False
# pop_5_9                                       {{'028', '004'}}  False    False
# pop_5_9m                                      {{'028', '004'}}   True    False
# pop1014                                       {'005'}, {'029'}  False    False
# pop1014m                                      {'005'}, {'029'}   True    False
# pop1517                                       {'030'}, {'006'}  False    False
# pop1517m                                      {'030'}, {'006'}   True    False
# pop1819                                       {'031'}, {'007'}  False    False
# pop1819m                                      {'031'}, {'007'}   True    False
# pop20                                         {'008'}, {'032'}  False    False
# pop20m                                        {'008'}, {'032'}   True    False
# pop21                                         {{'033', '009'}}  False    False
# pop21m                                        {{'033', '009'}}   True    False
# pop2224                                       {'034'}, {'010'}  False    False
# pop2224m                                      {'034'}, {'010'}   True    False
# pop2529                                       {'035'}, {'011'}  False    False
# pop2529m                                      {'035'}, {'011'}   True    False
# pop3034                                       {{'012', '036'}}  False    False
# pop3034m                                      {{'012', '036'}}   True    False
# pop3539                                       {{'013', '037'}}  False    False
# pop3539m                                      {{'013', '037'}}   True    False
# pop4044                                       {{'038', '014'}}  False    False
# pop4044m                                      {{'038', '014'}}   True    False
# pop4549                                       {{'039', '015'}}  False    False
# pop4549m                                      {{'039', '015'}}   True    False
# pop5054                                       {'040'}, {'016'}  False    False
# pop5054m                                      {'040'}, {'016'}   True    False
# pop5559                                       {{'017', '041'}}  False    False
# pop5559m                                      {{'017', '041'}}   True    False
# pop6061                                       {'042'}, {'018'}  False    False
# pop6061m                                      {'042'}, {'018'}   True    False
# pop6264                                       {'019'}, {'043'}  False    False
# pop6264m                                      {'019'}, {'043'}   True    False
# pop6566                                       {'044'}, {'020'}  False    False
# pop6566m                                      {'044'}, {'020'}   True    False
# pop6769                                       {'021'}, {'045'}  False    False
# pop6769m                                      {'021'}, {'045'}   True    False
# pop7074                                       {{'046', '022'}}  False    False
# pop7074m                                      {{'046', '022'}}   True    False
# pop7579                                       {'047'}, {'023'}  False    False
# pop7579m                                      {'047'}, {'023'}   True    False
# pop8084                                       {'024'}, {'048'}  False    False
# pop8084m                                      {'024'}, {'048'}   True    False
# pop85o                                        {'049'}, {'025'}  False    False
# pop85om                                       {'049'}, {'025'}   True    False
# pop_u18      {'006', '004', '030', '005'}, '003', {'028', '...  False    False
# pop_u18m     {'006', '004', '030', '005'}, '003', {'028', '...   True    False
# pop1824      {'009', '034', '033', '010', '032'}, '031', {'...  False    False
# pop1824m     {'009', '034', '033', '010', '032'}, '031', {'...   True    False
# pop2534                         {{'012', '035'}, '011', '036'}  False    False
# pop2534m                        {{'012', '035'}, '011', '036'}   True    False
# pop3564      {'038', '014'}, '037', '013', '017', '042', '0...  False    False
# pop3564m     {'038', '014'}, '037', '013', '017', '042', '0...   True    False
# pop65ov      {'022', '020', '048', '025', '024', '045', '04...  False    False
# pop65ovm     {'022', '020', '048', '025', '024', '045', '04...   True    False
# pop1834      {'009', '035', '034', '033', '010', '012', '03...  False    False
# pop1834m     {'009', '035', '034', '033', '010', '012', '03...   True    False
# pop3544                         {{'013', '038', '037'}, '014'}  False    False
# pop3544m                        {{'013', '038', '037'}, '014'}   True    False
# pop4564      {'017'}, '042', '043', {'018', '019', '041', '...  False    False
# pop4564m     {'017'}, '042', '043', {'018', '019', '041', '...   True    False
# fpop                                                 {{'026'}}  False    False
# fpopm                                                {{'026'}}   True    False
# fpop_u5                                              {{'027'}}  False    False
# fpop_u5m                                             {{'027'}}   True    False
# fpop_5_9                                             {{'028'}}  False    False
# fpop_5_9m                                            {{'028'}}   True    False
# fpop1014                                             {{'029'}}  False    False
# fpop1014m                                            {{'029'}}   True    False
# fpop1517                                             {{'030'}}  False    False
# fpop1517m                                            {{'030'}}   True    False
# fpop1819                                             {{'031'}}  False    False
# fpop1819m                                            {{'031'}}   True    False
# fpop20                                               {{'032'}}  False    False
# fpop20m                                              {{'032'}}   True    False
# fpop21                                               {{'033'}}  False    False
# fpop21m                                              {{'033'}}   True    False
# fpop2224                                             {{'034'}}  False    False
# fpop2224m                                            {{'034'}}   True    False
# fpop2529                                             {{'035'}}  False    False
# fpop2529m                                            {{'035'}}   True    False
# fpop3034                                             {{'036'}}  False    False
# fpop3034m                                            {{'036'}}   True    False
# fpop3539                                             {{'037'}}  False    False
# fpop3539m                                            {{'037'}}   True    False
# fpop4044                                             {{'038'}}  False    False
# fpop4044m                                            {{'038'}}   True    False
# fpop4549                                             {{'039'}}  False    False
# fpop4549m                                            {{'039'}}   True    False
# fpop5054                                             {{'040'}}  False    False
# fpop5054m                                            {{'040'}}   True    False
# fpop5559                                             {{'041'}}  False    False
# fpop5559m                                            {{'041'}}   True    False
# fpop6061                                             {{'042'}}  False    False
# fpop6061m                                            {{'042'}}   True    False
# fpop6264                                             {{'043'}}  False    False
# fpop6264m                                            {{'043'}}   True    False
# fpop6566                                             {{'044'}}  False    False
# fpop6566m                                            {{'044'}}   True    False
# fpop6769                                             {{'045'}}  False    False
# fpop6769m                                            {{'045'}}   True    False
# fpop7074                                             {{'046'}}  False    False
# fpop7074m                                            {{'046'}}   True    False
# fpop7579                                             {{'047'}}  False    False
# fpop7579m                                            {{'047'}}   True    False
# fpop8084                                             {{'048'}}  False    False
# fpop8084m                                            {{'048'}}   True    False
# fpop85o                                              {{'049'}}  False    False
# fpop85om                                             {{'049'}}   True    False
# fpop_u18                        {'030', {'028', '027'}, '029'}  False    False
# fpop_u18m                       {'030', {'028', '027'}, '029'}   True    False
# fpop1824                        {'034', '031'}, {'032', '033'}  False    False
# fpop1824m                       {'034', '031'}, {'032', '033'}   True    False
# fpop2534                                      {'035'}, {'036'}  False    False
# fpop2534m                                     {'035'}, {'036'}   True    False
# fpop3564     {'038', '041'}, '037', {'039', '042', '043', '...  False    False
# fpop3564m    {'038', '041'}, '037', {'039', '042', '043', '...   True    False
# fpop65ov          {'048', '047'}, '045', {'049', '046', '044'}  False    False
# fpop65ovm         {'048', '047'}, '045', {'049', '046', '044'}   True    False
# fpop1834     {'035', '033', '012', '032'}, '031', {'034', '...  False    False
# fpop1834m    {'035', '033', '012', '032'}, '031', {'034', '...   True    False
# fpop3544                                      {{'038', '037'}}  False    False
# fpop3544m                                     {{'038', '037'}}   True    False
# fpop4564                 {'041'}, {'039', '042', '043', '040'}  False    False
# fpop4564m                {'041'}, {'039', '042', '043', '040'}   True    False
# mpop                                                 {{'002'}}  False    False
# mpopm                                                {{'002'}}   True    False
# mpop_u5                                              {{'003'}}  False    False
# mpop_u5m                                             {{'003'}}   True    False
# mpop_5_9                                             {{'004'}}  False    False
# mpop_5_9m                                            {{'004'}}   True    False
# mpop1014                                             {{'005'}}  False    False
# mpop1014m                                            {{'005'}}   True    False
# mpop1517                                             {{'006'}}  False    False
# mpop1517m                                            {{'006'}}   True    False
# mpop1819                                             {{'007'}}  False    False
# mpop1819m                                            {{'007'}}   True    False
# mpop20                                               {{'008'}}  False    False
# mpop20m                                              {{'008'}}   True    False
# mpop21                                               {{'009'}}  False    False
# mpop21m                                              {{'009'}}   True    False
# mpop2224                                             {{'010'}}  False    False
# mpop2224m                                            {{'010'}}   True    False
# mpop2529                                             {{'011'}}  False    False
# mpop2529m                                            {{'011'}}   True    False
# mpop3034                                             {{'012'}}  False    False
# mpop3034m                                            {{'012'}}   True    False
# mpop3539                                             {{'013'}}  False    False
# mpop3539m                                            {{'013'}}   True    False
# mpop4044                                             {{'014'}}  False    False
# mpop4044m                                            {{'014'}}   True    False
# mpop4549                                             {{'015'}}  False    False
# mpop4549m                                            {{'015'}}   True    False
# mpop5054                                             {{'016'}}  False    False
# mpop5054m                                            {{'016'}}   True    False
# mpop5559                                             {{'017'}}  False    False
# mpop5559m                                            {{'017'}}   True    False
# mpop6061                                             {{'018'}}  False    False
# mpop6061m                                            {{'018'}}   True    False
# mpop6264                                             {{'019'}}  False    False
# mpop6264m                                            {{'019'}}   True    False
# mpop6566                                             {{'020'}}  False    False
# mpop6566m                                            {{'020'}}   True    False
# mpop6769                                             {{'021'}}  False    False
# mpop6769m                                            {{'021'}}   True    False
# mpop7074                                             {{'022'}}  False    False
# mpop7074m                                            {{'022'}}   True    False
# mpop7579                                      {'023'}, {'001'}  False    False
# mpop7579m                                            {{'023'}}   True    False
# mpop8084                                             {{'024'}}  False    False
# mpop8084m                                            {{'024'}}   True    False
# mpop85o                                              {{'025'}}  False    False
# mpop85om                                             {{'025'}}   True    False
# mpop_u18                        {{'003', '005'}, '006', '004'}  False    False
# mpop_u18m                       {{'003', '005'}, '006', '004'}   True    False
# mpop1824                        {'009', '007'}, '010', {'008'}  False    False
# mpop1824m                       {'009', '007'}, '010', {'008'}   True    False
# mpop2534                                      {{'012', '011'}}  False    False
# mpop2534m                                     {{'012', '011'}}   True    False
# mpop3564     {'014'}, '013', '017', {'018', '019', '015', '...  False    False
# mpop3564m    {'014'}, '013', '017', {'018', '019', '015', '...   True    False
# mpop65ov          {'022', '024'}, '020', '025', {'023', '021'}  False    False
# mpop65ovm         {'022', '024'}, '020', '025', {'023', '021'}   True    False
# mpop1834          {'009', '010', {'008', '012'}, '011', '007'}  False    False
# mpop1834m         {'009', '010', {'008', '012'}, '011', '007'}   True    False
# mpop3544                                      {{'013', '014'}}  False    False
# mpop3544m                                     {{'013', '014'}}   True    False
# mpop4564                 {'017'}, {'018', '019', '015', '016'}  False    False
# mpop4564m                {'017'}, {'018', '019', '015', '016'}   True    False
# pop_u5p                                {{'003', '001'}, '027'}  False     True
# pop_u5mp                               {{'003', '001'}, '027'}   True     True
# pop_5_9p                               {{'028', '001'}, '004'}  False     True
# pop_5_9mp                              {{'028', '001'}, '004'}   True     True
# pop1014p                               {'005'}, {'001', '029'}  False     True
# pop1014mp                              {'005'}, {'001', '029'}   True     True
# pop1517p                               {'030'}, '006', {'001'}  False     True
# pop1517mp                              {'030'}, '006', {'001'}   True     True
# pop1819p                               {'031'}, '007', {'001'}  False     True
# pop1819mp                              {'031'}, '007', {'001'}   True     True
# pop20p                                 {'001'}, '008', {'032'}  False     True
# pop20mp                                {'001'}, '008', {'032'}   True     True
# pop21p                                 {'009'}, {'001', '033'}  False     True
# pop21mp                                {'009'}, {'001', '033'}   True     True
# pop2224p                               {'034'}, '010', {'001'}  False     True
# pop2224mp                              {'034'}, '010', {'001'}   True     True
# pop2529p                               {'035'}, '011', {'001'}  False     True
# pop2529mp                              {'035'}, '011', {'001'}   True     True
# pop3034p                               {'012', '036'}, {'001'}  False     True
# pop3034mp                              {'012', '036'}, {'001'}   True     True
# pop3539p                               {{'013', '001', '037'}}  False     True
# pop3539mp                              {{'013', '001', '037'}}   True     True
# pop4044p                               {'038', '014'}, {'001'}  False     True
# pop4044mp                              {'038', '014'}, {'001'}   True     True
# pop4549p                               {'001', {'039', '015'}}  False     True
# pop4549mp                              {'001', {'039', '015'}}   True     True
# pop5054p                               {'001', '040'}, {'016'}  False     True
# pop5054mp                              {'001', '040'}, {'016'}   True     True
# pop5559p                               {'001', {'017', '041'}}  False     True
# pop5559mp                              {'001', {'017', '041'}}   True     True
# pop6061p                               {'042', '001'}, {'018'}  False     True
# pop6061mp                              {'042', '001'}, {'018'}   True     True
# pop6264p                               {'019'}, '043', {'001'}  False     True
# pop6264mp                              {'019'}, '043', {'001'}   True     True
# pop6566p                               {'044'}, '020', {'001'}  False     True
# pop6566mp                              {'044'}, '020', {'001'}   True     True
# pop6769p                               {'021', '001'}, {'045'}  False     True
# pop6769mp                              {'021', '001'}, {'045'}   True     True
# pop7074p                               {'046', '022'}, {'001'}  False     True
# pop7074mp                              {'046', '022'}, {'001'}   True     True
# pop7579p                               {'047'}, '023', {'001'}  False     True
# pop7579mp                              {'047'}, '023', {'001'}   True     True
# pop8084p                               {'024'}, '048', {'001'}  False     True
# pop8084mp                              {'024'}, '048', {'001'}   True     True
# pop85op                                {'049'}, '025', {'001'}  False     True
# pop85omp                               {'049'}, '025', {'001'}   True     True
# pop_u18p     {'005', '003', '006', '030', '004', '001', {'0...  False     True
# pop_u18mp    {'005', '003', '006', '030', '004', '001', {'0...   True     True
# pop1824p     {'009', '034', '033', '010', '032'}, '031', {'...  False     True
# pop1824mp    {'009', '034', '033', '010', '032'}, '031', {'...   True     True
# pop2534p                 {'035', {'011', '036'}, '012', '001'}  False     True
# pop2534mp                {'035', {'011', '036'}, '012', '001'}   True     True
# pop3564p     {'038', '014'}, '037', '013', '015', '017', '0...  False     True
# pop3564mp    {'038', '014'}, '037', '013', '015', '017', '0...   True     True
# pop65ovp     {'022', '020', '048', '025', '024', '045', '04...  False     True
# pop65ovmp    {'022', '020', '048', '025', '024', '045', '04...   True     True
# pop1834p     {'009', '035', '034', '033', '010', '012', '03...  False     True
# pop1834mp    {'009', '035', '034', '033', '010', '012', '03...   True     True
# pop3544p                 {'038', '014'}, '037', '013', {'001'}  False     True
# pop3544mp                {'038', '014'}, '037', '013', {'001'}   True     True
# pop4564p     {'017'}, '015', '042', '043', {'018', '019', '...  False     True
# pop4564mp    {'017'}, '015', '042', '043', {'018', '019', '...   True     True
# fpop_p                                        {'026'}, {'001'}  False     True
# fpop_mp                                       {'026'}, {'001'}   True     True
# fpop_u5p                                      {'027'}, {'001'}  False     True
# fpop_u5mp                                     {'027'}, {'001'}   True     True
# fpop_5_9p                                     {{'028', '001'}}  False     True
# fpop_5_9mp                                    {{'028', '001'}}   True     True
# fpop1014p                                     {'029'}, {'001'}  False     True
# fpop1014mp                                    {'029'}, {'001'}   True     True
# fpop1517p                                     {'030'}, {'001'}  False     True
# fpop1517mp                                    {'030'}, {'001'}   True     True
# fpop1819p                                     {'031'}, {'001'}  False     True
# fpop1819mp                                    {'031'}, {'001'}   True     True
# fpop20p                                       {'001'}, {'032'}  False     True
# fpop20mp                                      {'001'}, {'032'}   True     True
# fpop21p                                       {'033'}, {'001'}  False     True
# fpop21mp                                      {'033'}, {'001'}   True     True
# fpop2224p                                     {'034'}, {'001'}  False     True
# fpop2224mp                                    {'034'}, {'001'}   True     True
# fpop2529p                                     {'035'}, {'001'}  False     True
# fpop2529mp                                    {'035'}, {'001'}   True     True
# fpop3034p                                     {'036'}, {'001'}  False     True
# fpop3034mp                                    {'036'}, {'001'}   True     True
# fpop3539p                                     {'037'}, {'001'}  False     True
# fpop3539mp                                    {'037'}, {'001'}   True     True
# fpop4044p                                     {'038'}, {'001'}  False     True
# fpop4044mp                                    {'038'}, {'001'}   True     True
# fpop4549p                                     {{'039', '001'}}  False     True
# fpop4549mp                                    {{'039', '001'}}   True     True
# fpop5054p                                     {'040'}, {'001'}  False     True
# fpop5054mp                                    {'040'}, {'001'}   True     True
# fpop5559p                                     {'041'}, {'001'}  False     True
# fpop5559mp                                    {'041'}, {'001'}   True     True
# fpop6061p                                     {'042'}, {'001'}  False     True
# fpop6061mp                                    {'042'}, {'001'}   True     True
# fpop6264p                                     {'043'}, {'001'}  False     True
# fpop6264mp                                    {'043'}, {'001'}   True     True
# fpop6566p                                     {'044'}, {'001'}  False     True
# fpop6566mp                                    {'044'}, {'001'}   True     True
# fpop6769p                                     {'001'}, {'045'}  False     True
# fpop6769mp                                    {'001'}, {'045'}   True     True
# fpop7074p                                     {'046'}, {'001'}  False     True
# fpop7074mp                                    {'046'}, {'001'}   True     True
# fpop7579p                                     {'047'}, {'001'}  False     True
# fpop7579mp                                    {'047'}, {'001'}   True     True
# fpop8084p                                     {'048'}, {'001'}  False     True
# fpop8084mp                                    {'048'}, {'001'}   True     True
# fpop85op                                      {'049'}, {'001'}  False     True
# fpop85omp                                     {'049'}, {'001'}   True     True
# fpop_u18p                {'030', '029', '001', {'028', '027'}}  False     True
# fpop_u18mp               {'030', '029', '001', {'028', '027'}}   True     True
# fpop1824p                {'033', '032'}, '031', '001', {'034'}  False     True
# fpop1824mp               {'033', '032'}, '031', '001', {'034'}   True     True
# fpop2534p                              {'035'}, {'001', '036'}  False     True
# fpop2534mp                             {'035'}, {'001', '036'}   True     True
# fpop3564p    {'038', '041'}, '037', {'039', '042', '043', '...  False     True
# fpop3564mp   {'038', '041'}, '037', {'039', '042', '043', '...   True     True
# fpop65ovp    {'048', '047'}, '045', {'049', '046', '044', '...  False     True
# fpop65ovmp   {'048', '047'}, '045', {'049', '046', '044', '...   True     True
# fpop1834p    {'035', '033', '032'}, '031', '001', {'034', '...  False     True
# fpop1834mp   {'035', '033', '032'}, '031', '001', {'034', '...   True     True
# fpop3544p                              {'038', '037'}, {'001'}  False     True
# fpop3544mp                             {'038', '037'}, {'001'}   True     True
# fpop4564p         {'041'}, {'039', '042', '043', '001', '040'}  False     True
# fpop4564mp        {'041'}, {'039', '042', '043', '001', '040'}   True     True
# mpop_p                                        {'002'}, {'001'}  False     True
# mpop_mp                                       {'002'}, {'001'}   True     True
# mpop_u5p                                      {{'003', '001'}}  False     True
# mpop_u5mp                                     {{'003', '001'}}   True     True
# mpop_5_9p                                     {'004'}, {'001'}  False     True
# mpop_5_9mp                                    {'004'}, {'001'}   True     True
# mpop1014p                                     {'005'}, {'001'}  False     True
# mpop1014mp                                    {'005'}, {'001'}   True     True
# mpop1517p                                     {{'001', '006'}}  False     True
# mpop1517mp                                    {{'001', '006'}}   True     True
# mpop1819p                                     {'007'}, {'001'}  False     True
# mpop1819mp                                    {'007'}, {'001'}   True     True
# mpop20p                                       {'001'}, {'008'}  False     True
# mpop20mp                                      {'001'}, {'008'}   True     True
# mpop21p                                       {'009'}, {'001'}  False     True
# mpop21mp                                      {'009'}, {'001'}   True     True
# mpop2224p                                     {'010'}, {'001'}  False     True
# mpop2224mp                                    {'010'}, {'001'}   True     True
# mpop2529p                                     {'011'}, {'001'}  False     True
# mpop2529mp                                    {'011'}, {'001'}   True     True
# mpop3034p                                     {'012'}, {'001'}  False     True
# mpop3034mp                                    {'012'}, {'001'}   True     True
# mpop3539p                                     {{'013', '001'}}  False     True
# mpop3539mp                                    {{'013', '001'}}   True     True
# mpop4044p                                     {'014'}, {'001'}  False     True
# mpop4044mp                                    {'014'}, {'001'}   True     True
# mpop4549p                                     {'015'}, {'001'}  False     True
# mpop4549mp                                    {'015'}, {'001'}   True     True
# mpop5054p                                     {'001'}, {'016'}  False     True
# mpop5054mp                                    {'001'}, {'016'}   True     True
# mpop5559p                                     {{'017', '001'}}  False     True
# mpop5559mmp                                   {{'017', '001'}}   True     True
# mpop6061p                                     {'001'}, {'018'}  False     True
# mpop6061mp                                    {'001'}, {'018'}   True     True
# mpop6264p                                     {'019'}, {'001'}  False     True
# mpop6264mp                                    {'019'}, {'001'}   True     True
# mpop6566p                                     {'020'}, {'001'}  False     True
# mpop6566mp                                    {'020'}, {'001'}   True     True
# mpop6769p                                     {{'021', '001'}}  False     True
# mpop6769mp                                    {{'021', '001'}}   True     True
# mpop7074p                                     {'022'}, {'001'}  False     True
# mpop7074mp                                    {'022'}, {'001'}   True     True
# mpop7579mp                                    {'023'}, {'001'}   True     True
# mpop8084p                                     {'024'}, {'001'}  False     True
# mpop8084mp                                    {'024'}, {'001'}   True     True
# mpop85op                                      {'025'}, {'001'}  False     True
# mpop85omp                                     {'025'}, {'001'}   True     True
# mpop_u18p                {'006', '005'}, '003', '001', {'004'}  False     True
# mpop_u18mp               {'006', '005'}, '003', '001', {'004'}   True     True
# mpop1824p                {'009', {'008', '001', '010'}, '007'}  False     True
# mpop1824mp               {'009', {'008', '001', '010'}, '007'}   True     True
# mpop2534p                              {'012', '011'}, {'001'}  False     True
# mpop2534mp                             {'012', '011'}, {'001'}   True     True
# mpop3564p    {'014'}, '013', '015', '017', {'018', '019', '...  False     True
# mpop3564mp   {'014'}, '013', '015', '017', {'018', '019', '...   True     True
# mpop65ovp    {'022', '024'}, '020', '025', {'023', '001', '...  False     True
# mpop65ovmp   {'022', '024'}, '020', '025', {'023', '001', '...   True     True
# mpop1834p    {'009', '010', '012'}, {'008', '001', '011', '...  False     True
# mpop1834mp   {'009', '010', '012'}, {'008', '001', '011', '...   True     True
# mpop3544p                              {{'013', '001', '014'}}  False     True
# mpop3544mp                             {{'013', '001', '014'}}   True     True
# mpop4564p         {'017'}, '015', {'018', '019', '001', '016'}  False     True

# %%
#ids, names = c.load_table_censusvars('b01001_population_by_age_gender_acs_m')
keys = list(c.cols_dict['b01001_population_by_age_gender_acs_m'].keys())

# %%
#list(c.cols_dict[tbl_name].keys())

# %%
class WriteTables:
    
    def __init__(self, year='2018'):
        self.year = year
        c = CensusAPI(year)
        self.con, self.cur = c.connect_database('sdvm')
        
    
    def initializeTable(self, tbl_name):
        
        #Grabs the column ids for the specified table
        tbl_dict = column_ids.loc[tbl_name].to_dict(orient='index')
        keys = list(tbl_dict.keys())
        
        default_cols = ['muni_id']
        
        #Initializes final table dataframe with final columns and no rows
        final_table = pd.DataFrame(columns=default_cols + keys)
        
        return final_table
    
    def mapCategories(self, row):
    """ 
        Maps the moe:bool, percent:bool properties of table columns to their category 
        (estimate, moe, percent or moe percent)

        Returns: string
    """
        
        #Gets ['moe', 'percent'] as row
        tpl = tuple(row)
        
        
        if tpl == (False, False): #moe: false, percent: false
            return 'est'
        
        elif tpl == (False, True): #moe: false, percent: true
            return 'pct'
        
        elif tpl == (True, False): #moe: true, percent: false
            return 'moe'
        
        elif tpl == (True, True): #moe: true, percent: true
            return 'moe_pct'
        
        else:
            return None
        

    def populateFullTable(self, tbl_name):
        
        final_table = self.initializeTable(tbl_name)
        
        #Grabs the muni uni, muni names and geoids
        init_table = c.load_geoids()
        
        #Populates raw data from Census Subject Tables
        census_table = c.call_api(tbl_name)
        
        #Convert values to float and also set a lower bound at 0
        census_table.iloc[:, 3:] = census_table.iloc[:, 3:].applymap(lambda x: float(x)).clip(lower=0)
        
        #List of census ids that will be used in the final table
        ids = c.column_ids.loc[tbl_name].to_dict(orient='index')
        
        #List of universe ids for percentage calculations
        col_uni = c.col_uni_dict[tbl_name]
        
        #List of columns with errors
        error_cols = set()
        
        mapped_cols = c.column_ids.loc[tbl_name][['moe', 'percent']].apply(self.mapCategories, axis=1)

        est_cols = mapped_cols[(mapped_cols == 'est')].index.values
        pct_cols = mapped_cols[(mapped_cols == 'pct')].index.values
        moe_cols = mapped_cols[(mapped_cols == 'moe')].index.values
        moe_pct_cols = mapped_cols[(mapped_cols == 'moe_pct')].index.values
        
        
        for i, row in census_table.iterrows(): #Iterate every municipality
            
            muni_id = row.index
            final_table.loc[i, 'muni_id'] = row['MUNI_ID']
            
            #Initialize sets for est, est_pct, moe_est, moe_est_pct
            est, est_pct, moe_est, moe_est_pct = set(), set(), set(), set()
            est_uni = set()
            visited_cols = set()


            est_df = c.column_ids.loc[tbl_name].loc[est_cols]
            for col, est_row in est_df.iterrows():
                
                if col in visited_cols: #Checks if value has already been inserted for column
                    continue
                #print(col)   
                
                try:
                    final_table, visited_cols = self.populateEst(i, col, tbl_name, census_table, final_table, visited_cols)
                    
                except Exception as ex:
                    error_cols.add(col)
                    #print(ex)
                    #display(final_table)
                    continue
                    
                
            pct_df = c.column_ids.loc[tbl_name].loc[pct_cols]
            for col, pct_row in pct_df.iterrows():
                
                if col in visited_cols: #Checks if value has already been inserted for column
                    continue
                    
                try:
                    final_table, visited_cols = self.populateEstP(i, col, tbl_name, census_table, final_table, visited_cols)
                        
                except Exception as ex:
                    error_cols.add(col)

                    #display(final_table)
                    continue
                    #return
            
            moe_df = c.column_ids.loc[tbl_name].loc[moe_cols]
            for col, moe_row in moe_df.iterrows():
                
                if col in visited_cols: #Checks if value has already been inserted for column
                    continue
                    
                try:
                    final_table, visited_cols = self.populateMoe(i, col, tbl_name, census_table, final_table, visited_cols)
                        
                except Exception as ex:
                    error_cols.add(col)

                    #display(final_table)
                    continue
                    #return
            
            moe_pct_df = c.column_ids.loc[tbl_name].loc[moe_pct_cols]
            for col, moe_pct_row in moe_pct_df.iterrows():
                
                if col in visited_cols: #Checks if value has already been inserted for column
                    continue
                    
                try:
                    final_table, visited_cols = self.populateMoeP(i, col, tbl_name, census_table, final_table, visited_cols)
                        
                except Exception as ex:
                    error_cols.add(col)

                    #display(final_table)
                    continue
                    #return
                    
            
        
        self.con.close()   
        final_table = final_table.set_index([final_table['muni_id'] - 1])
        #print("Error found at these columns:" + " ".join(list(error_cols)))
        #print(list(error_cols))
        
        return final_table
    
    def populateEst(self, idx, col, tbl_name, census_table, final_table, visited_cols):
        
        #List of census ids that will be used in the final table
        ids = c.column_ids.loc[tbl_name].to_dict(orient='index')

        
        #Append 'E' to find it in the Census dataframe 
        ids_ = [idx + 'E' for idx in ids[col]['ids']]


        #Find the sum if there's multiple values
        #vals = sum([int(census_table.loc[idx, k]) for k in ids_])

        #Add value to table
        #final_table.loc[idx, col] = vals
        final_table[col] = acs_functions.acs_est
        #Updates the visited columns set
        visited_cols.update(col)
        
        return final_table, visited_cols
        
    def populateEstP(self, idx, col, tbl_name, census_table, final_table, visited_cols):
        
        #List of universe ids for percentage calculations
        col_uni = c.col_uni_dict[tbl_name]
        
        
        
        #Append 'E' (for estimate) to find it in the Census dataframe 
        estimate = [e + 'E' for e in col_uni[col][0]['estimate']]
        universe = [u + 'E' for u in col_uni[col][1]['universe']]

        #Find the sum if there's multiple values
        est_vals = sum([int(census_table.loc[idx, k]) for k in estimate])
        uni_vals = sum([int(census_table.loc[idx, k]) for k in universe])
        
        #Calls the Postgres procedure 'acs_est_pct' and return the result
        self.cur.callproc('acs_est_pct', ([est_vals], [uni_vals]))
        val_out = self.cur.fetchone()

        #Updates value in final table
        final_table.loc[idx, col] = val_out[0]
        
        #Updates the visited columns set
        visited_cols.update(col)
        
        return final_table, visited_cols
            

    
    def populateMoe(self, idx, col, tbl_name, census_table, final_table, visited_cols):
        
        #List of census ids that will be used in the final table
        ids = c.column_ids.loc[tbl_name].to_dict(orient='index')
        
        #Append 'E' or 'M' to find the estimate or moe values in the Census dataframe, respectively
        est_ids = [idx + 'E' for idx in ids[col]['ids']]
        moe_ids = [idx + 'M' for idx in ids[col]['ids']]

        est_vals = [int(census_table.loc[idx, k]) for k in est_ids]
        moe_vals = [int(census_table.loc[idx, k]) for k in moe_ids]


        self.cur.callproc('acs_moe', (est_vals, moe_vals))

        val_out = self.cur.fetchone()
        
        #Add value to table
        final_table.loc[idx, col] = val_out[0]
        visited_cols.update(col)
        
        return final_table, visited_cols

    
    def populateMoeP(self, idx, col, tbl_name, census_table, final_table, visited_cols):
        
        #List of universe ids for percentage calculations
        col_uni = c.col_uni_dict[tbl_name]
        
        col_uni_key = col[:-2] + 'p'
        estimate = [e + 'E' for e in col_uni[col_uni_key][0]['estimate']]
        universe = [u + 'E' for u in col_uni[col_uni_key][1]['universe']]

        moe_est = [e + 'M' for e in col_uni[col_uni_key][0]['estimate']]
        moe_uni = [u + 'M' for u in col_uni[col_uni_key][1]['universe']]

        est_vals = [int(census_table.loc[idx, k]) for k in estimate]
        uni_vals = [int(census_table.loc[idx, k]) for k in universe]

        moe_vals = [int(census_table.loc[idx, k]) for k in moe_est]
        moe_uni_vals = [int(census_table.loc[idx, k]) for k in moe_uni]

        self.cur.callproc('acs_moe_pct', (est_vals, uni_vals, moe_vals, moe_uni_vals))
        val_out = self.cur.fetchone()

        final_table.loc[idx, col] = val_out[0]
        visited_cols.update(col)

        return final_table, visited_cols 
    
    def compareTables(self, tbl_name, df_in):
        
        #Connect to Postgres database 
        self.con, self.cur = c.connect_database('sdvm')
        
        #Get columns at a string list
        keys = list(c.cols_dict[tbl_name].keys())
        cols = ", ".join(keys).replace('mpop5559mmp', 'mpop5559mp')
        
        cols = 'muni_id, ' + cols
        
        query = \
        """
        SELECT {1} from tabular.{0} WHERE acs_year = '2014-18';
        """
        #Get table from Postgres as pandas dataframe
        pg_df = pd.read_sql(query.format(tbl_name, cols), self.con, coerce_float=True)
        pg_df.index = pg_df['muni_id'] - 1
        
        #Casts all values as floats except for the GEO_ID column
        df_in.iloc[:, 1:] = df_in.iloc[:, 1:].astype('float', errors='ignore')
        
        #Removes municipalities from return Postres dataframe that aren't in the comparison dataframe
        pg_df = pg_df[(pg_df['muni_id'].isin(df_in['muni_id'].values))]

        #Ensures that the column names match in both tables
        pg_df = pg_df.reindex(columns=df_in.columns.values)
        
        #Creates comparison table and returns it with the PG dataframe
        comparison_table = pg_df.compare(df_in, align_axis=0)
        
        return pg_df, comparison_table
# Out:
#   File "<ipython-input-155-0bc61189b20b>", line 23
#     """"""
#     ^
# IndentationError: expected an indented block

# %%
p = WriteTables()
# Out:
# Connected to ds

# %%
start = time.time()
df = p.populateFullTable('b01001_population_by_age_gender_acs_m')
end = time.time()
print(end-start)
# Out:
# 430.69747972488403

# %%
len(df.columns)
# Out:
# 382

# %%
pg_df, comparison_table = p.compareTables('b01001_population_by_age_gender_acs_m', df)
# Out:
# Connected to ds

# %%
pg_df.loc[0, 'pop2534mp']
# Out:
# 2.11

# %%
df[['pop8084mp']][:10], pg_df[['pop8084mp']][:10]
# Out:
# (        pop8084mp
#  muni_id
#  0            0.37
#  1            0.32
#  2            0.62
#  3            0.86
#  4            0.79
#  5            1.88
#  6            0.64
#  7            0.28
#  8            0.45
#  9            0.42,
#           pop8084mp
#  muni_id
#  0             0.59
#  1             0.63
#  2             0.77
#  3             1.50
#  4             1.53
#  5             2.46
#  6             1.70
#  7             0.60
#  8             1.15
#  9             1.36)

# %%
comparison_table
# Out:
#               pop20m pop2224m pop85om pop1824m pop3564m pop65ovm pop1834m  \
# muni_id
# 0       self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 1       self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 2       self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 3       self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 4       self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 5       self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 6       self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 7       self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 8       self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 9       self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 10      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 11      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 12      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 13      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 14      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 15      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 16      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 17      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 18      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 19      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 20      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 21      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 22      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 23      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 24      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 25      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 26      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 27      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 28      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 29      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 30      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 31      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 32      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 33      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 34      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 35      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 36      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 37      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 38      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 39      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 40      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 41      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 42      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 43      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 44      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 45      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 46      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 47      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 48      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 49      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 50      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 51      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 52      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 53      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 54      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 55      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 56      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 57      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 58      self     NaN      NaN     NaN    45.01      NaN      NaN    74.46
#         other    NaN      NaN     NaN    43.38      NaN      NaN    73.49
# 59      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 60      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 61      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 62      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 63      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 64      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 65      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 66      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 67      self     NaN       12     NaN    55.15      NaN      NaN    62.42
#         other    NaN    16.97     NaN    53.82      NaN      NaN    61.25
# 68      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 69      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 70      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 71      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 72      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 73      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 74      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 75      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 76      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 77      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 78      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 79      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 80      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 81      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 82      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 83      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 84      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 85      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 86      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 87      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 88      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 89      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 90      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 91      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 92      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 93      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 94      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 95      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 96      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 97      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 98      self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 100     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 101     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 102     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 103     self     NaN    16.97     NaN      NaN      NaN      NaN      NaN
#         other    NaN       12     NaN      NaN      NaN      NaN      NaN
# 104     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 105     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 106     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 107     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 108     self     NaN      NaN     NaN      NaN    18.28      NaN      NaN
#         other    NaN      NaN     NaN      NaN    21.86      NaN      NaN
# 109     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 110     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 111     self     NaN      NaN     NaN    41.59      NaN     38.9    78.12
#         other    NaN      NaN     NaN    39.82      NaN    40.71    77.19
# 112     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 113     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 114     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 115     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 116     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 117     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 118     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 119     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 120     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 121     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 122     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 123     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 124     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 125     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 126     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 127     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 128     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 129     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 130     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 131     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 132     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 133     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 134     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 135     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 136     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 137     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 138     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 139     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 140     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 141     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 142     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 143     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 144     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 145     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 146     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 147     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 148     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 149     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 150     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 151     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 152     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 153     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 154     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 155     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 156     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 157     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 158     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 159     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 160     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 161     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 162     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 163     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 164     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 165     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 166     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 167     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 168     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 169     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 170     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 171     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 172     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 173     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 174     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 175     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 176     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 177     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 178     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 179     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 180     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 181     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 182     self     NaN      NaN     NaN      NaN      NaN    34.13      NaN
#         other    NaN      NaN     NaN      NaN      NaN    31.95      NaN
# 183     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 184     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 185     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 186     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 187     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 188     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 189     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 190     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 191     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 192     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 193     self     NaN      NaN     NaN      NaN      NaN      NaN    36.52
#         other    NaN      NaN     NaN      NaN      NaN      NaN     34.5
# 194     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 195     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 196     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 197     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 198     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 199     self      12      NaN     NaN    20.66      NaN      NaN    24.21
#         other  16.97      NaN     NaN     23.9      NaN      NaN    27.02
# 200     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 201     self     NaN      NaN   16.97      NaN      NaN      NaN      NaN
#         other    NaN      NaN      12      NaN      NaN      NaN      NaN
# 202     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 203     self     NaN      NaN     NaN      NaN      NaN      NaN    36.44
#         other    NaN      NaN     NaN      NaN      NaN      NaN    34.41
# 204     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 205     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 206     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 207     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 208     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 209     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 210     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 211     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 212     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 213     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 214     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 215     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 216     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 217     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 218     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 219     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 220     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 221     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 222     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 223     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 224     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 225     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 226     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 227     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 228     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 229     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 230     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 231     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 232     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 233     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 234     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 235     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 236     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 237     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 238     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 239     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 240     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 241     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 242     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 243     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 244     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 245     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 246     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 247     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 248     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 249     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 250     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 251     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 252     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 253     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 254     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 255     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 256     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 257     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 258     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 259     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 260     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 261     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 262     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 263     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 264     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 265     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 266     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 267     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 268     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 269     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 270     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 271     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 272     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 273     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 274     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 275     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 276     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 277     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 278     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 279     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 280     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 281     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 282     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 283     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 284     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 285     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 286     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 287     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 288     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 289     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 290     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 291     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 292     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 293     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 294     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 295     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 296     self     NaN      NaN     NaN      NaN      NaN    29.15     32.8
#         other    NaN      NaN     NaN      NaN      NaN    31.53    34.93
# 297     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 298     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 299     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 300     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 301     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 302     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 303     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 304     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 305     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 306     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 307     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 308     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 309     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 310     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
#         other    NaN      NaN     NaN      NaN      NaN      NaN      NaN
# 311     self     NaN      NaN     NaN      NaN      NaN      NaN      NaN
# ...
# 211     self        NaN       NaN      1.14       0.52
#         other       NaN       NaN      0.88        NaN
# 212     self        NaN       NaN      0.76       0.84
#         other       NaN       NaN      0.65        NaN
# 213     self        NaN       NaN      1.03       0.28
#         other       NaN       NaN      0.43        NaN
# 214     self        NaN       NaN      1.07       0.45
#         other       NaN       NaN      0.72        NaN
# 215     self        NaN       NaN      1.51       0.38
#         other       NaN       NaN      0.85        NaN
# 216     self        NaN       NaN      1.55       0.83
#         other       NaN       NaN      1.61        NaN
# 217     self        NaN       NaN      0.82       0.38
#         other       NaN       NaN       0.6        NaN
# 218     self        NaN       NaN      1.63       0.46
#         other       NaN       NaN       0.8        NaN
# 219     self        NaN       NaN      1.76       0.36
#         other       NaN       NaN       0.6        NaN
# 220     self        NaN       NaN      2.61        2.6
#         other       NaN       NaN      2.49        NaN
# 221     self        NaN       NaN      0.78       0.65
#         other       NaN       NaN      0.63        NaN
# 222     self        NaN       NaN      1.08       0.47
#         other       NaN       NaN      0.99        NaN
# 223     self        NaN       NaN      2.46       1.41
#         other       NaN       NaN      1.42        NaN
# 224     self        NaN       NaN      1.38        1.9
#         other       NaN       NaN      1.33        NaN
# 225     self        NaN       NaN      0.88       1.01
#         other       NaN       NaN      0.58        NaN
# 226     self        NaN       NaN      1.32       0.42
#         other       NaN       NaN      0.82        NaN
# 227     self        NaN       NaN       1.7       0.57
#         other       NaN       NaN      1.18        NaN
# 228     self        NaN       NaN      1.71       0.28
#         other       NaN       NaN      0.51        NaN
# 229     self        NaN       NaN      1.63       1.37
#         other       NaN       NaN      1.01        NaN
# 230     self        NaN       NaN      1.39       0.49
#         other       NaN       NaN      0.82        NaN
# 231     self        NaN       NaN      1.35       0.59
#         other       NaN       NaN      0.67        NaN
# 232     self        NaN       NaN      1.17       0.68
#         other       NaN       NaN      1.45        NaN
# 233     self        NaN       NaN      1.08        0.7
#         other       NaN       NaN      0.82        NaN
# 234     self        NaN       NaN      1.07       0.82
#         other       NaN       NaN      0.73        NaN
# 235     self        NaN       NaN      1.75       0.32
#         other       NaN       NaN      0.42        NaN
# 236     self        NaN       NaN      2.26        1.1
#         other       NaN       NaN      1.62        NaN
# 237     self        NaN       NaN      0.82       0.72
#         other       NaN       NaN      0.73        NaN
# 238     self        NaN       NaN      1.02       0.33
#         other       NaN       NaN       0.4        NaN
# 239     self        NaN       NaN      0.53       1.15
#         other       NaN       NaN      0.58        NaN
# 240     self        NaN       NaN      1.78       1.19
#         other       NaN       NaN      1.76        NaN
# 241     self        NaN       NaN      2.85       1.45
#         other       NaN       NaN      2.25        NaN
# 242     self        NaN       NaN      1.43        0.2
#         other       NaN       NaN      0.29        NaN
# 243     self        NaN       NaN      1.44       0.42
#         other       NaN       NaN      0.53        NaN
# 244     self        NaN       NaN      1.49       0.56
#         other       NaN       NaN       0.8        NaN
# 245     self        NaN       NaN      1.58       0.34
#         other       NaN       NaN       0.7        NaN
# 246     self        NaN       NaN      1.03       0.67
#         other       NaN       NaN      0.83        NaN
# 247     self        NaN       NaN       1.2       0.31
#         other       NaN       NaN      0.42        NaN
# 248     self        NaN       NaN      1.44       0.91
#         other       NaN       NaN      1.12        NaN
# 249     self        NaN       NaN      0.61       1.09
#         other       NaN       NaN       0.5        NaN
# 250     self        NaN       NaN       0.7       0.34
#         other       NaN       NaN      0.62        NaN
# 251     self        NaN       NaN       3.4       0.82
#         other       NaN       NaN      1.35        NaN
# 252     self        NaN       NaN      2.72       1.43
#         other       NaN       NaN      2.33        NaN
# 253     self        NaN       NaN      2.06       1.02
#         other       NaN       NaN       1.2        NaN
# 254     self        NaN       NaN      1.97       1.93
#         other       NaN       NaN      1.81        NaN
# 255     self        NaN       NaN      0.98       0.96
#         other       NaN       NaN         1        NaN
# 256     self        NaN       NaN      0.33       0.62
#         other       NaN       NaN      0.38        NaN
# 257     self        NaN       NaN       1.2       0.28
#         other       NaN       NaN      0.43        NaN
# 258     self        NaN       NaN      0.93       0.69
#         other       NaN       NaN      0.69        NaN
# 259     self        NaN       NaN      1.29       3.34
#         other       NaN       NaN      1.05        NaN
# 260     self        NaN       NaN      1.37       0.58
#         other       NaN       NaN      0.53        NaN
# 261     self        NaN       NaN       1.7       0.55
#         other       NaN       NaN      0.74        NaN
# 262     self        NaN       NaN      2.27       0.81
#         other       NaN       NaN      2.13        NaN
# 263     self        NaN       NaN      1.59       0.46
#         other       NaN       NaN      0.74        NaN
# 264     self        NaN       NaN      1.12       1.09
#         other       NaN       NaN      0.86        NaN
# 265     self        NaN       NaN      1.24       0.36
#         other       NaN       NaN      0.65        NaN
# 266     self        NaN       NaN      0.68       1.51
#         other       NaN       NaN      0.74        NaN
# 267     self        NaN       NaN      3.12       0.58
#         other       NaN       NaN       1.9        NaN
# 268     self        NaN       NaN      0.97       0.56
#         other       NaN       NaN      0.96        NaN
# 269     self        NaN       NaN       1.3       1.61
#         other       NaN       NaN      1.32        NaN
# 270     self        NaN       NaN      1.15       0.29
#         other       NaN       NaN       0.5        NaN
# 271     self        NaN       NaN      0.82       0.99
#         other       NaN       NaN       0.7        NaN
# 272     self        NaN       NaN      2.17       0.54
#         other       NaN       NaN      0.92        NaN
# 273     self        NaN       NaN      0.89       0.15
#         other       NaN       NaN      0.34        NaN
# 274     self        NaN       NaN       1.3       0.47
#         other       NaN       NaN      0.55        NaN
# 275     self        NaN       NaN      1.11       0.91
#         other       NaN       NaN      0.96        NaN
# 276     self        NaN       NaN      1.08       0.71
#         other       NaN       NaN      0.73        NaN
# 277     self        NaN       NaN       1.1        0.4
#         other       NaN       NaN      0.49        NaN
# 278     self        NaN       NaN      2.13       1.15
#         other       NaN       NaN      1.14        NaN
# 279     self        NaN       NaN      2.03       0.83
#         other       NaN       NaN      1.17        NaN
# 280     self        NaN       NaN      0.87       0.12
#         other       NaN       NaN      0.16        NaN
# 281     self        NaN       NaN      0.84       0.96
#         other       NaN       NaN      0.66        NaN
# 282     self        NaN       NaN      3.35       1.52
#         other       NaN       NaN       2.2        NaN
# 283     self        NaN       NaN      1.88       0.38
#         other       NaN       NaN      0.72        NaN
# 284     self        NaN       NaN      1.53       0.37
#         other       NaN       NaN      0.51        NaN
# 285     self        NaN       NaN      1.66       0.59
#         other       NaN       NaN      1.16        NaN
# 286     self        NaN       NaN      1.18        0.9
#         other       NaN       NaN      0.81        NaN
# 287     self        NaN       NaN      0.91        0.5
#         other       NaN       NaN      0.47        NaN
# 288     self        NaN       NaN      1.59        1.2
#         other       NaN       NaN      1.42        NaN
# 289     self        NaN       NaN      1.18       0.82
#         other       NaN       NaN      0.98        NaN
# 290     self        NaN       NaN      1.47       0.61
#         other       NaN       NaN      0.76        NaN
# 291     self        NaN       NaN      1.22       0.66
#         other       NaN       NaN      0.81        NaN
# 292     self        NaN       NaN      1.03       0.23
#         other       NaN       NaN      0.41        NaN
# 293     self        NaN       NaN      0.93       0.84
#         other       NaN       NaN      0.92        NaN
# 294     self        NaN       NaN      1.45       0.35
#         other       NaN       NaN      0.58        NaN
# 295     self        NaN       NaN      1.33       0.73
#         other       NaN       NaN       1.3        NaN
# 296     self      22.43       NaN      1.83       0.92
#         other     25.44       NaN       1.8        NaN
# 297     self        NaN       NaN      2.77       0.99
#         other       NaN       NaN      1.38        NaN
# 298     self        NaN       NaN      0.72       0.96
#         other       NaN       NaN      0.51        NaN
# 299     self        NaN       NaN       1.9       1.89
#         other       NaN       NaN      2.36        NaN
# 300     self        NaN       NaN      0.72       0.55
#         other       NaN       NaN      0.63        NaN
# 301     self        NaN       NaN      2.77       1.21
#         other       NaN       NaN      2.27        NaN
# 302     self        NaN       NaN      0.71       0.41
#         other       NaN       NaN      0.68        NaN
# 303     self        NaN       NaN      1.02       0.23
#         other       NaN       NaN      0.63        NaN
# 304     self        NaN       NaN      1.38       0.41
#         other       NaN       NaN      0.63        NaN
# 305     self        NaN       NaN      1.13       0.83
#         other       NaN       NaN      1.16        NaN
# 306     self        NaN       NaN      1.88        0.6
#         other       NaN       NaN      0.53        NaN
# 307     self        NaN       NaN      1.16       0.27
#         other       NaN       NaN      0.35        NaN
# 308     self        NaN       NaN      1.39       0.68
#         other       NaN       NaN      0.99        NaN
# 309     self        NaN       NaN      1.81       0.63
#         other       NaN       NaN      0.93        NaN
# 310     self        NaN       NaN      1.71       0.88
#         other       NaN       NaN      1.63        NaN
# 311     self        NaN       NaN      1.18       1.65
#         other       NaN       NaN      0.97        NaN
# 312     self        NaN       NaN       NaN       1.61
#         other       NaN       NaN       NaN        NaN
# 313     self        NaN       NaN      1.57       0.27
#         other       NaN       NaN      0.68        NaN
# 314     self        NaN       NaN      2.04        0.5
#         other       NaN       NaN      0.85        NaN
# 315     self        NaN       NaN      0.98       0.55
#         other       NaN       NaN      0.52        NaN
# 316     self        NaN       NaN      0.95        0.3
#         other       NaN       NaN      0.38        NaN
# 317     self        NaN       NaN      1.76       1.74
#         other       NaN       NaN      1.29        NaN
# 318     self        NaN       NaN       NaN       0.92
#         other       NaN       NaN       NaN        NaN
# 319     self        NaN       NaN      1.58        0.6
#         other       NaN       NaN      1.14        NaN
# 320     self        NaN       NaN      0.92       0.55
#         other       NaN       NaN      0.59        NaN
# 321     self        NaN       NaN      1.04        0.4
#         other       NaN       NaN      0.82        NaN
# 322     self        NaN       NaN      1.82       0.77
#         other       NaN       NaN      1.71        NaN
# 323     self        NaN       NaN      0.57       0.65
#         other       NaN       NaN       0.6        NaN
# 324     self        NaN       NaN      1.21       0.38
#         other       NaN       NaN      0.53        NaN
# 325     self        NaN       NaN      1.82       1.56
#         other       NaN       NaN       1.4        NaN
# 326     self     162.04       NaN      2.54       0.44
#         other    162.49       NaN      2.49        NaN
# 327     self        NaN       NaN       1.6        0.3
#         other       NaN       NaN      0.77        NaN
# 328     self        NaN       NaN      1.35       0.25
#         other       NaN       NaN      0.44        NaN
# 329     self        NaN       NaN      0.84       0.44
#         other       NaN       NaN      0.56        NaN
# 330     self        NaN       NaN      0.98        0.7
#         other       NaN       NaN      0.77        NaN
# 331     self        NaN       NaN      1.55        0.8
#         other       NaN       NaN      1.34        NaN
# 332     self        NaN       NaN      2.22       0.62
#         other       NaN       NaN      1.22        NaN
# 333     self        NaN       NaN      1.21       0.54
#         other       NaN       NaN       0.7        NaN
# 334     self        NaN       NaN      2.29       0.49
#         other       NaN       NaN      0.96        NaN
# 335     self        NaN       NaN       1.2        0.3
#         other       NaN       NaN      0.37        NaN
# 336     self        NaN       NaN      1.05       1.02
#         other       NaN       NaN      0.87        NaN
# 337     self        NaN       NaN      1.11       0.45
#         other       NaN       NaN      0.59        NaN
# 338     self        NaN       NaN       1.6       0.65
#         other       NaN       NaN      0.82        NaN
# 339     self        NaN       NaN      2.01       1.34
#         other       NaN       NaN      1.27        NaN
# 340     self        NaN       NaN      1.47       0.66
#         other       NaN       NaN      0.69        NaN
# 341     self        NaN       NaN      1.32       0.33
#         other       NaN       NaN      0.61        NaN
# 342     self        NaN       NaN      1.78       0.48
#         other       NaN       NaN      1.12        NaN
# 343     self        NaN       NaN      1.68       0.34
#         other       NaN       NaN      0.55        NaN
# 344     self        NaN       NaN       NaN       0.47
#         other       NaN       NaN       NaN        NaN
# 345     self        NaN       NaN      1.45        0.4
#         other       NaN       NaN      0.73        NaN
# 346     self        NaN       NaN      1.48       0.36
#         other       NaN       NaN      0.54        NaN
# 347     self        NaN       NaN      1.07       0.15
#         other       NaN       NaN       0.2        NaN
# 348     self        NaN       NaN      1.09       0.63
#         other       NaN       NaN      0.83        NaN
# 349     self        NaN       NaN      1.34       0.52
#         other       NaN       NaN      0.57        NaN
# 350     self        NaN       NaN      2.82       0.41
#         other       NaN       NaN      0.82        NaN

# %% [markdown]
# error_dict = {}
# cols = comparison_table.columns
#
# for idx, row in comparison_table.iterrows():
#     #print(idx)
#     #break
#     error_dict[str(idx)] = [i for i in cols if not np.isnan(comparison_table[i].loc[idx])]
#
# error_dict
# #[i for i in cols if not np.isnan(list(comparison_table[i].values)).all()]

# %% [markdown]
# # Appendix
#
# ## class: CensusAPI
#     - Initializes the Census API parameters
#     - Gets Census ids that correspond to different columns names
#    ### functions:
#    ### variables:
#
# ## class: WriteTables
#    ### functions:
#    ### variables:
