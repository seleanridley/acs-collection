# %%
import psycopg2
from config import config
import pandas as pd
import os
import pickle
import re
import numpy as np

# %%
#Postgres Connection Setup
def connect(server):
    """ Connect to the PostgreSQL database server """
    conn = None
    try:
        # read connection parameters
        params = config(section=server)

        # connect to the PostgreSQL server
        #print('Connecting to the PostgreSQL database...')
        conn = psycopg2.connect(**params)

        # create a cursor
        cur = conn.cursor()
        
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
    
    return cur

def close():
    if conn is not None:
        conn.close()
        print('Database connection closed.')

# %%
def get_acs_table_metadata():
    """
    Searches existing tables in metadata schema that are sourced from the ACS to aggregate census variables and titles.
    
    Returns:
    -------------
    
    """
    
    #Establish connection to Postgres server
    cur = connect('sdvm') 

    #Matches on tables in metadata schema that include the string 'acs'.
    cur.execute(
        """
        SELECT table_name
        FROM information_schema.tables
        WHERE table_schema = 'metadata' AND table_name LIKE '%acs_m'
        ORDER BY table_name;
        """)

    #Assigns query results
    table_names = cur.fetchall()

    table_meta = pd.DataFrame(columns=['title', 'tbl_name', 'tbl_num', 'geography'])
    
    for idx, table in enumerate(table_names): 
        proc_table = table[0].replace("'", '')
        
        query = \
        """
        SELECT details 
        FROM metadata.{0}
        WHERE orderid IN (2, 4, 5, 6);
        """.format(proc_table)
        
        cur.execute(query)
        metadata = cur.fetchall()
        try:
            table_meta.loc[idx] = [x[0] for x in metadata]
        except ValueError:
            print("Error at " + str(table_names[idx]))
            continue

    cur.close()
    return table_meta

# %%
table_meta = get_acs_table_metadata()
# Out:
# Error at ('b16002_hh_linguistic_isolation_acs_m',)

# %%
column_ids = pd.read_csv('column_ids.csv', skipinitialspace=True)
column_ids['ids'] = column_ids['ids'].apply(lambda x: set(str(x).zfill(3).replace(' ', '').split(',')))

# %%
column_ids.columns = ['table', 'col', 'group', 'ids', 'moe', 'percent']

# %%
#Uncomment to save new pickle of table_meta Dataframe
#pickle.dump(table_meta, open('pickles/table_meta.p', 'wb'))

# %%
#census_vars = pd.read_json('census_variables/variables.json', orient='index')
#census_vars

# %%
set(table_meta['title'])
# Out:
# {'Aggregate Gross Rent by Units in Structure',
#  'Aggregate travel time to work (in minutes) of workers by travel time',
#  'American Indian And Alaska Native Alone Population by Age and Gender',
#  'Asian Alone Population by Age and Gender',
#  'Average Household Size',
#  'Black Or African American Alone Population by Age and Gender',
#  'Children in Poverty by Family Type',
#  'Citizenship Status by Native and Foreign born',
#  'Citizenship Status by Native and Foreign born with Place of Birth',
#  'Citizenship and Foreign Born by Age and Gender',
#  'Contract Rent',
#  'Disability Status by Age and Gender',
#  'Disability Status by Age and Race/Ethnicity',
#  'Disability Status by Difficulty Type',
#  'Educational Attainment Overall and by Gender',
#  'Educational Attainment by Age',
#  'Educational Attainment by Employment',
#  'Educational Attainment by Place of Birth',
#  'Educational Attainment by Race/Ethinicity',
#  'Employment',
#  'Employment Status by Disability Status',
#  'Employment Status by Race and Age',
#  'Families Ratio Of Income To Poverty Level',
#  'Families receiving Food Stamps/SNAP by presence of Family Type',
#  'Families with Children in Poverty by Family Type and Race',
#  'Geographic Mobility: Current Residence by Age',
#  'Geographic Mobility: In Migration',
#  'Geographic Mobility: In Migration by Age',
#  'Geographic Mobility: Out Migration',
#  'Geographic Mobility: Out Migration by Age',
#  'Gini Index',
#  'Grandparents living with/responsible for own Grandchildren by Poverty',
#  'Health Insurance Coverage by Disability Status',
#  'Health Insurance Coverage by Gender and Age',
#  'Hearing Difficulty by Age',
#  'Hispanic Or Latino Population by Age and Gender',
#  'Household Income',
#  'Household Income by Age',
#  'Household Income by Race',
#  'Household Income by Tenure',
#  'Household Occupancy by Race',
#  'Household Size by Vehicles Available',
#  'Household Tenure by Age',
#  'Households receiving Food Stamps/SNAP by Race',
#  'Households receiving Food Stamps/SNAP by presence of children and household type',
#  'Households receiving Food Stamps/SNAP by presence of people 60 years or over',
#  'Households with Children Under 18',
#  'Households with Seniors',
#  'Housing Cost Burden by Age',
#  'Housing Cost Burden by Income',
#  'Housing Cost Burden by Tenure',
#  'Housing Cost Burden for Renters by Income',
#  'Housing Tenure by Heating Fuel',
#  'Housing Tenure by Year Built',
#  'Language Spoken at Home by Ability to Speak English',
#  'Means of Transporation to Work by Travel Time',
#  'Means of Transportation to work by Gender',
#  'Means of Transportation to work by Residence by Race',
#  'Median Age by Gender and Race/Ethnicity',
#  'Median Household Income by Family Type',
#  'Median Household Income by Race',
#  'Median Household Income by Tenure',
#  'Median Household Income for Households receiving Food Stamps/SNAP',
#  'Median Rent by Number of Bedrooms',
#  'Median Value by Mortgage Status',
#  'Mortgage Status for Households with Aggregate Values',
#  'Native Hawaiian And Other Pacific Islander Alone Population by Age and Gender',
#  'Nativity and English Ability by Race',
#  None,
#  'POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE',
#  'Per Capita Income',
#  'Place of Birth for Foreign Born Population',
#  'Population by Age and Gender',
#  'Population by Race/Ethnicity',
#  'Population in Poverty',
#  'Poverty by Age and Gender',
#  'Poverty by Household Type',
#  'Poverty by Race and Age',
#  'Public Assistance',
#  'Rent',
#  'Reported Ancestry',
#  'Some Other Race Alone Population by Age and Gender',
#  'Tenure by Housing Units',
#  'Time Period of Naturalization',
#  'Transportation to Work by Residence',
#  'Transportation to Work by Residence by Age',
#  'Transportation to Work from Workplace ',
#  'Travel Time to Work',
#  'Travel Time to Work by Place of Work ',
#  'Two Or More Races Population by Age and Gender',
#  'Units in Structures',
#  'Unmarried Households by Gender',
#  'Vehicles by Households',
#  'Vehicles by Households with aggregations',
#  'Vision Difficulty by Age',
#  'White Alone Not Hispanic Or Latino Population Population by Age and Gender',
#  'White Alone Population by Age and Gender '}

# %%
len(list(table_meta['tbl_name']))
# Out:
# 102

# %%
def get_col_names(sql_name, visited_ids, lines):
    #IDEA: continously add ids from visited_ids set and use "as" as a delimiter. Get all ids that came before delimiter
    #save what comes after delimiter as a hash map key and what comes before as values.
    
    hash_map = {}
    hash_map[sql_name] = {}
    list_ = []
    for line in lines:
        if "SELECT" in line:
            continue
        if "e._" in line:
            there = re.search('e._(.+?)]', line)
            if there:
                ids = [x for x in re.findall(r'\d+', there.group()) if len(x) == 3]
                list_ += ids
        
        #Once "as" is in line, hash the list of ids with the key of the term after the "as"
        if "as" in line: 
            there2 = re.search('as (.+?),', line)
            
            if there2:
                col_name = there2.group(1)
                if col_name.endswith(('m', 'me', 'mep')):
                    hash_map[sql_name][col_name] = {'ids':set(list_), 'moe': True}
                else:
                    hash_map[sql_name][col_name] = {'ids':set(list_), 'moe': False}  
                    
                if col_name.endswith(('p')):
                    hash_map[sql_name][col_name]['percent'] = True
                else:
                    hash_map[sql_name][col_name]['percent'] = False
            list_ = []
                
    return hash_map

# %%
list(table_meta['tbl_name'])
# Out:
# ['b01001_population_by_age_gender_acs_m',
#  'b01001a_whi_population_by_age_gender_acs_m',
#  'b01001b_aa_population_by_age_gender_acs_m',
#  'b01001c_na_population_by_age_gender_acs_m',
#  'b01001d_as_population_by_age_gender_acs_m',
#  'b01001e_pi_population_by_age_gender_acs_m',
#  'b01001f_oth_population_by_age_gender_acs_m',
#  'b01001g_mlt_population_by_age_gender_acs_m',
#  'b01001h_nhw_population_by_age_gender_acs_m',
#  'b01001i_lat_population_by_age_gender_acs_m',
#  'b01002_med_age_acs_m',
#  'b03002_race_ethnicity_acs_m',
#  'b04001_first_reported_ancestry_acs_m',
#  'b04006_reported_ancestry_acs_m',
#  'b05002_citizenship_nativity_acs_m',
#  'b05002_place_of_birth_citizenship_nativity_acs_m',
#  'b05003_citizenship_nativity_by_age_gender_acs_m',
#  'b05006_foreign_born_place_of_birth_acs_m',
#  'b05011_naturalization_by_year_acs_m',
#  'b06009_educational_attainment_by_placeofbirth_acs_m',
#  'b07001_geomobility_in_migration_by_age_acs_m',
#  'b07001_geomobility_migration_curr_res_by_age_acs_m',
#  'b07204_geomobility_in_migration_acs_m',
#  'b07401_geomobility_out_migration_by_age_acs_m',
#  'b07403_geomobility_out_migration_acs_m',
#  'b08006_means_transportation_to_work_by_residence_gender_acs_m',
#  'b08101_means_transportation_to_work_by_residence_age_acs_m',
#  'b08105_means_transportation_to_work_by_residence_race_acs_m',
#  'b08134_means_by_traveltime_to_work_acs_m',
#  'b08135_agg_traveltime_to_work_acs_m',
#  'b08201_hhsize_by_vehicles_acs_m',
#  'b08301_means_transportation_to_work_by_residence_acs_m',
#  'b08303_traveltime_to_work_by_residence_acs_m',
#  'b08601_means_transportation_to_work_by_workplace_acs_m',
#  'b08603_traveltime_to_work_by_placeofwork_acs_m',
#  'b10059_grandparents_grandkids_by_poverty_acs_m',
#  'b11005_hh_with_kids_acs_m',
#  'b11007_hh_with_seniors_acs_m',
#  'b11009_unmarried_partners_hh_acs_m',
#  'b15001_educational_attainment_by_age_acs_m',
#  'b15002_educational_attainment_acs_m',
#  'b16004_home_language_english_ability_acs_m',
#  'b16005_nativity_english_ability_by_race_acs_m',
#  'b17001_poverty_by_age_gender_acs_m',
#  'b17001_poverty_by_population_acs_m',
#  'Economy',
#  'b17006_child_poverty_by_familytype_acs_m',
#  'b17010_families_with_children_in_poverty_race_acs_m',
#  'b17017_poverty_by_hh_type_acs_m',
#  'b17020_poverty_by_race_age_acs_m',
#  'b17026_income_to_poverty_by_families_acs_m',
#  'b18101_disability_by_gender_age_acs_bm',
#  'b18101_thru_b18107_disability_status_acs_m',
#  'b18101ai_disability_by_age_race_acs_m',
#  'b18102_hearing_difficulty_by_age_acs_m',
#  'b18103_vision_difficulty_by_age_acs_m',
#  'b18135_health_insurance_by_disability_status_acs_m',
#  'b18140_median_earning_by_disability_status_acs_m',
#  'b19001_hh_income_acs_m',
#  'b19001_hh_income_race_acs_m',
#  'b19013_b19113_b19202_mhi_fam_acs_m',
#  'b19013_mhi_race_acs_m',
#  'b19037_hh_income_by_age_acs_m',
#  'b19037_hh_income_by_age_race_acs_m',
#  'b19058_public_assist_acs_m',
#  'b19083_gini_index_acs_m',
#  'b19301_per_capita_income_acs_m',
#  'b22001_hh_foodstamps_snap_60yrs_acs_m',
#  'b22002_hh_foodstamps_snap_hhtype_kids_acs_m',
#  'b22003_b22005_hh_foodstamps_snap_by_race_acs_m',
#  'b22007_fam_foodstamps_snap_famtype_acs_m',
#  'b22008_mhi_foodstamps_snap_acs_m',
#  'b23006_educational_attainment_by_laborforce_acs_m',
#  'b23025_employment_acs_m',
#  'b25002_b25003_hu_occupancy_by_tenure_race_acs_m',
#  'b25007_hh_tenure_by_age_acs_m',
#  'b25010_avg_hhsize_by_tenure_acs_m',
#  'b25024_hu_units_in_structure_acs_m',
#  'b25031_median_rent_by_bedrooms_acs_m',
#  'b25032_hu_tenure_by_units_acs_m',
#  'b25044_hu_vehicles_acs_m',
#  'b25046_b25044_b01003_hh_vehicle_ownership_acs_m',
#  'b25056_b25058_contract_rent_acs_m',
#  'b25063_b25064_b25065_rent_acs_m',
#  None,
#  'b25065_b25066_aggregate_rent_by_units_acs_m',
#  'b25072_b25093_costburden_by_age_acs_m',
#  'b25074_costburden_renters_by_income_acs_m',
#  'b25081_b25082_b25089_b25090_mortgage_status_aggregate_acs_m',
#  'b25091_b25070_costburden_acs_m',
#  'b25097_median_value_by_mortgage_status_acs_m',
#  'b25106_costburden_by_income_acs_m',
#  'b25117_hu_tenure_by_fuel_acs_m',
#  'b25118_hh_income_by_tenure_acs_m',
#  'b25119_mhi_tenure_acs_m',
#  'b25127_hu_tenure_year_built_units_acs_m',
#  'b27001_healthinsurance_by_gender_age_acs_m',
#  'c15002_educational_attainment_by_race_acs_m',
#  'c18120_emp_status_by_disability_status_acs_m',
#  'c18130_poverty_status_by_disability_status_acs_m',
#  'c23002_employment_by_race_age_acs_m',
#  'demo_foreign_born_place_of_birth_acs_m']

# %%
uni_dict = []
root = 'K:\DataServices\Code\SQL\ACS\Tables'
#for root, dir, files in os.walk('K:\DataServices\Code\SQL\ACS\Tables', topdown=False):
for file in os.listdir(root):   
    name = file
    name_wo_ext = name[:-4]
    group = name_wo_ext[:6]
    if name_wo_ext not in list(table_meta['tbl_name']):
        continue
    if name.endswith(".sql"):
        start, e_start, m_start = False, False, False
        moe, percent = False, False
        
        with open(os.path.join(root, name)) as sql_file:
            lines = sql_file.readlines()
            visited_cols = set()
            f = ''
            temp_dict = {'estimate': [], 'universe': []}
            for i, line in enumerate(lines):


                if('acs_est_pct(' in line):
                    start = True
                    moe, percent = False, True
                    
                if('acs_moe_pct(' in line):
                    m_start = True
                    f = f.split('acs_moe_pct')[-1]
                    moe, percent = True, True
                    
                if('muni_sum_est_pct(' in line):
                    start = True
                    moe, percent = False, True
                    
                if('acs_est(' in line):
                    e_start = True
                    moe, percent = False, False
                    
                if('acs_moe(' in line):
                    e_start = True
                    moe, percent = True, False
                    
                    
                if start or e_start or m_start:
                    f += line

                if (f.count(']') == 1 and e_start) or (f.count(']') == 2 and e_start): #est or moe
                    e_start = False
                    if 'as' not in f and 'as' in lines[i+1]:

                        #Get strings within square brackets
                        w_bracs = re.findall(r'\[.*?\]', f+lines[i+1])
                        try:
                            estimate = [w_bracs[0]] 
                        except:
                            continue

                        col = re.findall(r'as (.+?),', lines[i+1])
                        if isinstance(col, list) and len(col) > 0:
                            col = col[0]
                            if isinstance(col, list): col = '' 

                    else:
                        w_bracs = re.findall(r'\[.*?\]', f)
                        try:
                            estimate = [w_bracs[0]] 
                        except:
                            continue

                        col = re.findall(r'as (.+?),', f)
                        if isinstance(col, list) and len(col) > 0:
                            col = col[0]

                        if isinstance(col, list): 
                            col = ''

                    final_list = []

                    if col not in visited_cols:
                        visited_cols.add(col)
                    else:
                        continue

                    #Split any strings with commas
                    for idx, s in enumerate(estimate):
                        if ',' in s:
                            new_strings = s.split(',')
                            estimate.extend(new_strings)
                            estimate.pop(idx)
                        temp_dict['estimate'].append(''.join([x for x in estimate[idx] if x.isdigit()])[-3:])


                    t = {'table': name_wo_ext, 'group': group, 'col': col, 'moe': moe, 'percent': percent}
                    t.update(temp_dict)
                    uni_dict.append(t)
                    temp_dict = {'estimate': [], 'universe': []}

                    f = ''                    

                if (f.count(']') == 2 and start) or (f.count(']') == 4 and m_start):
                    start = False
                    m_start = False     
                    if 'as' not in f and 'as' in lines[i+1]:
                        #Get strings within square brackets
                        w_bracs = re.findall(r'\[.*?\]', f+lines[i+1])
                        col = re.findall(r'as (.+?),', lines[i+1])
                        
                        if isinstance(col, list) and len(col) > 0:
                            col = col[0]

                        if isinstance(col, list): 
                            col = ''

                        try: 
                            estimate = [w_bracs[0]] 
                            universe = [w_bracs[1]] 
                        except:
                            continue
                            
                        if(f.count(']') == 4):
                            print(col, '\t', f+lines[i+1], '\n -----END-----')
                        
                    else:
                        w_bracs = re.findall(r'\[.*?\]', f)

                        col = re.findall(r'as (.+?),', f)
                        if isinstance(col, list) and len(col) > 0:
                            col = col[0]

                        if isinstance(col, list): 
                            col = ''
                        try:
                            estimate = [w_bracs[0]] 
                            universe = [w_bracs[1]] 
                        except:
                            continue
                        if(f.count(']') == 4):
                            print(col, '\t', f, '\n -----END-----')
                            
                    final_list = []

                    if col not in visited_cols and not isinstance(col, list):
                        visited_cols.add(col)
                    else:
                        continue

                    #Split any strings with commas
                    for idx, s in enumerate(estimate):
                        if ',' in s:
                            new_strings = s.split(',')
                            estimate.extend(new_strings)
                            estimate.pop(idx)
                        temp_dict['estimate'].append(''.join([x for x in estimate[idx] if x.isdigit()])[-3:])

                    for idx, s in enumerate(universe):
                        if ',' in s:
                            new_strings = s.split(',')
                            universe.extend(new_strings)
                            universe.pop(idx)
                        temp_dict['universe'].append(''.join([x for x in universe[idx] if x.isdigit()])[-3:])


                    t = {'table': name_wo_ext, 'group': group, 'col': col, 'moe': moe, 'percent': percent}
                    t.update(temp_dict)
                    uni_dict.append(t)
                    temp_dict = {'estimate': [], 'universe': []}

                    f = ''                    
        sql_file.close()
# Out:
# pop_u5mp 	 acs1418.acs_moe_pct(
# 	array[e._003,e._018], --estimate
# 	array[e._001], --universe estimate
# 	array[m._003,m._018], --moe
# 	array[m._001]  --universe moe
# 	)as pop_u5mp,
#
#  -----END-----
# pop_5_9mp 	 acs1418.acs_moe_pct(
# 	array[e._004,e._019], --estimate
# 	array[e._001], --universe estimate
# 	array[m._004,m._019], --moe
# 	array[m._001]  --universe moe
# 	)as pop_5_9mp,
#
#  -----END-----
# pop1014mp 	 acs1418.acs_moe_pct(
# 	array[e._005,e._020], --estimate
# 	array[e._001], --universe estimate
# 	array[m._005,m._020], --moe
# 	array[m._001]  --universe moe
# 	)as pop1014mp,
#
#  -----END-----
# pop1517mp 	 acs1418.acs_moe_pct(
# 	array[e._006,e._021], --estimate
# 	array[e._001], --universe estimate
# 	array[m._006,m._021], --moe
# 	array[m._001]  --universe moe
# 	)as pop1517mp,
#
#  -----END-----
# pop1819mp 	 acs1418.acs_moe_pct(
# 	array[e._007,e._022], --estimate
# 	array[e._001], --universe estimate
# 	array[m._007,m._022], --moe
# 	array[m._001]  --universe moe
# 	)as pop1819mp,
#
#  -----END-----
# pop2024mp 	 acs1418.acs_moe_pct(
# 	array[e._008,e._023], --estimate
# 	array[e._001], --universe estimate
# 	array[m._008,m._023], --moe
# 	array[m._001]  --universe moe
# 	)as pop2024mp,
#
#  -----END-----
# pop2529mp 	 acs1418.acs_moe_pct(
# 	array[e._009,e._024], --estimate
# 	array[e._001], --universe estimate
# 	array[m._009,m._024], --moe
# 	array[m._001]  --universe moe
# 	)as pop2529mp,
#
#  -----END-----
# pop3034mp 	 acs1418.acs_moe_pct(
# 	array[e._010,e._025], --estimate
# 	array[e._001], --universe estimate
# 	array[m._010,m._025], --moe
# 	array[m._001]  --universe moe
# 	)as pop3034mp,
#
#  -----END-----
# pop3544mp 	 acs1418.acs_moe_pct(
# 	array[e._011,e._026], --estimate
# 	array[e._001], --universe estimate
# 	array[m._011,m._026], --moe
# 	array[m._001]  --universe moe
# 	)as pop3544mp,
#
#  -----END-----
# pop4554mp 	 acs1418.acs_moe_pct(
# 	array[e._012,e._027], --estimate
# 	array[e._001], --universe estimate
# 	array[m._012,m._027], --moe
# 	array[m._001]  --universe moe
# 	)as pop4554mp,
#
#  -----END-----
# pop5564mp 	 acs1418.acs_moe_pct(
# 	array[e._013,e._028], --estimate
# 	array[e._001], --universe estimate
# 	array[m._013,m._028], --moe
# 	array[m._001]  --universe moe
# 	)as pop5564mp,
#
#  -----END-----
# pop6574mp 	 acs1418.acs_moe_pct(
# 	array[e._014,e._029], --estimate
# 	array[e._001], --universe estimate
# 	array[m._014,m._029], --moe
# 	array[m._001]  --universe moe
# 	)as pop6574mp,
#
#  -----END-----
# pop7584mp 	 acs1418.acs_moe_pct(
# 	array[e._015,e._030], --estimate
# 	array[e._001], --universe estimate
# 	array[m._015,m._030], --moe
# 	array[m._001]  --universe moe
# 	)as pop7584mp,
#
#  -----END-----
# pop85omp 	 acs1418.acs_moe_pct(
# 	array[e._016,e._031], --estimate
# 	array[e._001], --universe estimate
# 	array[m._016,m._031], --moe
# 	array[m._001]  --universe moe
# 	)as pop85omp,
#
#  -----END-----
# pop_u18mp 	 acs1418.acs_moe_pct(
# 	array[e._003,e._004,e._005,e._006,e._018,e._019,e._020,e._021], --estimate
# 	array[e._001], --universe estimate
# 	array[m._003,m._004,m._005,m._006,m._018,e._019,e._020,e._021], --moe
# 	array[m._001]  --universe moe
# 	)as pop_u18mp,
#
#  -----END-----
# pop1824mp 	 acs1418.acs_moe_pct(
# 	array[e._007,e._008,e._022,e._023], --estimate
# 	array[e._001], --universe estimate
# 	array[m._007,m._008,m._022,m._023], --moe
# 	array[m._001]  --universe moe
# 	)as pop1824mp,
#
#  -----END-----
# pop2534mp 	 acs1418.acs_moe_pct(
# 	array[e._009,e._010,e._024,e._025], --estimate
# 	array[e._001], --universe estimate
# 	array[m._009,m._010,m._024,m._025], --moe
# 	array[m._001]  --universe moe
# 	)as pop2534mp,
#
#  -----END-----
# pop3564mp 	 acs1418.acs_moe_pct(
# 	array[e._011,e._012,e._013,e._026,e._027,e._028], --estimate
# 	array[e._001], --universe estimate
# 	array[m._011,m._012,m._013,m._026,m._027,m._028], --moe
# 	array[m._001]  --universe moe
# 	)as pop3564mp,
#
#  -----END-----
# pop65ovmp 	 acs1418.acs_moe_pct(
# 	array[e._014,e._015,e._016,e._029,e._030,e._031], --estimate
# 	array[e._001], --universe estimate
# 	array[m._014,m._015,m._016,m._029,m._030,m._031], --moe
# 	array[m._001]  --universe moe
# 	)as pop65ovmp,
#
#  -----END-----
# pop1834mp 	 acs1418.acs_moe_pct(
# 	array[e._007,e._008,e._009,e._010,e._022,e._023,e._024,e._025], --estimate
# 	array[e._001], --universe estimate
# 	array[m._007,m._008,m._009,m._010,m._022,m._023,m._024,m._025],
# 	array[m._001]  --universe moe
# 	) as pop1834mp,
#
#  -----END-----
# pop4564mp 	 acs1418.acs_moe_pct(
# 	array[e._012,e._013,e._027,e._028], --estimate
# 	array[e._001], --universe estimate
# 	array[m._012,m._013,m._027,m._028],
# 	array[m._001]  --universe moe
# 	) as pop4564mp,
#
#  -----END-----
# fpop_mp 	 acs1418.acs_moe_pct(
# 	array[e._017], --estimate
# 	array[e._001], --universe estimate
# 	array[m._017], --moe
# 	array[m._001]  --universe moe
# 	)as fpop_mp,
#
#  -----END-----
# fpop_u5mp 	 acs1418.acs_moe_pct(
# 	array[e._018], --estimate
# 	array[e._001], --universe estimate
# 	array[m._018], --moe
# 	array[m._001]  --universe moe
# 	)as fpop_u5mp,
#
#  -----END-----
# fpop_5_9mp 	 acs1418.acs_moe_pct(
# 	array[e._019], --estimate
# 	array[e._001], --universe estimate
# 	array[m._019], --moe
# 	array[m._001]  --universe moe
# 	)as fpop_5_9mp,
#
#  -----END-----
# fpop1014mp 	 acs1418.acs_moe_pct(
# 	array[e._020], --estimate
# 	array[e._001], --universe estimate
# 	array[m._020], --moe
# 	array[m._001]  --universe moe
# 	)as fpop1014mp,
#
#  -----END-----
# fpop1517mp 	 acs1418.acs_moe_pct(
# 	array[e._021], --estimate
# 	array[e._001], --universe estimate
# 	array[m._021], --moe
# 	array[m._001]  --universe moe
# 	)as fpop1517mp,
#
#  -----END-----
# fpop1819mp 	 acs1418.acs_moe_pct(
# 	array[e._022], --estimate
# 	array[e._001], --universe estimate
# 	array[m._022], --moe
# 	array[m._001]  --universe moe
# 	)as fpop1819mp,
#
#  -----END-----
# fpop2024mp 	 acs1418.acs_moe_pct(
# 	array[e._023], --estimate
# 	array[e._001], --universe estimate
# 	array[m._023], --moe
# 	array[m._001]  --universe moe
# 	)as fpop2024mp,
#
#  -----END-----
# fpop2529mp 	 acs1418.acs_moe_pct(
# 	array[e._024], --estimate
# 	array[e._001], --universe estimate
# 	array[m._024], --moe
# 	array[m._001]  --universe moe
# 	)as fpop2529mp,
#
#  -----END-----
# fpop3034mp 	 acs1418.acs_moe_pct(
# 	array[e._025], --estimate
# 	array[e._001], --universe estimate
# 	array[m._025], --moe
# 	array[m._001]  --universe moe
# 	)as fpop3034mp,
#
#  -----END-----
# fpop3544mp 	 acs1418.acs_moe_pct(
# 	array[e._026], --estimate
# 	array[e._001], --universe estimate
# 	array[m._026], --moe
# 	array[m._001]  --universe moe
# 	)as fpop3544mp,
#
#  -----END-----
# fpop4554mp 	 acs1418.acs_moe_pct(
# 	array[e._027], --estimate
# 	array[e._001], --universe estimate
# 	array[m._027], --moe
# 	array[m._001]  --universe moe
# 	)as fpop4554mp,
#
#  -----END-----
# fpop5564mp 	 acs1418.acs_moe_pct(
# 	array[e._028], --estimate
# 	array[e._001], --universe estimate
# 	array[m._028], --moe
# 	array[m._001]  --universe moe
# 	)as fpop5564mp,
#
#  -----END-----
# fpop6574mp 	 acs1418.acs_moe_pct(
# 	array[e._029], --estimate
# 	array[e._001], --universe estimate
# 	array[m._029], --moe
# 	array[m._001]  --universe moe
# 	)as fpop6574mp,
#
#  -----END-----
# fpop7584mp 	 acs1418.acs_moe_pct(
# 	array[e._030], --estimate
# 	array[e._001], --universe estimate
# 	array[m._030], --moe
# 	array[m._001]  --universe moe
# 	)as fpop7584mp,
#
#  -----END-----
# fpop85omp 	 acs1418.acs_moe_pct(
# 	array[e._031], --estimate
# 	array[e._001], --universe estimate
# 	array[m._031], --moe
# 	array[m._001]  --universe moe
# 	)as fpop85omp,
#
#  -----END-----
# fpop_u18mp 	 acs1418.acs_moe_pct(
# 	array[e._018,e._019,e._020,e._021], --estimate
# 	array[e._001], --universe estimate
# 	array[m._018,e._019,e._020,e._021], --moe
# 	array[m._001]  --universe moe
# 	)as fpop_u18mp,
#
#  -----END-----
# fpop1824mp 	 acs1418.acs_moe_pct(
# 	array[e._022,e._023], --estimate
# 	array[e._001], --universe estimate
# 	array[m._022,m._023], --moe
# 	array[m._001]  --universe moe
# 	)as fpop1824mp,
#
#  -----END-----
# fpop2534mp 	 acs1418.acs_moe_pct(
# 	array[e._024,e._025], --estimate
# 	array[e._001], --universe estimate
# 	array[m._024,m._025], --moe
# 	array[m._001]  --universe moe
# 	)as fpop2534mp,
#
#  -----END-----
# fpop3564mp 	 acs1418.acs_moe_pct(
# 	array[e._026,e._027,e._028], --estimate
# 	array[e._001], --universe estimate
# 	array[m._026,m._027,m._028], --moe
# 	array[m._001]  --universe moe
# 	)as fpop3564mp,
#
#  -----END-----
# fpop65ovmp 	 acs1418.acs_moe_pct(
# 	array[e._029,e._030,e._031], --estimate
# 	array[e._001], --universe estimate
# 	array[m._029,m._030,m._031], --moe
# 	array[m._001]  --universe moe
# 	)as fpop65ovmp,
#
#  -----END-----
# fpop1834mp 	 acs1418.acs_moe_pct(
# 	array[e._022,e._023,e._024,e._025], --estimate
# 	array[e._001], --universe estimate
# 	array[m._022,m._023,m._024,m._025],
# 	array[m._001]  --universe moe
# 	) as fpop1834mp,
#
#  -----END-----
# fpop4564mp 	 acs1418.acs_moe_pct(
# 	array[e._012,e._013,e._027,e._028], --estimate
# 	array[e._001], --universe estimate
# 	array[m._012,m._013,m._027,m._028],
# 	array[m._001]  --universe moe
# 	) as fpop4564mp,
#
#  -----END-----
# mpop_mp 	 acs1418.acs_moe_pct(
# 	array[e._002], --estimate
# 	array[e._001], --universe estimate
# 	array[m._002], --moe
# 	array[m._001]  --universe moe
# 	)as mpop_mp,
#
#  -----END-----
# mpop_u5mp 	 acs1418.acs_moe_pct(
# 	array[e._003], --estimate
# 	array[e._001], --universe estimate
# 	array[m._003], --moe
# 	array[m._001]  --universe moe
# 	)as mpop_u5mp,
#
#  -----END-----
# mpop_5_9mp 	 acs1418.acs_moe_pct(
# 	array[e._004], --estimate
# 	array[e._001], --universe estimate
# 	array[m._004], --moe
# 	array[m._001]  --universe moe
# 	)as mpop_5_9mp,
#
#  -----END-----
# mpop1014mp 	 acs1418.acs_moe_pct(
# 	array[e._005], --estimate
# 	array[e._001], --universe estimate
# 	array[m._005], --moe
# 	array[m._001]  --universe moe
# 	)as mpop1014mp,
#
#  -----END-----
# mpop1517mp 	 acs1418.acs_moe_pct(
# 	array[e._006], --estimate
# 	array[e._001], --universe estimate
# 	array[m._006], --moe
# 	array[m._001]  --universe moe
# 	)as mpop1517mp,
#
#  -----END-----
# mpop1819mp 	 acs1418.acs_moe_pct(
# 	array[e._007], --estimate
# 	array[e._001], --universe estimate
# 	array[m._007], --moe
# 	array[m._001]  --universe moe
# 	)as mpop1819mp,
#
#  -----END-----
# mpop2024mp 	 acs1418.acs_moe_pct(
# 	array[e._008], --estimate
# 	array[e._001], --universe estimate
# 	array[m._008], --moe
# 	array[m._001]  --universe moe
# 	)as mpop2024mp,
#
#  -----END-----
# mpop2529mp 	 acs1418.acs_moe_pct(
# 	array[e._009], --estimate
# 	array[e._001], --universe estimate
# 	array[m._009], --moe
# 	array[m._001]  --universe moe
# 	)as mpop2529mp,
#
#  -----END-----
# mpop3034mp 	 acs1418.acs_moe_pct(
# 	array[e._010], --estimate
# 	array[e._001], --universe estimate
# 	array[m._010], --moe
# 	array[m._001]  --universe moe
# 	)as mpop3034mp,
#
#  -----END-----
# mpop3544mp 	 acs1418.acs_moe_pct(
# 	array[e._011], --estimate
# 	array[e._001], --universe estimate
# 	array[m._011], --moe
# 	array[m._001]  --universe moe
# 	)as mpop3544mp,
#
#  -----END-----
# mpop4554mp 	 acs1418.acs_moe_pct(
# 	array[e._012], --estimate
# 	array[e._001], --universe estimate
# 	array[m._012], --moe
# 	array[m._001]  --universe moe
# 	)as mpop4554mp,
#
#  -----END-----
# mpop5564mp 	 acs1418.acs_moe_pct(
# 	array[e._013], --estimate
# 	array[e._001], --universe estimate
# 	array[m._013], --moe
# 	array[m._001]  --universe moe
# 	)as mpop5564mp,
#
#  -----END-----
# mpop6574mp 	 acs1418.acs_moe_pct(
# 	array[e._014], --estimate
# 	array[e._001], --universe estimate
# 	array[m._014], --moe
# 	array[m._001]  --universe moe
# 	)as mpop6574mp,
#
#  -----END-----
# mpop7584mp 	 acs1418.acs_moe_pct(
# 	array[e._015], --estimate
# 	array[e._001], --universe estimate
# 	array[m._015], --moe
# 	array[m._001]  --universe moe
# 	)as mpop7584mp,
#
#  -----END-----
# mpop85omp 	 acs1418.acs_moe_pct(
# 	array[e._016], --estimate
# 	array[e._001], --universe estimate
# 	array[m._016], --moe
# 	array[m._001]  --universe moe
# 	)as mpop85omp,
#
#  -----END-----
# mpop_u18mp 	 acs1418.acs_moe_pct(
# 	array[e._003,e._004,e._005,e._006], --estimate
# 	array[e._001], --universe estimate
# 	array[m._003,m._004,m._005,m._006], --moe
# 	array[m._001]  --universe moe
# 	)as mpop_u18mp,
#
#  -----END-----
# mpop1824mp 	 acs1418.acs_moe_pct(
# 	array[e._007,e._008], --estimate
# 	array[e._001], --universe estimate
# 	array[m._007,m._008], --moe
# 	array[m._001]  --universe moe
# 	)as mpop1824mp,
#
#  -----END-----
# mpop2534mp 	 acs1418.acs_moe_pct(
# 	array[e._009,e._010], --estimate
# 	array[e._001], --universe estimate
# 	array[m._009,m._010], --moe
# 	array[m._001]  --universe moe
# 	)as mpop2534mp,
#
#  -----END-----
# mpop3564mp 	 acs1418.acs_moe_pct(
# 	array[e._011,e._012,e._013], --estimate
# 	array[e._001], --universe estimate
# 	array[m._011,m._012,m._013], --moe
# 	array[m._001]  --universe moe
# 	)as mpop3564mp,
#
#  -----END-----
# mpop65ovmp 	 acs1418.acs_moe_pct(
# 	array[e._014,e._015,e._016], --estimate
# 	array[e._001], --universe estimate
# 	array[m._014,m._015,m._016], --moe
# 	array[m._001]  --universe moe
# 	)as mpop65ovmp,
#
#  -----END-----
# mpop1834mp 	 acs1418.acs_moe_pct(
# 	array[e._007,e._008,e._009,e._010], --estimate
# 	array[e._001], --universe estimate
# 	array[m._007,m._008,m._009,m._010],
# 	array[m._001]  --universe moe
# 	) as mpop1834mp,
#
#  -----END-----
#  	 acs1418.acs_moe_pct(
# 	array[e._012,e._013], --estimate
# 	array[e._001], --universe estimate
# 	array[m._012,m._013],
# 	array[m._001]  --universe moe
# 	) as mpop4564mp
#
#  -----END-----
# pop_u5mp 	 acs1418.acs_moe_pct(
# 	array[e._003,e._018], --estimate
# 	array[e._001], --universe estimate
# 	array[m._003,m._018], --moe
# 	array[m._001]  --universe moe
# 	)as pop_u5mp,
#
#  -----END-----
# pop_5_9mp 	 acs1418.acs_moe_pct(
# 	array[e._004,e._019], --estimate
# 	array[e._001], --universe estimate
# 	array[m._004,m._019], --moe
# 	array[m._001]  --universe moe
# 	)as pop_5_9mp,
#
#  -----END-----
# pop1014mp 	 acs1418.acs_moe_pct(
# 	array[e._005,e._020], --estimate
# 	array[e._001], --universe estimate
# 	array[m._005,m._020], --moe
# 	array[m._001]  --universe moe
# 	)as pop1014mp,
#
#  -----END-----
# pop1517mp 	 acs1418.acs_moe_pct(
# 	array[e._006,e._021], --estimate
# 	array[e._001], --universe estimate
# 	array[m._006,m._021], --moe
# 	array[m._001]  --universe moe
# 	)as pop1517mp,
#
#  -----END-----
# pop1819mp 	 acs1418.acs_moe_pct(
# 	array[e._007,e._022], --estimate
# 	array[e._001], --universe estimate
# 	array[m._007,m._022], --moe
# 	array[m._001]  --universe moe
# 	)as pop1819mp,
#
#  -----END-----
# pop2024mp 	 acs1418.acs_moe_pct(
# 	array[e._008,e._023], --estimate
# 	array[e._001], --universe estimate
# 	array[m._008,m._023], --moe
# 	array[m._001]  --universe moe
# 	)as pop2024mp,
#
#  -----END-----
# pop2529mp 	 acs1418.acs_moe_pct(
# 	array[e._009,e._024], --estimate
# 	array[e._001], --universe estimate
# 	array[m._009,m._024], --moe
# 	array[m._001]  --universe moe
# 	)as pop2529mp,
#
#  -----END-----
# pop3034mp 	 acs1418.acs_moe_pct(
# 	array[e._010,e._025], --estimate
# 	array[e._001], --universe estimate
# 	array[m._010,m._025], --moe
# 	array[m._001]  --universe moe
# 	)as pop3034mp,
#
#  -----END-----
# pop3544mp 	 acs1418.acs_moe_pct(
# 	array[e._011,e._026], --estimate
# 	array[e._001], --universe estimate
# 	array[m._011,m._026], --moe
# 	array[m._001]  --universe moe
# 	)as pop3544mp,
#
#  -----END-----
# pop4554mp 	 acs1418.acs_moe_pct(
# 	array[e._012,e._027], --estimate
# 	array[e._001], --universe estimate
# 	array[m._012,m._027], --moe
# 	array[m._001]  --universe moe
# 	)as pop4554mp,
#
#  -----END-----
# pop5564mp 	 acs1418.acs_moe_pct(
# 	array[e._013,e._028], --estimate
# 	array[e._001], --universe estimate
# 	array[m._013,m._028], --moe
# 	array[m._001]  --universe moe
# 	)as pop5564mp,
#
#  -----END-----
# pop6574mp 	 acs1418.acs_moe_pct(
# 	array[e._014,e._029], --estimate
# 	array[e._001], --universe estimate
# 	array[m._014,m._029], --moe
# 	array[m._001]  --universe moe
# 	)as pop6574mp,
#
#  -----END-----
# pop7584mp 	 acs1418.acs_moe_pct(
# 	array[e._015,e._030], --estimate
# 	array[e._001], --universe estimate
# 	array[m._015,m._030], --moe
# 	array[m._001]  --universe moe
# 	)as pop7584mp,
#
#  -----END-----
# pop85omp 	 acs1418.acs_moe_pct(
# 	array[e._016,e._031], --estimate
# 	array[e._001], --universe estimate
# 	array[m._016,m._031], --moe
# 	array[m._001]  --universe moe
# 	)as pop85omp,
#
#  -----END-----
# pop_u18mp 	 acs1418.acs_moe_pct(
# 	array[e._003,e._004,e._005,e._006,e._018,e._019,e._020,e._021], --estimate
# 	array[e._001], --universe estimate
# 	array[m._003,m._004,m._005,m._006,m._018,e._019,e._020,e._021], --moe
# 	array[m._001]  --universe moe
# 	)as pop_u18mp,
#
#  -----END-----
# pop1824mp 	 acs1418.acs_moe_pct(
# 	array[e._007,e._008,e._022,e._023], --estimate
# 	array[e._001], --universe estimate
# 	array[m._007,m._008,m._022,m._023], --moe
# 	array[m._001]  --universe moe
# 	)as pop1824mp,
#
#  -----END-----
# pop2534mp 	 acs1418.acs_moe_pct(
# 	array[e._009,e._010,e._024,e._025], --estimate
# 	array[e._001], --universe estimate
# 	array[m._009,m._010,m._024,m._025], --moe
# 	array[m._001]  --universe moe
# 	)as pop2534mp,
#
#  -----END-----
# pop3564mp 	 acs1418.acs_moe_pct(
# 	array[e._011,e._012,e._013,e._026,e._027,e._028], --estimate
# 	array[e._001], --universe estimate
# 	array[m._011,m._012,m._013,m._026,m._027,m._028], --moe
# 	array[m._001]  --universe moe
# 	)as pop3564mp,
#
#  -----END-----
# pop65ovmp 	 acs1418.acs_moe_pct(
# 	array[e._014,e._015,e._016,e._029,e._030,e._031], --estimate
# 	array[e._001], --universe estimate
# 	array[m._014,m._015,m._016,m._029,m._030,m._031], --moe
# 	array[m._001]  --universe moe
# 	)as pop65ovmp,
#
#  -----END-----
# pop1834mp 	 acs1418.acs_moe_pct(
# 	array[e._007,e._008,e._009,e._010,e._022,e._023,e._024,e._025], --estimate
# 	array[e._001], --universe estimate
# 	array[m._007,m._008,m._009,m._010,m._022,m._023,m._024,m._025],
# 	array[m._001]  --universe moe
# 	) as pop1834mp,
#
#  -----END-----
# pop4564mp 	 acs1418.acs_moe_pct(
# 	array[e._012,e._013,e._027,e._028], --estimate
# 	array[e._001], --universe estimate
# 	array[m._012,m._013,m._027,m._028],
# 	array[m._001]  --universe moe
# 	) as pop4564mp,
#
#  -----END-----
# fpop_mp 	 acs1418.acs_moe_pct(
# 	array[e._017], --estimate
# 	array[e._001], --universe estimate
# 	array[m._017], --moe
# 	array[m._001]  --universe moe
# 	)as fpop_mp,
#
#  -----END-----
# fpop_u5mp 	 acs1418.acs_moe_pct(
# 	array[e._018], --estimate
# 	array[e._001], --universe estimate
# 	array[m._018], --moe
# 	array[m._001]  --universe moe
# 	)as fpop_u5mp,
#
#  -----END-----
# fpop_5_9mp 	 acs1418.acs_moe_pct(
# 	array[e._019], --estimate
# 	array[e._001], --universe estimate
# 	array[m._019], --moe
# 	array[m._001]  --universe moe
# 	)as fpop_5_9mp,
#
#  -----END-----
# fpop1014mp 	 acs1418.acs_moe_pct(
# 	array[e._020], --estimate
# 	array[e._001], --universe estimate
# 	array[m._020], --moe
# 	array[m._001]  --universe moe
# 	)as fpop1014mp,
#
#  -----END-----
# fpop1517mp 	 acs1418.acs_moe_pct(
# 	array[e._021], --estimate
# 	array[e._001], --universe estimate
# 	array[m._021], --moe
# 	array[m._001]  --universe moe
# 	)as fpop1517mp,
#
#  -----END-----
# fpop1819mp 	 acs1418.acs_moe_pct(
# 	array[e._022], --estimate
# 	array[e._001], --universe estimate
# 	array[m._022], --moe
# 	array[m._001]  --universe moe
# 	)as fpop1819mp,
#
#  -----END-----
# fpop2024mp 	 acs1418.acs_moe_pct(
# 	array[e._023], --estimate
# 	array[e._001], --universe estimate
# 	array[m._023], --moe
# 	array[m._001]  --universe moe
# 	)as fpop2024mp,
#
#  -----END-----
# fpop2529mp 	 acs1418.acs_moe_pct(
# 	array[e._024], --estimate
# 	array[e._001], --universe estimate
# 	array[m._024], --moe
# 	array[m._001]  --universe moe
# 	)as fpop2529mp,
#
#  -----END-----
# fpop3034mp 	 acs1418.acs_moe_pct(
# 	array[e._025], --estimate
# 	array[e._001], --universe estimate
# 	array[m._025], --moe
# 	array[m._001]  --universe moe
# 	)as fpop3034mp,
#
#  -----END-----
# fpop3544mp 	 acs1418.acs_moe_pct(
# 	array[e._026], --estimate
# 	array[e._001], --universe estimate
# 	array[m._026], --moe
# 	array[m._001]  --universe moe
# 	)as fpop3544mp,
#
#  -----END-----
# fpop4554mp 	 acs1418.acs_moe_pct(
# 	array[e._027], --estimate
# 	array[e._001], --universe estimate
# 	array[m._027], --moe
# 	array[m._001]  --universe moe
# 	)as fpop4554mp,
#
#  -----END-----
# fpop5564mp 	 acs1418.acs_moe_pct(
# 	array[e._028], --estimate
# 	array[e._001], --universe estimate
# 	array[m._028], --moe
# 	array[m._001]  --universe moe
# 	)as fpop5564mp,
#
#  -----END-----
# fpop6574mp 	 acs1418.acs_moe_pct(
# 	array[e._029], --estimate
# 	array[e._001], --universe estimate
# 	array[m._029], --moe
# 	array[m._001]  --universe moe
# 	)as fpop6574mp,
#
#  -----END-----
# fpop7584mp 	 acs1418.acs_moe_pct(
# 	array[e._030], --estimate
# 	array[e._001], --universe estimate
# 	array[m._030], --moe
# 	array[m._001]  --universe moe
# 	)as fpop7584mp,
#
#  -----END-----
# fpop85omp 	 acs1418.acs_moe_pct(
# 	array[e._031], --estimate
# 	array[e._001], --universe estimate
# 	array[m._031], --moe
# 	array[m._001]  --universe moe
# 	)as fpop85omp,
#
#  -----END-----
# fpop_u18mp 	 acs1418.acs_moe_pct(
# 	array[e._018,e._019,e._020,e._021], --estimate
# 	array[e._001], --universe estimate
# 	array[m._018,e._019,e._020,e._021], --moe
# 	array[m._001]  --universe moe
# 	)as fpop_u18mp,
#
#  -----END-----
# fpop1824mp 	 acs1418.acs_moe_pct(
# 	array[e._022,e._023], --estimate
# 	array[e._001], --universe estimate
# 	array[m._022,m._023], --moe
# 	array[m._001]  --universe moe
# 	)as fpop1824mp,
#
#  -----END-----
# fpop2534mp 	 acs1418.acs_moe_pct(
# 	array[e._024,e._025], --estimate
# 	array[e._001], --universe estimate
# 	array[m._024,m._025], --moe
# 	array[m._001]  --universe moe
# 	)as fpop2534mp,
#
#  -----END-----
# fpop3564mp 	 acs1418.acs_moe_pct(
# 	array[e._026,e._027,e._028], --estimate
# 	array[e._001], --universe estimate
# 	array[m._026,m._027,m._028], --moe
# 	array[m._001]  --universe moe
# 	)as fpop3564mp,
#
#  -----END-----
# fpop65ovmp 	 acs1418.acs_moe_pct(
# 	array[e._029,e._030,e._031], --estimate
# 	array[e._001], --universe estimate
# 	array[m._029,m._030,m._031], --moe
# 	array[m._001]  --universe moe
# 	)as fpop65ovmp,
#
#  -----END-----
# fpop1834mp 	 acs1418.acs_moe_pct(
# 	array[e._022,e._023,e._024,e._025], --estimate
# 	array[e._001], --universe estimate
# 	array[m._022,m._023,m._024,m._025],
# 	array[m._001]  --universe moe
# 	) as fpop1834mp,
#
#  -----END-----
# fpop4564mp 	 acs1418.acs_moe_pct(
# 	array[e._012,e._013,e._027,e._028], --estimate
# 	array[e._001], --universe estimate
# 	array[m._012,m._013,m._027,m._028],
# 	array[m._001]  --universe moe
# 	) as fpop4564mp,
#
#  -----END-----
# mpop_mp 	 acs1418.acs_moe_pct(
# 	array[e._002], --estimate
# 	array[e._001], --universe estimate
# 	array[m._002], --moe
# 	array[m._001]  --universe moe
# 	)as mpop_mp,
#
#  -----END-----
# mpop_u5mp 	 acs1418.acs_moe_pct(
# 	array[e._003], --estimate
# 	array[e._001], --universe estimate
# 	array[m._003], --moe
# 	array[m._001]  --universe moe
# 	)as mpop_u5mp,
#
#  -----END-----
# mpop_5_9mp 	 acs1418.acs_moe_pct(
# 	array[e._004], --estimate
# 	array[e._001], --universe estimate
# 	array[m._004], --moe
# 	array[m._001]  --universe moe
# 	)as mpop_5_9mp,
#
#  -----END-----
# mpop1014mp 	 acs1418.acs_moe_pct(
# 	array[e._005], --estimate
# 	array[e._001], --universe estimate
# 	array[m._005], --moe
# 	array[m._001]  --universe moe
# 	)as mpop1014mp,
#
#  -----END-----
# mpop1517mp 	 acs1418.acs_moe_pct(
# 	array[e._006], --estimate
# 	array[e._001], --universe estimate
# 	array[m._006], --moe
# 	array[m._001]  --universe moe
# 	)as mpop1517mp,
#
#  -----END-----
# mpop1819mp 	 acs1418.acs_moe_pct(
# 	array[e._007], --estimate
# 	array[e._001], --universe estimate
# 	array[m._007], --moe
# 	array[m._001]  --universe moe
# 	)as mpop1819mp,
#
#  -----END-----
# mpop2024mp 	 acs1418.acs_moe_pct(
# 	array[e._008], --estimate
# 	array[e._001], --universe estimate
# 	array[m._008], --moe
# 	array[m._001]  --universe moe
# 	)as mpop2024mp,
#
#  -----END-----
# mpop2529mp 	 acs1418.acs_moe_pct(
# 	array[e._009], --estimate
# 	array[e._001], --universe estimate
# 	array[m._009], --moe
# 	array[m._001]  --universe moe
# 	)as mpop2529mp,
#
#  -----END-----
# mpop3034mp 	 acs1418.acs_moe_pct(
# 	array[e._010], --estimate
# 	array[e._001], --universe estimate
# 	array[m._010], --moe
# 	array[m._001]  --universe moe
# 	)as mpop3034mp,
#
#  -----END-----
# mpop3544mp 	 acs1418.acs_moe_pct(
# 	array[e._011], --estimate
# 	array[e._001], --universe estimate
# 	array[m._011], --moe
# 	array[m._001]  --universe moe
# 	)as mpop3544mp,
#
#  -----END-----
# mpop4554mp 	 acs1418.acs_moe_pct(
# 	array[e._012], --estimate
# 	array[e._001], --universe estimate
# 	array[m._012], --moe
# 	array[m._001]  --universe moe
# 	)as mpop4554mp,
#
#  -----END-----
# mpop5564mp 	 acs1418.acs_moe_pct(
# 	array[e._013], --estimate
# 	array[e._001], --universe estimate
# 	array[m._013], --moe
# 	array[m._001]  --universe moe
# 	)as mpop5564mp,
#
#  -----END-----
# mpop6574mp 	 acs1418.acs_moe_pct(
# 	array[e._014], --estimate
# 	array[e._001], --universe estimate
# 	array[m._014], --moe
# 	array[m._001]  --universe moe
# 	)as mpop6574mp,
#
#  -----END-----
# mpop7584mp 	 acs1418.acs_moe_pct(
# 	array[e._015], --estimate
# 	array[e._001], --universe estimate
# 	array[m._015], --moe
# 	array[m._001]  --universe moe
# 	)as mpop7584mp,
#
#  -----END-----
# mpop85omp 	 acs1418.acs_moe_pct(
# 	array[e._016], --estimate
# 	array[e._001], --universe estimate
# 	array[m._016], --moe
# 	array[m._001]  --universe moe
# 	)as mpop85omp,
#
#  -----END-----
# mpop_u18mp 	 acs1418.acs_moe_pct(
# 	array[e._003,e._004,e._005,e._006], --estimate
# 	array[e._001], --universe estimate
# 	array[m._003,m._004,m._005,m._006], --moe
# 	array[m._001]  --universe moe
# 	)as mpop_u18mp,
#
#  -----END-----
# mpop1824mp 	 acs1418.acs_moe_pct(
# 	array[e._007,e._008], --estimate
# 	array[e._001], --universe estimate
# 	array[m._007,m._008], --moe
# 	array[m._001]  --universe moe
# 	)as mpop1824mp,
#
#  -----END-----
# mpop2534mp 	 acs1418.acs_moe_pct(
# 	array[e._009,e._010], --estimate
# 	array[e._001], --universe estimate
# 	array[m._009,m._010], --moe
# 	array[m._001]  --universe moe
# 	)as mpop2534mp,
#
#  -----END-----
# mpop3564mp 	 acs1418.acs_moe_pct(
# 	array[e._011,e._012,e._013], --estimate
# 	array[e._001], --universe estimate
# 	array[m._011,m._012,m._013], --moe
# 	array[m._001]  --universe moe
# 	)as mpop3564mp,
#
#  -----END-----
# mpop65ovmp 	 acs1418.acs_moe_pct(
# 	array[e._014,e._015,e._016], --estimate
# 	array[e._001], --universe estimate
# 	array[m._014,m._015,m._016], --moe
# 	array[m._001]  --universe moe
# 	)as mpop65ovmp,
#
#  -----END-----
# mpop1834mp 	 acs1418.acs_moe_pct(
# 	array[e._007,e._008,e._009,e._010], --estimate
# 	array[e._001], --universe estimate
# 	array[m._007,m._008,m._009,m._010],
# 	array[m._001]  --universe moe
# 	) as mpop1834mp,
#
#  -----END-----
#  	 acs1418.acs_moe_pct(
# 	array[e._012,e._013], --estimate
# 	array[e._001], --universe estimate
# 	array[m._012,m._013],
# 	array[m._001]  --universe moe
# 	) as mpop4564mp
#
#  -----END-----
# pop_u5mp 	 acs1418.acs_moe_pct(
# 	array[e._003,e._018], --estimate
# 	array[e._001], --universe estimate
# 	array[m._003,m._018], --moe
# 	array[m._001]  --universe moe
# 	)as pop_u5mp,
#
#  -----END-----
# pop_5_9mp 	 acs1418.acs_moe_pct(
# 	array[e._004,e._019], --estimate
# 	array[e._001], --universe estimate
# 	array[m._004,m._019], --moe
# 	array[m._001]  --universe moe
# 	)as pop_5_9mp,
#
#  -----END-----
# pop1014mp 	 acs1418.acs_moe_pct(
# 	array[e._005,e._020], --estimate
# 	array[e._001], --universe estimate
# 	array[m._005,m._020], --moe
# 	array[m._001]  --universe moe
# 	)as pop1014mp,
#
#  -----END-----
# pop1517mp 	 acs1418.acs_moe_pct(
# 	array[e._006,e._021], --estimate
# 	array[e._001], --universe estimate
# 	array[m._006,m._021], --moe
# 	array[m._001]  --universe moe
# 	)as pop1517mp,
#
#  -----END-----
# pop1819mp 	 acs1418.acs_moe_pct(
# 	array[e._007,e._022], --estimate
# 	array[e._001], --universe estimate
# 	array[m._007,m._022], --moe
# 	array[m._001]  --universe moe
# 	)as pop1819mp,
#
#  -----END-----
# pop2024mp 	 acs1418.acs_moe_pct(
# 	array[e._008,e._023], --estimate
# 	array[e._001], --universe estimate
# 	array[m._008,m._023], --moe
# 	array[m._001]  --universe moe
# 	)as pop2024mp,
#
#  -----END-----
# pop2529mp 	 acs1418.acs_moe_pct(
# 	array[e._009,e._024], --estimate
# 	array[e._001], --universe estimate
# 	array[m._009,m._024], --moe
# 	array[m._001]  --universe moe
# 	)as pop2529mp,
#
#  -----END-----
# pop3034mp 	 acs1418.acs_moe_pct(
# 	array[e._010,e._025], --estimate
# 	array[e._001], --universe estimate
# 	array[m._010,m._025], --moe
# 	array[m._001]  --universe moe
# 	)as pop3034mp,
#
#  -----END-----
# pop3544mp 	 acs1418.acs_moe_pct(
# 	array[e._011,e._026], --estimate
# 	array[e._001], --universe estimate
# 	array[m._011,m._026], --moe
# 	array[m._001]  --universe moe
# 	)as pop3544mp,
#
#  -----END-----
# pop4554mp 	 acs1418.acs_moe_pct(
# 	array[e._012,e._027], --estimate
# 	array[e._001], --universe estimate
# 	array[m._012,m._027], --moe
# 	array[m._001]  --universe moe
# 	)as pop4554mp,
#
#  -----END-----
# pop5564mp 	 acs1418.acs_moe_pct(
# 	array[e._013,e._028], --estimate
# 	array[e._001], --universe estimate
# 	array[m._013,m._028], --moe
# 	array[m._001]  --universe moe
# 	)as pop5564mp,
#
#  -----END-----
# pop6574mp 	 acs1418.acs_moe_pct(
# 	array[e._014,e._029], --estimate
# 	array[e._001], --universe estimate
# 	array[m._014,m._029], --moe
# 	array[m._001]  --universe moe
# 	)as pop6574mp,
#
#  -----END-----
# pop7584mp 	 acs1418.acs_moe_pct(
# 	array[e._015,e._030], --estimate
# 	array[e._001], --universe estimate
# 	array[m._015,m._030], --moe
# 	array[m._001]  --universe moe
# 	)as pop7584mp,
#
#  -----END-----
# pop85omp 	 acs1418.acs_moe_pct(
# 	array[e._016,e._031], --estimate
# 	array[e._001], --universe estimate
# 	array[m._016,m._031], --moe
# 	array[m._001]  --universe moe
# 	)as pop85omp,
#
#  -----END-----
# pop_u18mp 	 acs1418.acs_moe_pct(
# 	array[e._003,e._004,e._005,e._006,e._018,e._019,e._020,e._021], --estimate
# 	array[e._001], --universe estimate
# 	array[m._003,m._004,m._005,m._006,m._018,e._019,e._020,e._021], --moe
# 	array[m._001]  --universe moe
# 	)as pop_u18mp,
#
#  -----END-----
# pop1824mp 	 acs1418.acs_moe_pct(
# 	array[e._007,e._008,e._022,e._023], --estimate
# 	array[e._001], --universe estimate
# 	array[m._007,m._008,m._022,m._023], --moe
# 	array[m._001]  --universe moe
# 	)as pop1824mp,
#
#  -----END-----
# pop2534mp 	 acs1418.acs_moe_pct(
# 	array[e._009,e._010,e._024,e._025], --estimate
# 	array[e._001], --universe estimate
# 	array[m._009,m._010,m._024,m._025], --moe
# 	array[m._001]  --universe moe
# 	)as pop2534mp,
#
#  -----END-----
# pop3564mp 	 acs1418.acs_moe_pct(
# 	array[e._011,e._012,e._013,e._026,e._027,e._028], --estimate
# 	array[e._001], --universe estimate
# 	array[m._011,m._012,m._013,m._026,m._027,m._028], --moe
# 	array[m._001]  --universe moe
# 	)as pop3564mp,
#
#  -----END-----
# pop65ovmp 	 acs1418.acs_moe_pct(
# 	array[e._014,e._015,e._016,e._029,e._030,e._031], --estimate
# 	array[e._001], --universe estimate
# 	array[m._014,m._015,m._016,m._029,m._030,m._031], --moe
# 	array[m._001]  --universe moe
# 	)as pop65ovmp,
#
#  -----END-----
# pop1834mp 	 acs1418.acs_moe_pct(
# 	array[e._007,e._008,e._009,e._010,e._022,e._023,e._024,e._025], --estimate
# 	array[e._001], --universe estimate
# 	array[m._007,m._008,m._009,m._010,m._022,m._023,m._024,m._025],
# 	array[m._001]  --universe moe
# 	) as pop1834mp,
#
#  -----END-----
# pop4564mp 	 acs1418.acs_moe_pct(
# 	array[e._012,e._013,e._027,e._028], --estimate
# 	array[e._001], --universe estimate
# 	array[m._012,m._013,m._027,m._028],
# 	array[m._001]  --universe moe
# 	) as pop4564mp,
#
#  -----END-----
# fpop_mp 	 acs1418.acs_moe_pct(
# 	array[e._017], --estimate
# 	array[e._001], --universe estimate
# 	array[m._017], --moe
# 	array[m._001]  --universe moe
# 	)as fpop_mp,
#
#  -----END-----
# fpop_u5mp 	 acs1418.acs_moe_pct(
# 	array[e._018], --estimate
# 	array[e._001], --universe estimate
# 	array[m._018], --moe
# 	array[m._001]  --universe moe
# 	)as fpop_u5mp,
#
#  -----END-----
# fpop_5_9mp 	 acs1418.acs_moe_pct(
# 	array[e._019], --estimate
# 	array[e._001], --universe estimate
# 	array[m._019], --moe
# 	array[m._001]  --universe moe
# 	)as fpop_5_9mp,
#
#  -----END-----
# fpop1014mp 	 acs1418.acs_moe_pct(
# 	array[e._020], --estimate
# 	array[e._001], --universe estimate
# 	array[m._020], --moe
# 	array[m._001]  --universe moe
# 	)as fpop1014mp,
#
#  -----END-----
# fpop1517mp 	 acs1418.acs_moe_pct(
# 	array[e._021], --estimate
# 	array[e._001], --universe estimate
# 	array[m._021], --moe
# 	array[m._001]  --universe moe
# 	)as fpop1517mp,
#
#  -----END-----
# fpop1819mp 	 acs1418.acs_moe_pct(
# 	array[e._022], --estimate
# 	array[e._001], --universe estimate
# 	array[m._022], --moe
# 	array[m._001]  --universe moe
# 	)as fpop1819mp,
#
#  -----END-----
# fpop2024mp 	 acs1418.acs_moe_pct(
# 	array[e._023], --estimate
# 	array[e._001], --universe estimate
# 	array[m._023], --moe
# 	array[m._001]  --universe moe
# 	)as fpop2024mp,
#
#  -----END-----
# fpop2529mp 	 acs1418.acs_moe_pct(
# 	array[e._024], --estimate
# 	array[e._001], --universe estimate
# 	array[m._024], --moe
# 	array[m._001]  --universe moe
# 	)as fpop2529mp,
#
#  -----END-----
# fpop3034mp 	 acs1418.acs_moe_pct(
# 	array[e._025], --estimate
# 	array[e._001], --universe estimate
# 	array[m._025], --moe
# 	array[m._001]  --universe moe
# 	)as fpop3034mp,
#
#  -----END-----
# fpop3544mp 	 acs1418.acs_moe_pct(
# 	array[e._026], --estimate
# 	array[e._001], --universe estimate
# 	array[m._026], --moe
# 	array[m._001]  --universe moe
# 	)as fpop3544mp,
#
#  -----END-----
# fpop4554mp 	 acs1418.acs_moe_pct(
# 	array[e._027], --estimate
# 	array[e._001], --universe estimate
# 	array[m._027], --moe
# 	array[m._001]  --universe moe
# 	)as fpop4554mp,
#
#  -----END-----
# fpop5564mp 	 acs1418.acs_moe_pct(
# 	array[e._028], --estimate
# 	array[e._001], --universe estimate
# 	array[m._028], --moe
# 	array[m._001]  --universe moe
# 	)as fpop5564mp,
#
#  -----END-----
# fpop6574mp 	 acs1418.acs_moe_pct(
# 	array[e._029], --estimate
# 	array[e._001], --universe estimate
# 	array[m._029], --moe
# 	array[m._001]  --universe moe
# 	)as fpop6574mp,
#
#  -----END-----
# fpop7584mp 	 acs1418.acs_moe_pct(
# 	array[e._030], --estimate
# 	array[e._001], --universe estimate
# 	array[m._030], --moe
# 	array[m._001]  --universe moe
# 	)as fpop7584mp,
#
#  -----END-----
# fpop85omp 	 acs1418.acs_moe_pct(
# 	array[e._031], --estimate
# 	array[e._001], --universe estimate
# 	array[m._031], --moe
# 	array[m._001]  --universe moe
# 	)as fpop85omp,
#
#  -----END-----
# fpop_u18mp 	 acs1418.acs_moe_pct(
# 	array[e._018,e._019,e._020,e._021], --estimate
# 	array[e._001], --universe estimate
# 	array[m._018,e._019,e._020,e._021], --moe
# 	array[m._001]  --universe moe
# 	)as fpop_u18mp,
#
#  -----END-----
# fpop1824mp 	 acs1418.acs_moe_pct(
# 	array[e._022,e._023], --estimate
# 	array[e._001], --universe estimate
# 	array[m._022,m._023], --moe
# 	array[m._001]  --universe moe
# 	)as fpop1824mp,
#
#  -----END-----
# fpop2534mp 	 acs1418.acs_moe_pct(
# 	array[e._024,e._025], --estimate
# 	array[e._001], --universe estimate
# 	array[m._024,m._025], --moe
# 	array[m._001]  --universe moe
# 	)as fpop2534mp,
#
#  -----END-----
# fpop3564mp 	 acs1418.acs_moe_pct(
# 	array[e._026,e._027,e._028], --estimate
# 	array[e._001], --universe estimate
# 	array[m._026,m._027,m._028], --moe
# 	array[m._001]  --universe moe
# 	)as fpop3564mp,
#
#  -----END-----
# fpop65ovmp 	 acs1418.acs_moe_pct(
# 	array[e._029,e._030,e._031], --estimate
# 	array[e._001], --universe estimate
# 	array[m._029,m._030,m._031], --moe
# 	array[m._001]  --universe moe
# 	)as fpop65ovmp,
#
#  -----END-----
# fpop1834mp 	 acs1418.acs_moe_pct(
# 	array[e._022,e._023,e._024,e._025], --estimate
# 	array[e._001], --universe estimate
# 	array[m._022,m._023,m._024,m._025],
# 	array[m._001]  --universe moe
# 	) as fpop1834mp,
#
#  -----END-----
# fpop4564mp 	 acs1418.acs_moe_pct(
# 	array[e._012,e._013,e._027,e._028], --estimate
# 	array[e._001], --universe estimate
# 	array[m._012,m._013,m._027,m._028],
# 	array[m._001]  --universe moe
# 	) as fpop4564mp,
#
#  -----END-----
# mpop_mp 	 acs1418.acs_moe_pct(
# 	array[e._002], --estimate
# 	array[e._001], --universe estimate
# 	array[m._002], --moe
# 	array[m._001]  --universe moe
# 	)as mpop_mp,
#
#  -----END-----
# mpop_u5mp 	 acs1418.acs_moe_pct(
# 	array[e._003], --estimate
# 	array[e._001], --universe estimate
# 	array[m._003], --moe
# 	array[m._001]  --universe moe
# 	)as mpop_u5mp,
#
#  -----END-----
# mpop_5_9mp 	 acs1418.acs_moe_pct(
# 	array[e._004], --estimate
# 	array[e._001], --universe estimate
# 	array[m._004], --moe
# 	array[m._001]  --universe moe
# 	)as mpop_5_9mp,
#
#  -----END-----
# mpop1014mp 	 acs1418.acs_moe_pct(
# 	array[e._005], --estimate
# 	array[e._001], --universe estimate
# 	array[m._005], --moe
# 	array[m._001]  --universe moe
# 	)as mpop1014mp,
#
#  -----END-----
# mpop1517mp 	 acs1418.acs_moe_pct(
# 	array[e._006], --estimate
# 	array[e._001], --universe estimate
# 	array[m._006], --moe
# 	array[m._001]  --universe moe
# 	)as mpop1517mp,
#
#  -----END-----
# mpop1819mp 	 acs1418.acs_moe_pct(
# 	array[e._007], --estimate
# 	array[e._001], --universe estimate
# 	array[m._007], --moe
# 	array[m._001]  --universe moe
# 	)as mpop1819mp,
#
#  -----END-----
# mpop2024mp 	 acs1418.acs_moe_pct(
# 	array[e._008], --estimate
# 	array[e._001], --universe estimate
# 	array[m._008], --moe
# 	array[m._001]  --universe moe
# 	)as mpop2024mp,
#
#  -----END-----
# mpop2529mp 	 acs1418.acs_moe_pct(
# 	array[e._009], --estimate
# 	array[e._001], --universe estimate
# 	array[m._009], --moe
# 	array[m._001]  --universe moe
# 	)as mpop2529mp,
#
#  -----END-----
# mpop3034mp 	 acs1418.acs_moe_pct(
# 	array[e._010], --estimate
# 	array[e._001], --universe estimate
# 	array[m._010], --moe
# 	array[m._001]  --universe moe
# 	)as mpop3034mp,
#
#  -----END-----
# mpop3544mp 	 acs1418.acs_moe_pct(
# 	array[e._011], --estimate
# 	array[e._001], --universe estimate
# 	array[m._011], --moe
# 	array[m._001]  --universe moe
# 	)as mpop3544mp,
#
#  -----END-----
# mpop4554mp 	 acs1418.acs_moe_pct(
# 	array[e._012], --estimate
# 	array[e._001], --universe estimate
# 	array[m._012], --moe
# 	array[m._001]  --universe moe
# 	)as mpop4554mp,
#
#  -----END-----
# mpop5564mp 	 acs1418.acs_moe_pct(
# 	array[e._013], --estimate
# 	array[e._001], --universe estimate
# 	array[m._013], --moe
# 	array[m._001]  --universe moe
# 	)as mpop5564mp,
#
#  -----END-----
# mpop6574mp 	 acs1418.acs_moe_pct(
# 	array[e._014], --estimate
# 	array[e._001], --universe estimate
# 	array[m._014], --moe
# 	array[m._001]  --universe moe
# 	)as mpop6574mp,
#
#  -----END-----
# mpop7584mp 	 acs1418.acs_moe_pct(
# 	array[e._015], --estimate
# 	array[e._001], --universe estimate
# 	array[m._015], --moe
# 	array[m._001]  --universe moe
# 	)as mpop7584mp,
#
#  -----END-----
# mpop85omp 	 acs1418.acs_moe_pct(
# 	array[e._016], --estimate
# 	array[e._001], --universe estimate
# 	array[m._016], --moe
# 	array[m._001]  --universe moe
# 	)as mpop85omp,
#
#  -----END-----
# mpop_u18mp 	 acs1418.acs_moe_pct(
# 	array[e._003,e._004,e._005,e._006], --estimate
# 	array[e._001], --universe estimate
# 	array[m._003,m._004,m._005,m._006], --moe
# 	array[m._001]  --universe moe
# 	)as mpop_u18mp,
#
#  -----END-----
# mpop1824mp 	 acs1418.acs_moe_pct(
# 	array[e._007,e._008], --estimate
# 	array[e._001], --universe estimate
# 	array[m._007,m._008], --moe
# 	array[m._001]  --universe moe
# 	)as mpop1824mp,
#
#  -----END-----
# mpop2534mp 	 acs1418.acs_moe_pct(
# 	array[e._009,e._010], --estimate
# 	array[e._001], --universe estimate
# 	array[m._009,m._010], --moe
# 	array[m._001]  --universe moe
# 	)as mpop2534mp,
#
#  -----END-----
# mpop3564mp 	 acs1418.acs_moe_pct(
# 	array[e._011,e._012,e._013], --estimate
# 	array[e._001], --universe estimate
# 	array[m._011,m._012,m._013], --moe
# 	array[m._001]  --universe moe
# 	)as mpop3564mp,
#
#  -----END-----
# mpop65ovmp 	 acs1418.acs_moe_pct(
# 	array[e._014,e._015,e._016], --estimate
# 	array[e._001], --universe estimate
# 	array[m._014,m._015,m._016], --moe
# 	array[m._001]  --universe moe
# 	)as mpop65ovmp,
#
#  -----END-----
# mpop1834mp 	 acs1418.acs_moe_pct(
# 	array[e._007,e._008,e._009,e._010], --estimate
# 	array[e._001], --universe estimate
# 	array[m._007,m._008,m._009,m._010],
# 	array[m._001]  --universe moe
# 	) as mpop1834mp,
#
#  -----END-----
#  	 acs1418.acs_moe_pct(
# 	array[e._012,e._013], --estimate
# 	array[e._001], --universe estimate
# 	array[m._012,m._013],
# 	array[m._001]  --universe moe
# 	) as mpop4564mp
#
#  -----END-----
# pop_u5mp 	 acs1418.acs_moe_pct(
# 	array[e._003,e._018], --estimate
# 	array[e._001], --universe estimate
# 	array[m._003,m._018], --moe
# 	array[m._001]  --universe moe
# 	)as pop_u5mp,
#
#  -----END-----
# pop_5_9mp 	 acs1418.acs_moe_pct(
# 	array[e._004,e._019], --estimate
# 	array[e._001], --universe estimate
# 	array[m._004,m._019], --moe
# 	array[m._001]  --universe moe
# 	)as pop_5_9mp,
#
#  -----END-----
# pop1014mp 	 acs1418.acs_moe_pct(
# 	array[e._005,e._020], --estimate
# 	array[e._001], --universe estimate
# 	array[m._005,m._020], --moe
# 	array[m._001]  --universe moe
# 	)as pop1014mp,
#
#  -----END-----
# pop1517mp 	 acs1418.acs_moe_pct(
# 	array[e._006,e._021], --estimate
# 	array[e._001], --universe estimate
# 	array[m._006,m._021], --moe
# 	array[m._001]  --universe moe
# 	)as pop1517mp,
#
#  -----END-----
# pop1819mp 	 acs1418.acs_moe_pct(
# 	array[e._007,e._022], --estimate
# 	array[e._001], --universe estimate
# 	array[m._007,m._022], --moe
# 	array[m._001]  --universe moe
# 	)as pop1819mp,
#
#  -----END-----
# pop2024mp 	 acs1418.acs_moe_pct(
# 	array[e._008,e._023], --estimate
# 	array[e._001], --universe estimate
# 	array[m._008,m._023], --moe
# 	array[m._001]  --universe moe
# 	)as pop2024mp,
#
#  -----END-----
# pop2529mp 	 acs1418.acs_moe_pct(
# 	array[e._009,e._024], --estimate
# 	array[e._001], --universe estimate
# 	array[m._009,m._024], --moe
# 	array[m._001]  --universe moe
# 	)as pop2529mp,
#
#  -----END-----
# pop3034mp 	 acs1418.acs_moe_pct(
# 	array[e._010,e._025], --estimate
# 	array[e._001], --universe estimate
# 	array[m._010,m._025], --moe
# 	array[m._001]  --universe moe
# 	)as pop3034mp,
#
#  -----END-----
# pop3544mp 	 acs1418.acs_moe_pct(
# 	array[e._011,e._026], --estimate
# 	array[e._001], --universe estimate
# 	array[m._011,m._026], --moe
# 	array[m._001]  --universe moe
# 	)as pop3544mp,
#
#  -----END-----
# pop4554mp 	 acs1418.acs_moe_pct(
# 	array[e._012,e._027], --estimate
# 	array[e._001], --universe estimate
# 	array[m._012,m._027], --moe
# 	array[m._001]  --universe moe
# 	)as pop4554mp,
#
#  -----END-----
# pop5564mp 	 acs1418.acs_moe_pct(
# 	array[e._013,e._028], --estimate
# 	array[e._001], --universe estimate
# 	array[m._013,m._028], --moe
# 	array[m._001]  --universe moe
# 	)as pop5564mp,
#
#  -----END-----
# pop6574mp 	 acs1418.acs_moe_pct(
# 	array[e._014,e._029], --estimate
# 	array[e._001], --universe estimate
# 	array[m._014,m._029], --moe
# 	array[m._001]  --universe moe
# 	)as pop6574mp,
#
#  -----END-----
# pop7584mp 	 acs1418.acs_moe_pct(
# 	array[e._015,e._030], --estimate
# 	array[e._001], --universe estimate
# 	array[m._015,m._030], --moe
# 	array[m._001]  --universe moe
# 	)as pop7584mp,
#
#  -----END-----
# pop85omp 	 acs1418.acs_moe_pct(
# 	array[e._016,e._031], --estimate
# 	array[e._001], --universe estimate
# 	array[m._016,m._031], --moe
# 	array[m._001]  --universe moe
# 	)as pop85omp,
#
#  -----END-----
# pop_u18mp 	 acs1418.acs_moe_pct(
# 	array[e._003,e._004,e._005,e._006,e._018,e._019,e._020,e._021], --estimate
# 	array[e._001], --universe estimate
# 	array[m._003,m._004,m._005,m._006,m._018,e._019,e._020,e._021], --moe
# 	array[m._001]  --universe moe
# 	)as pop_u18mp,
#
#  -----END-----
# pop1824mp 	 acs1418.acs_moe_pct(
# 	array[e._007,e._008,e._022,e._023], --estimate
# 	array[e._001], --universe estimate
# 	array[m._007,m._008,m._022,m._023], --moe
# 	array[m._001]  --universe moe
# 	)as pop1824mp,
#
#  -----END-----
# pop2534mp 	 acs1418.acs_moe_pct(
# 	array[e._009,e._010,e._024,e._025], --estimate
# 	array[e._001], --universe estimate
# 	array[m._009,m._010,m._024,m._025], --moe
# 	array[m._001]  --universe moe
# 	)as pop2534mp,
#
#  -----END-----
# pop3564mp 	 acs1418.acs_moe_pct(
# 	array[e._011,e._012,e._013,e._026,e._027,e._028], --estimate
# 	array[e._001], --universe estimate
# 	array[m._011,m._012,m._013,m._026,m._027,m._028], --moe
# 	array[m._001]  --universe moe
# 	)as pop3564mp,
#
#  -----END-----
# pop65ovmp 	 acs1418.acs_moe_pct(
# 	array[e._014,e._015,e._016,e._029,e._030,e._031], --estimate
# 	array[e._001], --universe estimate
# 	array[m._014,m._015,m._016,m._029,m._030,m._031], --moe
# 	array[m._001]  --universe moe
# 	)as pop65ovmp,
#
#  -----END-----
# pop1834mp 	 acs1418.acs_moe_pct(
# 	array[e._007,e._008,e._009,e._010,e._022,e._023,e._024,e._025], --estimate
# 	array[e._001], --universe estimate
# 	array[m._007,m._008,m._009,m._010,m._022,m._023,m._024,m._025],
# 	array[m._001]  --universe moe
# 	) as pop1834mp,
#
#  -----END-----
# pop4564mp 	 acs1418.acs_moe_pct(
# 	array[e._012,e._013,e._027,e._028], --estimate
# 	array[e._001], --universe estimate
# 	array[m._012,m._013,m._027,m._028],
# 	array[m._001]  --universe moe
# 	) as pop4564mp,
#
#  -----END-----
# fpop_mp 	 acs1418.acs_moe_pct(
# 	array[e._017], --estimate
# 	array[e._001], --universe estimate
# 	array[m._017], --moe
# 	array[m._001]  --universe moe
# 	)as fpop_mp,
#
#  -----END-----
# fpop_u5mp 	 acs1418.acs_moe_pct(
# 	array[e._018], --estimate
# 	array[e._001], --universe estimate
# 	array[m._018], --moe
# 	array[m._001]  --universe moe
# 	)as fpop_u5mp,
#
#  -----END-----
# fpop_5_9mp 	 acs1418.acs_moe_pct(
# 	array[e._019], --estimate
# 	array[e._001], --universe estimate
# 	array[m._019], --moe
# 	array[m._001]  --universe moe
# 	)as fpop_5_9mp,
#
#  -----END-----
# fpop1014mp 	 acs1418.acs_moe_pct(
# 	array[e._020], --estimate
# 	array[e._001], --universe estimate
# 	array[m._020], --moe
# 	array[m._001]  --universe moe
# 	)as fpop1014mp,
#
#  -----END-----
# fpop1517mp 	 acs1418.acs_moe_pct(
# 	array[e._021], --estimate
# 	array[e._001], --universe estimate
# 	array[m._021], --moe
# 	array[m._001]  --universe moe
# 	)as fpop1517mp,
#
#  -----END-----
# fpop1819mp 	 acs1418.acs_moe_pct(
# 	array[e._022], --estimate
# 	array[e._001], --universe estimate
# 	array[m._022], --moe
# 	array[m._001]  --universe moe
# 	)as fpop1819mp,
#
#  -----END-----
# fpop2024mp 	 acs1418.acs_moe_pct(
# 	array[e._023], --estimate
# 	array[e._001], --universe estimate
# 	array[m._023], --moe
# 	array[m._001]  --universe moe
# 	)as fpop2024mp,
#
#  -----END-----
# fpop2529mp 	 acs1418.acs_moe_pct(
# 	array[e._024], --estimate
# 	array[e._001], --universe estimate
# 	array[m._024], --moe
# 	array[m._001]  --universe moe
# 	)as fpop2529mp,
#
#  -----END-----
# fpop3034mp 	 acs1418.acs_moe_pct(
# 	array[e._025], --estimate
# 	array[e._001], --universe estimate
# 	array[m._025], --moe
# 	array[m._001]  --universe moe
# 	)as fpop3034mp,
#
#  -----END-----
# fpop3544mp 	 acs1418.acs_moe_pct(
# 	array[e._026], --estimate
# 	array[e._001], --universe estimate
# 	array[m._026], --moe
# 	array[m._001]  --universe moe
# 	)as fpop3544mp,
#
#  -----END-----
# fpop4554mp 	 acs1418.acs_moe_pct(
# 	array[e._027], --estimate
# 	array[e._001], --universe estimate
# 	array[m._027], --moe
# 	array[m._001]  --universe moe
# 	)as fpop4554mp,
#
#  -----END-----
# fpop5564mp 	 acs1418.acs_moe_pct(
# 	array[e._028], --estimate
# 	array[e._001], --universe estimate
# 	array[m._028], --moe
# 	array[m._001]  --universe moe
# 	)as fpop5564mp,
#
#  -----END-----
# fpop6574mp 	 acs1418.acs_moe_pct(
# 	array[e._029], --estimate
# 	array[e._001], --universe estimate
# 	array[m._029], --moe
# 	array[m._001]  --universe moe
# 	)as fpop6574mp,
#
#  -----END-----
# fpop7584mp 	 acs1418.acs_moe_pct(
# 	array[e._030], --estimate
# 	array[e._001], --universe estimate
# 	array[m._030], --moe
# 	array[m._001]  --universe moe
# 	)as fpop7584mp,
#
#  -----END-----
# fpop85omp 	 acs1418.acs_moe_pct(
# 	array[e._031], --estimate
# 	array[e._001], --universe estimate
# 	array[m._031], --moe
# 	array[m._001]  --universe moe
# 	)as fpop85omp,
#
#  -----END-----
# fpop_u18mp 	 acs1418.acs_moe_pct(
# 	array[e._018,e._019,e._020,e._021], --estimate
# 	array[e._001], --universe estimate
# 	array[m._018,e._019,e._020,e._021], --moe
# 	array[m._001]  --universe moe
# 	)as fpop_u18mp,
#
#  -----END-----
# fpop1824mp 	 acs1418.acs_moe_pct(
# 	array[e._022,e._023], --estimate
# 	array[e._001], --universe estimate
# 	array[m._022,m._023], --moe
# 	array[m._001]  --universe moe
# 	)as fpop1824mp,
#
#  -----END-----
# fpop2534mp 	 acs1418.acs_moe_pct(
# 	array[e._024,e._025], --estimate
# 	array[e._001], --universe estimate
# 	array[m._024,m._025], --moe
# 	array[m._001]  --universe moe
# 	)as fpop2534mp,
#
#  -----END-----
# fpop3564mp 	 acs1418.acs_moe_pct(
# 	array[e._026,e._027,e._028], --estimate
# 	array[e._001], --universe estimate
# 	array[m._026,m._027,m._028], --moe
# 	array[m._001]  --universe moe
# 	)as fpop3564mp,
#
#  -----END-----
# fpop65ovmp 	 acs1418.acs_moe_pct(
# 	array[e._029,e._030,e._031], --estimate
# 	array[e._001], --universe estimate
# 	array[m._029,m._030,m._031], --moe
# 	array[m._001]  --universe moe
# 	)as fpop65ovmp,
#
#  -----END-----
# fpop1834mp 	 acs1418.acs_moe_pct(
# 	array[e._022,e._023,e._024,e._025], --estimate
# 	array[e._001], --universe estimate
# 	array[m._022,m._023,m._024,m._025],
# 	array[m._001]  --universe moe
# 	) as fpop1834mp,
#
#  -----END-----
# fpop4564mp 	 acs1418.acs_moe_pct(
# 	array[e._012,e._013,e._027,e._028], --estimate
# 	array[e._001], --universe estimate
# 	array[m._012,m._013,m._027,m._028],
# 	array[m._001]  --universe moe
# 	) as fpop4564mp,
#
#  -----END-----
# mpop_mp 	 acs1418.acs_moe_pct(
# 	array[e._002], --estimate
# 	array[e._001], --universe estimate
# 	array[m._002], --moe
# 	array[m._001]  --universe moe
# 	)as mpop_mp,
#
#  -----END-----
# mpop_u5mp 	 acs1418.acs_moe_pct(
# 	array[e._003], --estimate
# 	array[e._001], --universe estimate
# 	array[m._003], --moe
# 	array[m._001]  --universe moe
# 	)as mpop_u5mp,
#
#  -----END-----
# mpop_5_9mp 	 acs1418.acs_moe_pct(
# 	array[e._004], --estimate
# 	array[e._001], --universe estimate
# 	array[m._004], --moe
# 	array[m._001]  --universe moe
# 	)as mpop_5_9mp,
#
#  -----END-----
# ...
# 	array[m._003,m._007,m._011,m._015,m._019] --universe moe
# 	)as o_75mep,
#
#  -----END-----
# o_75cbmep 	 acs1418.acs_moe_pct(
# 	array[e._022],--estimate
# 	array[e._019], --universe estimate
# 	array[m._022],--moe
# 	array[m._019] --universe moe
# 	)as o_75cbmep,
#
#  -----END-----
# r_occ_mep 	 acs1418.acs_moe_pct(
# 	array[e._024],--estimate
# 	array[e._001], --universe estimate
# 	array[m._024],--moe
# 	array[m._001] --universe moe
# 	)as r_occ_mep,
#
#  -----END-----
# r_35mep 	 acs1418.acs_moe_pct(
# 	array[e._025,e._029],--estimate
# 	array[e._025,e._029,e._033,e._037,e._041], --universe estimate
# 	array[m._025,m._029],--moe
# 	array[m._025,m._029,m._033,m._037,m._041] --universe moe
# 	)as r_35mep,
#
#  -----END-----
# r_35cbmep 	 acs1418.acs_moe_pct(
# 	array[e._028,e._032],--estimate
# 	array[e._025,e._029], --universe estimate
# 	array[m._028,m._032],--moe
# 	array[m._025,m._029] --universe moe
# 	)as r_35cbmep,
#
#  -----END-----
# r_3575mep 	 acs1418.acs_moe_pct(
# 	array[e._033,e._037],--estimate
# 	array[e._025,e._029,e._033,e._037,e._041], --universe estimate
# 	array[m._033,m._037],--moe
# 	array[m._025,m._029,m._033,m._037,m._041] --universe moe
# 	)as r_3575mep,
#
#  -----END-----
# r_3575cbmp 	 acs1418.acs_moe_pct(
# 	array[e._036,e._040],--estimate
# 	array[e._033,e._037], --universe estimate
# 	array[m._036,m._040],--moe
# 	array[m._033,m._037] --universe moe
# 	)as r_3575cbmp,
#
#  -----END-----
# r_75mep 	 acs1418.acs_moe_pct(
# 	array[e._041],--estimate
# 	array[e._025,e._029,e._033,e._037,e._041], --universe estimate
# 	array[m._041],--moe
# 	array[m._025,m._029,m._033,m._037,m._041] --universe moe
# 	)as r_75mep,
#
#  -----END-----
#  	 acs1418.acs_moe_pct(
# 	array[e._044],--estimate
# 	array[e._041], --universe estimate
# 	array[m._044],--moe
# 	array[m._041] --universe moe
# 	)as r_75cbmep
#
#  -----END-----
# gas_mep 	 acs1418.acs_moe_pct(
# 	array[e._003::numeric,e._013::numeric],--estimate
# 	array[e._001::numeric], --universe estimate
# 	array[m._003::numeric,m._013::numeric],--moe
# 	array[m._001::numeric] --universe moe
# 	)as gas_mep,
#
#  -----END-----
# othgas_mep 	 acs1418.acs_moe_pct(
# 	array[e._004::numeric,e._014::numeric],--estimate
# 	array[e._001::numeric], --universe estimate
# 	array[m._004::numeric,m._014::numeric],--moe
# 	array[m._001::numeric] --universe moe
# 	)as othgas_mep,
#
#  -----END-----
# elec_mep 	 acs1418.acs_moe_pct(
# 	array[e._005::numeric,e._015::numeric],--estimate
# 	array[e._001::numeric], --universe estimate
# 	array[m._005::numeric,m._015::numeric],--moe
# 	array[m._001::numeric] --universe moe
# 	)as elec_mep,
#
#  -----END-----
# oil_mep 	 acs1418.acs_moe_pct(
# 	array[e._006::numeric,e._016::numeric],--estimate
# 	array[e._001::numeric], --universe estimate
# 	array[m._006::numeric,m._016::numeric],--moe
# 	array[m._001::numeric] --universe moe
# 	)as oil_mep,
#
#  -----END-----
# coal_mep 	 acs1418.acs_moe_pct(
# 	array[e._007::numeric,e._017::numeric],--estimate
# 	array[e._001::numeric], --universe estimate
# 	array[m._007::numeric,m._017::numeric],--moe
# 	array[m._001::numeric] --universe moe
# 	)as coal_mep,
#
#  -----END-----
# wood_mep 	 acs1418.acs_moe_pct(
# 	array[e._008::numeric,e._018::numeric],--estimate
# 	array[e._001::numeric], --universe estimate
# 	array[m._008::numeric,m._018::numeric],--moe
# 	array[m._001::numeric] --universe moe
# 	)as wood_mep,
#
#  -----END-----
# solar_mep 	 acs1418.acs_moe_pct(
# 	array[e._009::numeric,e._019::numeric],--estimate
# 	array[e._001::numeric], --universe estimate
# 	array[m._009::numeric,m._019::numeric],--moe
# 	array[m._001::numeric] --universe moe
# 	)as solar_mep,
#
#  -----END-----
# other_mep 	 acs1418.acs_moe_pct(
# 	array[e._010::numeric,e._020],--estimate
# 	array[e._001::numeric], --universe estimate
# 	array[m._010::numeric,m._020],--moe
# 	array[m._001::numeric] --universe moe
# 	)as other_mep,
#
#  -----END-----
# none_mep 	 acs1418.acs_moe_pct(
# 	array[e._011::numeric,e._021::numeric],--estimate
# 	array[e._001::numeric], --universe estimate
# 	array[m._011::numeric,m._021::numeric],--moe
# 	array[m._001::numeric] --universe moe
# 	)as none_mep,
#
#  -----END-----
# whilh_mep 	 acs1418.acs_moe_pct(
# 	array[whi_e._003,whi_e._008],--estimate
# 	array[whi_e._001], --universe estimate
# 	array[whi_m._003,whi_m._008],--moe
# 	array[whi_m._001] --universe moe
# 	)as whilh_mep,
#
#  -----END-----
# whihs_mep 	 acs1418.acs_moe_pct(
# 	array[whi_e._004,whi_e._009],--estimate
# 	array[whi_e._001], --universe estimate
# 	array[whi_m._004,whi_m._009],--moe
# 	array[whi_m._001] --universe moe
# 	)as whihs_mep,
#
#  -----END-----
# whisc_mep 	 acs1418.acs_moe_pct(
# 	array[whi_e._005,whi_e._010],--estimate
# 	array[whi_e._001], --universe estimate
# 	array[whi_m._005,whi_m._010],--moe
# 	array[whi_m._001] --universe moe
# 	)as whisc_mep,
#
#  -----END-----
# whibd_mep 	 acs1418.acs_moe_pct(
# 	array[whi_e._006,whi_e._011],--estimate
# 	array[whi_e._001], --universe estimate
# 	array[whi_m._006,whi_m._011],--moe
# 	array[whi_m._001] --universe moe
# 	)as whibd_mep,
#
#  -----END-----
# aalh_mep 	 acs1418.acs_moe_pct(
# 	array[aa_e._003,aa_e._008],--estimate
# 	array[aa_e._001], --universe estimate
# 	array[aa_m._003,aa_m._008],--moe
# 	array[aa_m._001] --universe moe
# 	)as aalh_mep,
#
#  -----END-----
# aahs_mep 	 acs1418.acs_moe_pct(
# 	array[aa_e._004,aa_e._009],--estimate
# 	array[aa_e._001], --universe estimate
# 	array[aa_m._004,aa_m._009],--moe
# 	array[aa_m._001] --universe moe
# 	)as aahs_mep,
#
#  -----END-----
# aasc_mep 	 acs1418.acs_moe_pct(
# 	array[aa_e._005,aa_e._010],--estimate
# 	array[aa_e._001], --universe estimate
# 	array[aa_m._005,aa_m._010],--moe
# 	array[aa_m._001] --universe moe
# 	)as aasc_mep,
#
#  -----END-----
# aabd_mep 	 acs1418.acs_moe_pct(
# 	array[aa_e._006,aa_e._011],--estimate
# 	array[aa_e._001], --universe estimate
# 	array[aa_m._006,aa_m._011],--moe
# 	array[aa_m._001] --universe moe
# 	)as aabd_mep,
#
#  -----END-----
# nalh_mep 	 acs1418.acs_moe_pct(
# 	array[na_e._003,na_e._008],--estimate
# 	array[na_e._001], --universe estimate
# 	array[na_m._003,na_m._008],--moe
# 	array[na_m._001] --universe moe
# 	)as nalh_mep,
#
#  -----END-----
# nahs_mep 	 acs1418.acs_moe_pct(
# 	array[na_e._004,na_e._009],--estimate
# 	array[na_e._001], --universe estimate
# 	array[na_m._004,na_m._009],--moe
# 	array[na_m._001] --universe moe
# 	)as nahs_mep,
#
#  -----END-----
# nasc_mep 	 acs1418.acs_moe_pct(
# 	array[na_e._005,na_e._010],--estimate
# 	array[na_e._001], --universe estimate
# 	array[na_m._005,na_m._010],--moe
# 	array[na_m._001] --universe moe
# 	)as nasc_mep,
#
#  -----END-----
# nabd_mep 	 acs1418.acs_moe_pct(
# 	array[na_e._006,na_e._011],--estimate
# 	array[na_e._001], --universe estimate
# 	array[na_m._006,na_m._011],--moe
# 	array[na_m._001] --universe moe
# 	)as nabd_mep,
#
#  -----END-----
#  	 acs1418.acs_moe_pct(
# 	array[as_e._003,as_e._008],--estimate
# 	array[as_e._001], --universe estimate
# 	array[as_m._003,as_m._008],--moe
# 	array[as_m._001] --universe moe
#
#  -----END-----
# dis_mp 	 acs1418.acs_moe_pct(
# 	array[e._004,e._007,e._010], --estimate
# 	array[e._001], --universe estimate
# 	array[m._004,m._007,m._010], --moe
# 	array[m._001]  --universe moe
# 	) as dis_mp,
#
#  -----END-----
# ndis_mp 	 acs1418.acs_moe_pct(
# 	array[e._005,e._008,e._011], --estimate
# 	array[e._001], --universe estimate
# 	array[m._005,m._008,m._011], --moe
# 	array[m._001]  --universe moe
# 	) as ndis_mp,
#
#  -----END-----
# dislf_mp 	 acs1418.acs_moe_pct(
# 	array[e._004,e._007], --estimate
# 	array[e._004,e._007,e._010], --universe estimate
# 	array[m._004,m._007], --moe
# 	array[m._004,m._007,m._010]  --universe moe
# 	) as dislf_mp,
#
#  -----END-----
# disnlf_mp 	 acs1418.acs_moe_pct(
# 	array[e._010], --estimate
# 	array[e._004,e._007,e._010], --universe estimate
# 	array[m._010], --moe
# 	array[m._004,m._007,m._010]  --universe moe
# 	) as disnlf_mp,
#
#  -----END-----
# ndlf_mp 	 acs1418.acs_moe_pct(
# 	array[e._005,e._008], --estimate
# 	array[e._005,e._008,e._011], --universe estimate
# 	array[m._005,m._008], --moe
# 	array[m._005,m._008,m._011]  --universe moe
# 	) as ndlf_mp,
#
#  -----END-----
# ndnlf_mp 	 acs1418.acs_moe_pct(
# 	array[e._011], --estimate
# 	array[e._005,e._008,e._011], --universe estimate
# 	array[m._011], --moe
# 	array[m._005,m._008,m._011]  --universe moe
# 	) as ndnlf_mp,
#
#  -----END-----
# lfmp 	 acs1418.acs_moe_pct(
# 	array[e._002], --estimate
# 	array[e._001], --universe estimate
# 	array[m._002], --moe
# 	array[m._001]  --universe moe
# 	) as lfmp,
#
#  -----END-----
# lfdis_mp 	 acs1418.acs_moe_pct(
# 	array[e._004,e._007], --estimate
# 	array[e._002], --universe estimate
# 	array[m._004,m._007], --moe
# 	array[m._002]  --universe moe
# 	) as lfdis_mp,
#
#  -----END-----
# lfnd_mp 	 acs1418.acs_moe_pct(
# 	array[e._005,e._008], --estimate
# 	array[e._002], --universe estimate
# 	array[m._005,m._008], --moe
# 	array[m._002]  --universe moe
# 	) as lfnd_mp,
#
#  -----END-----
# emp_mp 	 acs1418.acs_moe_pct(
# 	array[e._003], --estimate
# 	array[e._002], --universe estimate
# 	array[m._003], --moe
# 	array[m._002]  --universe moe
# 	) as emp_mp,
#
#  -----END-----
# empdis_mp 	 acs1418.acs_moe_pct(
# 	array[e._004], --estimate
# 	array[e._003], --universe estimate
# 	array[m._004], --moe
# 	array[m._003]  --universe moe
# 	) as empdis_mp,
#
#  -----END-----
# empnd_mp 	 acs1418.acs_moe_pct(
# 	array[e._005], --estimate
# 	array[e._003], --universe estimate
# 	array[m._005], --moe
# 	array[m._003]  --universe moe
# 	) as empnd_mp,
#
#  -----END-----
# uemp_mp 	 acs1418.acs_moe_pct(
# 	array[e._006], --estimate
# 	array[e._002], --universe estimate
# 	array[m._006], --moe
# 	array[m._002]  --universe moe
# 	) as uemp_mp,
#
#  -----END-----
# uempdis_mp 	 acs1418.acs_moe_pct(
# 	array[e._007], --estimate
# 	array[e._006], --universe estimate
# 	array[m._007], --moe
# 	array[m._006]  --universe moe
# 	) as uempdis_mp,
#
#  -----END-----
# uempnd_mp 	 acs1418.acs_moe_pct(
# 	array[e._008], --estimate
# 	array[e._006], --universe estimate
# 	array[m._008], --moe
# 	array[m._006]  --universe moe
# 	) as uempnd_mp,
#
#  -----END-----
# disemp_mp 	 acs1418.acs_moe_pct(
# 	array[e._004], 			--estimate
# 	array[e._004,e._007], 	--universe estimate
# 	array[m._004], 			--moe
# 	array[m._004,m._007]  	--universe moe
# 	) as disemp_mp,
#
#  -----END-----
# ndemp_mp 	 acs1418.acs_moe_pct(
# 	array[e._005], --estimate
# 	array[e._005,e._008], --universe estimate
# 	array[m._005], --moe
# 	array[m._005,m._008]  --universe moe
# 	) as ndemp_mp,
#
#  -----END-----
# disuemp_mp 	 acs1418.acs_moe_pct(
# 	array[e._007], --estimate
# 	array[e._004,e._007], --universe estimate
# 	array[m._007], --moe
# 	array[m._004,m._007]  --universe moe
# 	) as disuemp_mp,
#
#  -----END-----
# nduemp_mp 	 acs1418.acs_moe_pct(
# 	array[e._008], --estimate
# 	array[e._005,e._008], --universe estimate
# 	array[m._008], --moe
# 	array[m._005,m._008]  --universe moe
# 	) as nduemp_mp,
#
#  -----END-----
# nlfmp 	 acs1418.acs_moe_pct(
# 	array[e._009], --estimate
# 	array[e._001], --universe estimate
# 	array[m._009], --moe
# 	array[m._001]  --universe moe
# 	) as nlfmp,
#
#  -----END-----
# nlfdis_mp 	 acs1418.acs_moe_pct(
# 	array[e._010], --estimate
# 	array[e._009], --universe estimate
# 	array[m._010], --moe
# 	array[m._009]  --universe moe
# 	) as nlfdis_mp,
#
#  -----END-----
#  	 acs1418.acs_moe_pct(
# 	array[e._011], --estimate
# 	array[e._009], --universe estimate
# 	array[m._011], --moe
# 	array[m._009]  --universe moe
# 	) as nlfnd_mp
#
#  -----END-----
# dismp 	 acs1418.acs_moe_pct(
# 	array[e._003,e._010,e._017],--estimate
# 	array[e._001], --universe estimate
# 	array[m._003,m._010,m._017],--moe
# 	array[m._001] --universe moe
# 	)as dismp,
#
#  -----END-----
# ndmp 	 acs1418.acs_moe_pct(
# 	array[e._006,e._013,e._020],--estimate
# 	array[e._001], --universe estimate
# 	array[m._006,m._013,m._020],--moe
# 	array[m._001] --universe moe
# 	)as ndmp,
#
#  -----END-----
# dispovmp 	 acs1418.acs_moe_pct(
# 	array[e._004,e._011,e._018],--estimate
# 	array[e._003,e._010,e._017], --universe estimate
# 	array[m._004,m._011,m._018],--moe
# 	array[m._003,m._010,m._017] --universe moe
# 	)as dispovmp,
#
#  -----END-----
# ndpovmp 	 acs1418.acs_moe_pct(
# 	array[e._007,e._014,e._021],--estimate
# 	array[e._006,e._013,e._020], --universe estimate
# 	array[m._007,m._014,m._021],--moe
# 	array[m._006,m._013,m._020] --universe moe
# 	)as ndpovmp,
#
#  -----END-----
# disnpovmp 	 acs1418.acs_moe_pct(
# 	array[e._005,e._012,e._019],--estimate
# 	array[e._003,e._010,e._017], --universe estimate
# 	array[m._005,m._012,m._019],--moe
# 	array[m._003,m._010,m._017] --universe moe
# 	)as disnpovmp,
#
#  -----END-----
# ndnpovmp 	 acs1418.acs_moe_pct(
# 	array[e._008,e._015,e._022],--estimate
# 	array[e._006,e._013,e._020], --universe estimate
# 	array[m._008,m._015,m._022],--moe
# 	array[m._006,m._013,m._020] --universe moe
# 	)as ndnpovmp,
#
#  -----END-----
# cnpopu18mp 	 acs1418.acs_moe_pct(
# 	array[e._002],--estimate
# 	array[e._001], --universe estimate
# 	array[m._002],--moe
# 	array[m._001] --universe moe
# 	)as cnpopu18mp,
#
#  -----END-----
# du18mp 	 acs1418.acs_moe_pct(
# 	array[e._003],--estimate
# 	array[e._002], --universe estimate
# 	array[m._003],--moe
# 	array[m._002] --universe moe
# 	)as du18mp,
#
#  -----END-----
# du18pvmp 	 acs1418.acs_moe_pct(
# 	array[e._004],--estimate
# 	array[e._003], --universe estimate
# 	array[m._004],--moe
# 	array[m._003] --universe moe
# 	)as du18pvmp,
#
#  -----END-----
# du18npvmp 	 acs1418.acs_moe_pct(
# 	array[e._005],--estimate
# 	array[e._003], --universe estimate
# 	array[m._005],--moe
# 	array[m._003] --universe moe
# 	)as du18npvmp,
#
#  -----END-----
# ndu18mp 	 acs1418.acs_moe_pct(
# 	array[e._006],--estimate
# 	array[e._002], --universe estimate
# 	array[m._006],--moe
# 	array[m._002] --universe moe
# 	)as ndu18mp,
#
#  -----END-----
# ndu18pvmp 	 acs1418.acs_moe_pct(
# 	array[e._007],--estimate
# 	array[e._006], --universe estimate
# 	array[m._007],--moe
# 	array[m._006] --universe moe
# 	)as ndu18pvmp,
#
#  -----END-----
# ndu18npvmp 	 acs1418.acs_moe_pct(
# 	array[e._008],--estimate
# 	array[e._006], --universe estimate
# 	array[m._008],--moe
# 	array[m._006] --universe moe
# 	)as ndu18npvmp,
#
#  -----END-----
# cnp1864mp 	 acs1418.acs_moe_pct(
# 	array[e._009],--estimate
# 	array[e._001], --universe estimate
# 	array[m._009],--moe
# 	array[m._001] --universe moe
# 	)as cnp1864mp,
#
#  -----END-----
# d1864mp 	 acs1418.acs_moe_pct(
# 	array[e._010],--estimate
# 	array[e._009], --universe estimate
# 	array[m._010],--moe
# 	array[m._009] --universe moe
# 	)as d1864mp,
#
#  -----END-----
# d1864pvmp 	 acs1418.acs_moe_pct(
# 	array[e._011],--estimate
# 	array[e._010], --universe estimate
# 	array[m._011],--moe
# 	array[m._010] --universe moe
# 	)as d1864pvmp,
#
#  -----END-----
# d1864npvmp 	 acs1418.acs_moe_pct(
# 	array[e._012],--estimate
# 	array[e._010], --universe estimate
# 	array[m._012],--moe
# 	array[m._010] --universe moe
# 	)as d1864npvmp,
#
#  -----END-----
# nd1864mp 	 acs1418.acs_moe_pct(
# 	array[e._013],--estimate
# 	array[e._009], --universe estimate
# 	array[m._013],--moe
# 	array[m._009] --universe moe
# 	)as nd1864mp,
#
#  -----END-----
# nd1864pvmp 	 acs1418.acs_moe_pct(
# 	array[e._014],--estimate
# 	array[e._013], --universe estimate
# 	array[m._014],--moe
# 	array[m._013] --universe moe
# 	)as nd1864pvmp,
#
#  -----END-----
# nd1864npmp 	 acs1418.acs_moe_pct(
# 	array[e._015],--estimate
# 	array[e._013], --universe estimate
# 	array[m._015],--moe
# 	array[m._013] --universe moe
# 	)as nd1864npmp,
#
#  -----END-----
# cnpop65omp 	 acs1418.acs_moe_pct(
# 	array[e._016],--estimate
# 	array[e._001], --universe estimate
# 	array[m._016],--moe
# 	array[m._001] --universe moe
# 	)as cnpop65omp,
#
#  -----END-----
# d65omp 	 acs1418.acs_moe_pct(
# 	array[e._017],--estimate
# 	array[e._016], --universe estimate
# 	array[m._017],--moe
# 	array[m._016] --universe moe
# 	)as d65omp,
#
#  -----END-----
# d65opvmp 	 acs1418.acs_moe_pct(
# 	array[e._018],--estimate
# 	array[e._017], --universe estimate
# 	array[m._018],--moe
# 	array[m._017] --universe moe
# 	)as d65opvmp,
#
#  -----END-----
# d65onpvmp 	 acs1418.acs_moe_pct(
# 	array[e._019],--estimate
# 	array[e._017], --universe estimate
# 	array[m._019],--moe
# 	array[m._017] --universe moe
# 	)as d65onpvmp,
#
#  -----END-----
# nd65omp 	 acs1418.acs_moe_pct(
# 	array[e._020],--estimate
# 	array[e._016], --universe estimate
# 	array[m._020],--moe
# 	array[m._016] --universe moe
# 	)as nd65omp,
#
#  -----END-----
# nd65opvmp 	 acs1418.acs_moe_pct(
# 	array[e._021],--estimate
# 	array[e._020], --universe estimate
# 	array[m._021],--moe
# 	array[m._020] --universe moe
# 	)as nd65opvmp,
#
#  -----END-----
#  	 acs1418.acs_moe_pct(
# 	array[e._022],--estimate
# 	array[e._020], --universe estimate
# 	array[m._022],--moe
# 	array[m._020] --universe moe
# 	)as nd65onpvmp
#
#  -----END-----

# %%
uni_dict

[x for x in uni_dict if x['table'] == 'b01001_population_by_age_gender_acs_m']
# Out:
# [{'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop',
#   'moe': False,
#   'percent': False,
#   'estimate': ['001'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'popm',
#   'moe': True,
#   'percent': False,
#   'estimate': ['001'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_u5',
#   'moe': False,
#   'percent': False,
#   'estimate': ['003', '027'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_u5m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['003', '027'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_5_9',
#   'moe': False,
#   'percent': False,
#   'estimate': ['004', '028'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_5_9m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['004', '028'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1014',
#   'moe': False,
#   'percent': False,
#   'estimate': ['005', '029'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1014m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['005', '029'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1517',
#   'moe': False,
#   'percent': False,
#   'estimate': ['006', '030'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1517m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['006', '030'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1819',
#   'moe': False,
#   'percent': False,
#   'estimate': ['007', '031'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1819m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['007', '031'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop20',
#   'moe': False,
#   'percent': False,
#   'estimate': ['008', '032'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop20m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['008', '032'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop21',
#   'moe': False,
#   'percent': False,
#   'estimate': ['009', '033'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop21m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['009', '033'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2224',
#   'moe': False,
#   'percent': False,
#   'estimate': ['010', '034'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2224m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['010', '034'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2529',
#   'moe': False,
#   'percent': False,
#   'estimate': ['011', '035'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2529m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['011', '035'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3034',
#   'moe': False,
#   'percent': False,
#   'estimate': ['012', '036'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3034m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['012', '036'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3539',
#   'moe': False,
#   'percent': False,
#   'estimate': ['013', '037'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3539m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['013', '037'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop4044',
#   'moe': False,
#   'percent': False,
#   'estimate': ['014', '038'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop4044m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['014', '038'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop4549',
#   'moe': False,
#   'percent': False,
#   'estimate': ['015', '039'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop4549m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['015', '039'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop5054',
#   'moe': False,
#   'percent': False,
#   'estimate': ['016', '040'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop5054m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['016', '040'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop5559',
#   'moe': False,
#   'percent': False,
#   'estimate': ['017', '041'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop5559m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['017', '041'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop6061',
#   'moe': False,
#   'percent': False,
#   'estimate': ['018', '042'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop6061m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['018', '042'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop6264',
#   'moe': False,
#   'percent': False,
#   'estimate': ['019', '043'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop6264m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['019', '043'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop6566',
#   'moe': False,
#   'percent': False,
#   'estimate': ['020', '044'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop6566m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['020', '044'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop6769',
#   'moe': False,
#   'percent': False,
#   'estimate': ['021', '045'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop6769m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['021', '045'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop7074',
#   'moe': False,
#   'percent': False,
#   'estimate': ['022', '046'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop7074m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['022', '046'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop7579',
#   'moe': False,
#   'percent': False,
#   'estimate': ['023', '047'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop7579m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['023', '047'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop8084',
#   'moe': False,
#   'percent': False,
#   'estimate': ['024', '048'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop8084m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['024', '048'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop85o',
#   'moe': False,
#   'percent': False,
#   'estimate': ['025', '049'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop85om',
#   'moe': True,
#   'percent': False,
#   'estimate': ['025', '049'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_u18',
#   'moe': False,
#   'percent': False,
#   'estimate': ['003', '004', '005', '006', '027', '028', '029', '030'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_u18m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['003', '004', '005', '006', '027', '028', '029', '030'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1824',
#   'moe': False,
#   'percent': False,
#   'estimate': ['007', '008', '009', '010', '031', '032', '033', '034'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1824m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['007', '008', '009', '010', '031', '032', '033', '034'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2534',
#   'moe': False,
#   'percent': False,
#   'estimate': ['011', '012', '035', '036'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2534m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['011', '012', '035', '036'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3564',
#   'moe': False,
#   'percent': False,
#   'estimate': ['013',
#    '014',
#    '015',
#    '016',
#    '017',
#    '018',
#    '019',
#    '037',
#    '038',
#    '039',
#    '040',
#    '041',
#    '042',
#    '043'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3564m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['013',
#    '014',
#    '015',
#    '016',
#    '017',
#    '018',
#    '019',
#    '037',
#    '038',
#    '039',
#    '040',
#    '041',
#    '042',
#    '043'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop65ov',
#   'moe': False,
#   'percent': False,
#   'estimate': ['020',
#    '021',
#    '022',
#    '023',
#    '024',
#    '025',
#    '044',
#    '045',
#    '046',
#    '047',
#    '048',
#    '049'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop65ovm',
#   'moe': True,
#   'percent': False,
#   'estimate': ['020',
#    '021',
#    '022',
#    '023',
#    '024',
#    '025',
#    '044',
#    '045',
#    '046',
#    '047',
#    '048',
#    '049'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1834',
#   'moe': False,
#   'percent': False,
#   'estimate': ['007',
#    '008',
#    '009',
#    '010',
#    '011',
#    '012',
#    '031',
#    '032',
#    '033',
#    '034',
#    '035',
#    '036'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1834m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['007',
#    '008',
#    '009',
#    '010',
#    '011',
#    '012',
#    '031',
#    '032',
#    '033',
#    '034',
#    '035',
#    '036'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3544',
#   'moe': False,
#   'percent': False,
#   'estimate': ['013', '014', '037', '038'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3544m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['013', '014', '037', '038'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop4564',
#   'moe': False,
#   'percent': False,
#   'estimate': ['015',
#    '016',
#    '017',
#    '018',
#    '019',
#    '039',
#    '040',
#    '041',
#    '042',
#    '043'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop4564m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['015',
#    '016',
#    '017',
#    '018',
#    '019',
#    '039',
#    '040',
#    '041',
#    '042',
#    '043'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop',
#   'moe': False,
#   'percent': False,
#   'estimate': ['026'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpopm',
#   'moe': True,
#   'percent': False,
#   'estimate': ['026'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_u5',
#   'moe': False,
#   'percent': False,
#   'estimate': ['027'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_u5m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['027'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_5_9',
#   'moe': False,
#   'percent': False,
#   'estimate': ['028'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_5_9m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['028'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1014',
#   'moe': False,
#   'percent': False,
#   'estimate': ['029'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1014m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['029'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1517',
#   'moe': False,
#   'percent': False,
#   'estimate': ['030'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1517m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['030'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1819',
#   'moe': False,
#   'percent': False,
#   'estimate': ['031'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1819m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['031'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop20',
#   'moe': False,
#   'percent': False,
#   'estimate': ['032'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop20m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['032'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop21',
#   'moe': False,
#   'percent': False,
#   'estimate': ['033'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop21m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['033'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop2224',
#   'moe': False,
#   'percent': False,
#   'estimate': ['034'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop2224m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['034'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop2529',
#   'moe': False,
#   'percent': False,
#   'estimate': ['035'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop2529m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['035'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3034',
#   'moe': False,
#   'percent': False,
#   'estimate': ['036'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3034m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['036'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3539',
#   'moe': False,
#   'percent': False,
#   'estimate': ['037'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3539m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['037'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop4044',
#   'moe': False,
#   'percent': False,
#   'estimate': ['038'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop4044m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['038'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop4549',
#   'moe': False,
#   'percent': False,
#   'estimate': ['039'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop4549m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['039'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop5054',
#   'moe': False,
#   'percent': False,
#   'estimate': ['040'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop5054m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['040'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop5559',
#   'moe': False,
#   'percent': False,
#   'estimate': ['041'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop5559m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['041'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop6061',
#   'moe': False,
#   'percent': False,
#   'estimate': ['042'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop6061m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['042'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop6264',
#   'moe': False,
#   'percent': False,
#   'estimate': ['043'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop6264m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['043'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop6566',
#   'moe': False,
#   'percent': False,
#   'estimate': ['044'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop6566m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['044'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop6769',
#   'moe': False,
#   'percent': False,
#   'estimate': ['045'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop6769m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['045'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop7074',
#   'moe': False,
#   'percent': False,
#   'estimate': ['046'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop7074m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['046'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop7579',
#   'moe': False,
#   'percent': False,
#   'estimate': ['047'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop7579m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['047'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop8084',
#   'moe': False,
#   'percent': False,
#   'estimate': ['048'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop8084m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['048'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop85o',
#   'moe': False,
#   'percent': False,
#   'estimate': ['049'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop85om',
#   'moe': True,
#   'percent': False,
#   'estimate': ['049'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_u18',
#   'moe': False,
#   'percent': False,
#   'estimate': ['027', '028', '029', '030'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_u18m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['027', '028', '029', '030'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1824',
#   'moe': False,
#   'percent': False,
#   'estimate': ['031', '032', '033', '034'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1824m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['031', '032', '033', '034'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop2534',
#   'moe': False,
#   'percent': False,
#   'estimate': ['035', '036'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop2534m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['035', '036'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3564',
#   'moe': False,
#   'percent': False,
#   'estimate': ['037', '038', '039', '040', '041', '042', '043'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3564m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['037', '038', '039', '040', '041', '042', '043'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop65ov',
#   'moe': False,
#   'percent': False,
#   'estimate': ['044', '045', '046', '047', '048', '049'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop65ovm',
#   'moe': True,
#   'percent': False,
#   'estimate': ['044', '045', '046', '047', '048', '049'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1834',
#   'moe': False,
#   'percent': False,
#   'estimate': ['012', '031', '032', '033', '034', '035', '036'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1834m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['012', '031', '032', '033', '034', '035', '036'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3544',
#   'moe': False,
#   'percent': False,
#   'estimate': ['037', '038'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3544m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['037', '038'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop4564',
#   'moe': False,
#   'percent': False,
#   'estimate': ['039', '040', '041', '042', '043'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop4564m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['039', '040', '041', '042', '043'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop',
#   'moe': False,
#   'percent': False,
#   'estimate': ['002'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpopm',
#   'moe': True,
#   'percent': False,
#   'estimate': ['002'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop_u5',
#   'moe': False,
#   'percent': False,
#   'estimate': ['003'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop_u5m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['003'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop_5_9',
#   'moe': False,
#   'percent': False,
#   'estimate': ['004'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop_5_9m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['004'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1014',
#   'moe': False,
#   'percent': False,
#   'estimate': ['005'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1014m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['005'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1517',
#   'moe': False,
#   'percent': False,
#   'estimate': ['006'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1517m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['006'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1819',
#   'moe': False,
#   'percent': False,
#   'estimate': ['007'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1819m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['007'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop20',
#   'moe': False,
#   'percent': False,
#   'estimate': ['008'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop20m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['008'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop21',
#   'moe': False,
#   'percent': False,
#   'estimate': ['009'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop21m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['009'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop2224',
#   'moe': False,
#   'percent': False,
#   'estimate': ['010'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop2224m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['010'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop2529',
#   'moe': False,
#   'percent': False,
#   'estimate': ['011'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop2529m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['011'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop3034',
#   'moe': False,
#   'percent': False,
#   'estimate': ['012'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop3034m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['012'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop3539',
#   'moe': False,
#   'percent': False,
#   'estimate': ['013'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop3539m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['013'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop4044',
#   'moe': False,
#   'percent': False,
#   'estimate': ['014'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop4044m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['014'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop4549',
#   'moe': False,
#   'percent': False,
#   'estimate': ['015'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop4549m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['015'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop5054',
#   'moe': False,
#   'percent': False,
#   'estimate': ['016'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop5054m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['016'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop5559',
#   'moe': False,
#   'percent': False,
#   'estimate': ['017'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop5559m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['017'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop6061',
#   'moe': False,
#   'percent': False,
#   'estimate': ['018'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop6061m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['018'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop6264',
#   'moe': False,
#   'percent': False,
#   'estimate': ['019'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop6264m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['019'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop6566',
#   'moe': False,
#   'percent': False,
#   'estimate': ['020'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop6566m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['020'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop6769',
#   'moe': False,
#   'percent': False,
#   'estimate': ['021'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop6769m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['021'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop7074',
#   'moe': False,
#   'percent': False,
#   'estimate': ['022'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop7074m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['022'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop7579',
#   'moe': False,
#   'percent': False,
#   'estimate': ['023'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop7579m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['023'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop8084',
#   'moe': False,
#   'percent': False,
#   'estimate': ['024'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop8084m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['024'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop85o',
#   'moe': False,
#   'percent': False,
#   'estimate': ['025'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop85om',
#   'moe': True,
#   'percent': False,
#   'estimate': ['025'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop_u18',
#   'moe': False,
#   'percent': False,
#   'estimate': ['003', '004', '005', '006'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop_u18m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['003', '004', '005', '006'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1824',
#   'moe': False,
#   'percent': False,
#   'estimate': ['007', '008', '009', '010'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1824m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['007', '008', '009', '010'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop2534',
#   'moe': False,
#   'percent': False,
#   'estimate': ['011', '012'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop2534m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['011', '012'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop3564',
#   'moe': False,
#   'percent': False,
#   'estimate': ['013', '014', '015', '016', '017', '018', '019'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop3564m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['013', '014', '015', '016', '017', '018', '019'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop65ov',
#   'moe': False,
#   'percent': False,
#   'estimate': ['020', '021', '022', '023', '024', '025'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop65ovm',
#   'moe': True,
#   'percent': False,
#   'estimate': ['020', '021', '022', '023', '024', '025'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1834',
#   'moe': False,
#   'percent': False,
#   'estimate': ['007', '008', '009', '010', '011', '012'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1834m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['007', '008', '009', '010', '011', '012'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop3544',
#   'moe': False,
#   'percent': False,
#   'estimate': ['013', '014'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop3544m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['013', '014'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop4564',
#   'moe': False,
#   'percent': False,
#   'estimate': ['015', '016', '017', '018', '019'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop4564m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['015', '016', '017', '018', '019'],
#   'universe': []},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_u5p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['003', '027'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_u5mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['003', '027'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_5_9p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['004', '028'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_5_9mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['004', '028'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1014p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['005', '029'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1014mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['005', '029'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1517p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['006', '030'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1517mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['006', '030'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1819p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['007', '031'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1819mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['007', '031'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop20p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['008', '032'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop20mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['008', '032'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop21p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['009', '033'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop21mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['009', '033'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2224p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['010', '034'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2224mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['010', '034'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2529p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['011', '035'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2529mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['011', '035'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3034p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['012', '036'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3034mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['012', '036'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3539p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['013', '037'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3539mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['013', '037'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop4044p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['014', '038'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop4044mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['014', '038'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop4549p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['015', '039'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop4549mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['015', '039'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop5054p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['016', '040'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop5054mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['016', '040'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop5559p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['017', '041'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop5559mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['017', '041'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop6061p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['018', '042'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop6061mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['018', '042'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop6264p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['019', '043'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop6264mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['019', '043'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop6566p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['020', '044'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop6566mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['020', '044'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop6769p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['021', '045'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop6769mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['021', '045'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop7074p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['022', '046'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop7074mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['022', '046'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop7579p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['023', '047'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop7579mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['023', '047'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop8084p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['024', '048'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop8084mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['024', '048'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop85op',
#   'moe': False,
#   'percent': True,
#   'estimate': ['025', '049'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop85omp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['025', '049'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_u18p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['003', '004', '005', '006', '027', '028', '029', '030'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_u18mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['003', '004', '005', '006', '027', '028', '029', '030'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1824p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['007', '008', '009', '010', '031', '032', '033', '034'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1824mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['007', '008', '009', '010', '031', '032', '033', '034'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2534p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['011', '012', '035', '036'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2534mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['011', '012', '035', '036'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3564p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['013',
#    '014',
#    '015',
#    '016',
#    '017',
#    '018',
#    '019',
#    '037',
#    '038',
#    '039',
#    '040',
#    '041',
#    '042',
#    '043'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3564mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['013',
#    '014',
#    '015',
#    '016',
#    '017',
#    '018',
#    '019',
#    '037',
#    '038',
#    '039',
#    '040',
#    '041',
#    '042',
#    '043'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop65ovp',
#   'moe': False,
#   'percent': True,
#   'estimate': ['020',
#    '021',
#    '022',
#    '023',
#    '024',
#    '025',
#    '044',
#    '045',
#    '046',
#    '047',
#    '048',
#    '049'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop65ovmp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['020',
#    '021',
#    '022',
#    '023',
#    '024',
#    '025',
#    '044',
#    '045',
#    '046',
#    '047',
#    '048',
#    '049'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1834p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['007',
#    '008',
#    '009',
#    '010',
#    '011',
#    '012',
#    '031',
#    '032',
#    '033',
#    '034',
#    '035',
#    '036'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1834mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['007',
#    '008',
#    '009',
#    '010',
#    '011',
#    '012',
#    '031',
#    '032',
#    '033',
#    '034',
#    '035',
#    '036'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3544p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['013', '014', '037', '038'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3544mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['013', '014', '037', '038'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop4564p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['015',
#    '016',
#    '017',
#    '018',
#    '019',
#    '039',
#    '040',
#    '041',
#    '042',
#    '043'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop4564mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['015',
#    '016',
#    '017',
#    '018',
#    '019',
#    '039',
#    '040',
#    '041',
#    '042',
#    '043'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['026'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['026'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
# ...
#   'estimate': ['045'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop7074p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['046'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop7074mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['046'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop7579p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['047'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop7579mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['047'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop8084p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['048'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop8084mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['048'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop85op',
#   'moe': False,
#   'percent': True,
#   'estimate': ['049'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop85omp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['049'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_u18p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['027', '028', '029', '030'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_u18mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['027', '028', '029', '030'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1824p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['031', '032', '033', '034'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1824mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['031', '032', '033', '034'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop2534p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['035', '036'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop2534mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['035', '036'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3564p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['037', '038', '039', '040', '041', '042', '043'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3564mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['037', '038', '039', '040', '041', '042', '043'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop65ovp',
#   'moe': False,
#   'percent': True,
#   'estimate': ['044', '045', '046', '047', '048', '049'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop65ovmp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['044', '045', '046', '047', '048', '049'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1834p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['031', '032', '033', '034', '035', '036'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1834mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['031', '032', '033', '034', '035', '036'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3544p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['037', '038'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3544mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['037', '038'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop4564p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['039', '040', '041', '042', '043'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop4564mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['039', '040', '041', '042', '043'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop_p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['002'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop_mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['002'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop_u5p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['003'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop_u5mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['003'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop_5_9p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['004'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop_5_9mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['004'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1014p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['005'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1014mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['005'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1517p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['006'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1517mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['006'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1819p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['007'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1819mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['007'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop20p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['008'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop20mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['008'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop21p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['009'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop21mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['009'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop2224p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['010'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop2224mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['010'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop2529p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['011'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop2529mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['011'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop3034p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['012'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop3034mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['012'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop3539p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['013'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop3539mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['013'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop4044p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['014'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop4044mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['014'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop4549p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['015'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop4549mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['015'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop5054p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['016'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop5054mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['016'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop5559p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['017'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop5559mmp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['017'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop6061p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['018'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop6061mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['018'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop6264p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['019'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop6264mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['019'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop6566p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['020'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop6566mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['020'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop6769p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['021'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop6769mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['021'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop7074p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['022'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop7074mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['022'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': '',
#   'moe': True,
#   'percent': True,
#   'estimate': ['023'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop8084p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['024'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop8084mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['024'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop85op',
#   'moe': False,
#   'percent': True,
#   'estimate': ['025'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop85omp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['025'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop_u18p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['003', '004', '005', '006'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop_u18mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['003', '004', '005', '006'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1824p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['007', '008', '009', '010'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1824mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['007', '008', '009', '010'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop2534p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['011', '012'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop2534mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['011', '012'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop3564p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['013', '014', '015', '016', '017', '018', '019'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop3564mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['013', '014', '015', '016', '017', '018', '019'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop65ovp',
#   'moe': False,
#   'percent': True,
#   'estimate': ['020', '021', '022', '023', '024', '025'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop65ovmp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['020', '021', '022', '023', '024', '025'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1834p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['007', '008', '009', '010', '011', '012'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1834mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['007', '008', '009', '010', '011', '012'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop3544p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['013', '014'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop3544mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['013', '014'],
#   'universe': ['001']},
#  {'table': 'b01001_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop4564p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['015', '016', '017', '018', '019'],
#   'universe': ['001']}]

# %%
#pickle.dump(ids_dict, open('table_to_censusid.p', 'wb'))

# %%
#col_names_dict['b01001_population_by_age_gender_acs_m']
#pickle.dump(col_names_dict, open('cols_ids_dict.p', 'wb'))

# %%
uni_dict
# Out:
# [{'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop',
#   'moe': False,
#   'percent': False,
#   'estimate': ['001'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'popm',
#   'moe': True,
#   'percent': False,
#   'estimate': ['001'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_u5',
#   'moe': False,
#   'percent': False,
#   'estimate': ['003', '018'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_u5m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['003', '018'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_5_9',
#   'moe': False,
#   'percent': False,
#   'estimate': ['004', '019'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_5_9m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['004', '019'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1014',
#   'moe': False,
#   'percent': False,
#   'estimate': ['005', '020'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1014m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['005', '020'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1517',
#   'moe': False,
#   'percent': False,
#   'estimate': ['006', '021'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1517m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['006', '021'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1819',
#   'moe': False,
#   'percent': False,
#   'estimate': ['007', '022'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1819m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['007', '022'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2024',
#   'moe': False,
#   'percent': False,
#   'estimate': ['008', '023'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2024m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['008', '023'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2529',
#   'moe': False,
#   'percent': False,
#   'estimate': ['009', '024'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2529m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['009', '024'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3034',
#   'moe': False,
#   'percent': False,
#   'estimate': ['010', '025'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3034m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['010', '025'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3544',
#   'moe': False,
#   'percent': False,
#   'estimate': ['011', '026'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3544m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['011', '026'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop4554',
#   'moe': False,
#   'percent': False,
#   'estimate': ['012', '027'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop4554m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['012', '027'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop5564',
#   'moe': False,
#   'percent': False,
#   'estimate': ['013', '028'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop5564m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['013', '028'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop6574',
#   'moe': False,
#   'percent': False,
#   'estimate': ['014', '029'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop6574m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['014', '029'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop7584',
#   'moe': False,
#   'percent': False,
#   'estimate': ['015', '030'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop7584m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['015', '030'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop85o',
#   'moe': False,
#   'percent': False,
#   'estimate': ['016', '031'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop85om',
#   'moe': True,
#   'percent': False,
#   'estimate': ['016', '031'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_u18',
#   'moe': False,
#   'percent': False,
#   'estimate': ['003', '004', '005', '006', '018', '019', '020', '021'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_u18m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['003', '004', '005', '006', '018', '019', '020', '021'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1824',
#   'moe': False,
#   'percent': False,
#   'estimate': ['007', '008', '022', '023'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1824m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['007', '008', '022', '023'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2534',
#   'moe': False,
#   'percent': False,
#   'estimate': ['009', '010', '024', '025'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2534m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['009', '010', '024', '025'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3564',
#   'moe': False,
#   'percent': False,
#   'estimate': ['011', '012', '013', '026', '027', '028'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3564m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['011', '012', '013', '026', '027', '028'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop65ov',
#   'moe': False,
#   'percent': False,
#   'estimate': ['014', '015', '016', '029', '030', '031'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop65ovm',
#   'moe': True,
#   'percent': False,
#   'estimate': ['014', '015', '016', '029', '030', '031'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1834',
#   'moe': False,
#   'percent': False,
#   'estimate': ['007', '008', '009', '010', '022', '023', '024', '025'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1834m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['007', '008', '009', '010', '022', '023', '024', '025'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop4564',
#   'moe': False,
#   'percent': False,
#   'estimate': ['012', '013', '027', '028'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop4564m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['012', '013', '027', '028'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop',
#   'moe': False,
#   'percent': False,
#   'estimate': ['017'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpopm',
#   'moe': True,
#   'percent': False,
#   'estimate': ['017'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_u5',
#   'moe': False,
#   'percent': False,
#   'estimate': ['018'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_u5m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['018'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_5_9',
#   'moe': False,
#   'percent': False,
#   'estimate': ['019'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_5_9m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['019'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1014',
#   'moe': False,
#   'percent': False,
#   'estimate': ['020'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1014m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['020'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1517',
#   'moe': False,
#   'percent': False,
#   'estimate': ['021'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1517m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['021'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1819',
#   'moe': False,
#   'percent': False,
#   'estimate': ['022'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1819m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['022'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop2024',
#   'moe': False,
#   'percent': False,
#   'estimate': ['023'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop2024m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['023'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop2529',
#   'moe': False,
#   'percent': False,
#   'estimate': ['024'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop2529m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['024'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3034',
#   'moe': False,
#   'percent': False,
#   'estimate': ['025'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3034m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['025'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3544',
#   'moe': False,
#   'percent': False,
#   'estimate': ['026'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3544m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['026'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop4554',
#   'moe': False,
#   'percent': False,
#   'estimate': ['027'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop4554m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['027'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop5564',
#   'moe': False,
#   'percent': False,
#   'estimate': ['028'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop5564m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['028'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop6574',
#   'moe': False,
#   'percent': False,
#   'estimate': ['029'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop6574m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['029'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop7584',
#   'moe': False,
#   'percent': False,
#   'estimate': ['030'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop7584m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['030'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop85o',
#   'moe': False,
#   'percent': False,
#   'estimate': ['031'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop85om',
#   'moe': True,
#   'percent': False,
#   'estimate': ['031'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_u18',
#   'moe': False,
#   'percent': False,
#   'estimate': ['018', '019', '020', '021'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_u18m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['018', '019', '020', '021'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1824',
#   'moe': False,
#   'percent': False,
#   'estimate': ['007', '008', '022', '023'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1824m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['007', '008', '022', '023'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop2534',
#   'moe': False,
#   'percent': False,
#   'estimate': ['024', '025'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop2534m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['024', '025'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3564',
#   'moe': False,
#   'percent': False,
#   'estimate': ['026', '027', '028'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3564m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['026', '027', '028'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop65ov',
#   'moe': False,
#   'percent': False,
#   'estimate': ['029', '030', '031'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop65ovm',
#   'moe': True,
#   'percent': False,
#   'estimate': ['029', '030', '031'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1834',
#   'moe': False,
#   'percent': False,
#   'estimate': ['022', '023', '024', '025'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1834m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['022', '023', '024', '025'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop4564',
#   'moe': False,
#   'percent': False,
#   'estimate': ['027', '028'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop4564m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['027', '028'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop',
#   'moe': False,
#   'percent': False,
#   'estimate': ['002'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpopm',
#   'moe': True,
#   'percent': False,
#   'estimate': ['002'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop_u5',
#   'moe': False,
#   'percent': False,
#   'estimate': ['003'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop_u5m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['003'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop_5_9',
#   'moe': False,
#   'percent': False,
#   'estimate': ['004'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop_5_9m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['004'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1014',
#   'moe': False,
#   'percent': False,
#   'estimate': ['005'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1014m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['005'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1517',
#   'moe': False,
#   'percent': False,
#   'estimate': ['006'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1517m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['006'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1819',
#   'moe': False,
#   'percent': False,
#   'estimate': ['007'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1819m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['007'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop2024',
#   'moe': False,
#   'percent': False,
#   'estimate': ['008'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop2024m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['008'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop2529',
#   'moe': False,
#   'percent': False,
#   'estimate': ['009'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop2529m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['009'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop3034',
#   'moe': False,
#   'percent': False,
#   'estimate': ['010'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop3034m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['010'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop3544',
#   'moe': False,
#   'percent': False,
#   'estimate': ['011'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop3544m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['011'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop4554',
#   'moe': False,
#   'percent': False,
#   'estimate': ['012'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop4554m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['012'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop5564',
#   'moe': False,
#   'percent': False,
#   'estimate': ['013'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop5564m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['013'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop6574',
#   'moe': False,
#   'percent': False,
#   'estimate': ['014'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop6574m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['014'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop7584',
#   'moe': False,
#   'percent': False,
#   'estimate': ['015'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop7584m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['015'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop85o',
#   'moe': False,
#   'percent': False,
#   'estimate': ['016'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop85om',
#   'moe': True,
#   'percent': False,
#   'estimate': ['016'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop_u18',
#   'moe': False,
#   'percent': False,
#   'estimate': ['003', '004', '005', '006'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop_u18m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['003', '004', '005', '006'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1824',
#   'moe': False,
#   'percent': False,
#   'estimate': ['007', '008'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1824m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['007', '008'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop2534',
#   'moe': False,
#   'percent': False,
#   'estimate': ['009', '010'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop2534m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['009', '010'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop3564',
#   'moe': False,
#   'percent': False,
#   'estimate': ['011', '012', '013'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop3564m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['011', '012', '013'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop65ov',
#   'moe': False,
#   'percent': False,
#   'estimate': ['014', '015', '016'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop65ovm',
#   'moe': True,
#   'percent': False,
#   'estimate': ['014', '015', '016'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1834',
#   'moe': False,
#   'percent': False,
#   'estimate': ['007', '008', '009', '010'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1834m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['007', '008', '009', '010'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop4564',
#   'moe': False,
#   'percent': False,
#   'estimate': ['012', '013'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop4564m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['012', '013'],
#   'universe': []},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_u5p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['003', '018'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_u5mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['003', '018'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_5_9p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['004', '019'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_5_9mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['004', '019'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1014p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['005', '020'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1014mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['005', '020'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1517p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['006', '021'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1517mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['006', '021'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1819p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['007', '022'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1819mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['007', '022'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2024p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['008', '023'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2024mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['008', '023'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2529p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['009', '024'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2529mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['009', '024'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3034p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['010', '025'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3034mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['010', '025'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3544p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['011', '026'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3544mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['011', '026'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop4554p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['012', '027'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop4554mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['012', '027'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop5564p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['013', '028'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop5564mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['013', '028'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop6574p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['014', '029'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop6574mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['014', '029'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop7584p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['015', '030'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop7584mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['015', '030'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop85op',
#   'moe': False,
#   'percent': True,
#   'estimate': ['016', '031'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop85omp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['016', '031'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_u18p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['003', '004', '005', '006', '018', '019', '020', '021'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_u18mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['003', '004', '005', '006', '018', '019', '020', '021'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1824p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['007', '008', '022', '023'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1824mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['007', '008', '022', '023'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2534p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['009', '010', '024', '025'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2534mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['009', '010', '024', '025'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3564p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['011', '012', '013', '026', '027', '028'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3564mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['011', '012', '013', '026', '027', '028'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop65ovp',
#   'moe': False,
#   'percent': True,
#   'estimate': ['014', '015', '016', '029', '030', '031'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop65ovmp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['014', '015', '016', '029', '030', '031'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1834p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['007', '008', '009', '010', '022', '023', '024', '025'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1834mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['007', '008', '009', '010', '022', '023', '024', '025'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop4564p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['012', '013', '027', '028'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop4564mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['012', '013', '027', '028'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['017'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['017'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_u5p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['018'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_u5mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['018'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_5_9p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['019'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_5_9mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['019'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1014p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['020'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1014mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['020'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1517p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['021'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1517mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['021'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1819p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['022'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1819mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['022'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop2024p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['023'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop2024mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['023'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop2529p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['024'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop2529mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['024'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3034p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['025'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3034mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['025'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3544p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['026'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3544mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['026'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop4554p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['027'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop4554mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['027'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop5564p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['028'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop5564mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['028'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop6574p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['029'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop6574mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['029'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop7584p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['030'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop7584mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['030'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop85op',
#   'moe': False,
#   'percent': True,
#   'estimate': ['031'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop85omp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['031'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_u18p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['018', '019', '020', '021'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_u18mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['018', '019', '020', '021'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1824p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['022', '023'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1824mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['022', '023'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop2534p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['024', '025'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop2534mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['024', '025'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3564p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['026', '027', '028'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3564mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['026', '027', '028'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop65ovp',
#   'moe': False,
#   'percent': True,
#   'estimate': ['029', '030', '031'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop65ovmp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['029', '030', '031'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1834p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['022', '023', '024', '025'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1834mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['022', '023', '024', '025'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop4564p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['012', '013', '027', '028'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop4564mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['012', '013', '027', '028'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop_p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['002'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop_mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['002'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop_u5p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['003'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop_u5mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['003'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop_5_9p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['004'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop_5_9mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['004'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1014p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['005'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1014mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['005'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1517p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['006'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1517mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['006'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1819p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['007'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1819mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['007'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop2024p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['008'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop2024mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['008'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop2529p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['009'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop2529mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['009'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop3034p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['010'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop3034mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['010'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop3544p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['011'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop3544mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['011'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop4554p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['012'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop4554mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['012'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop5564p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['013'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop5564mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['013'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop6574p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['014'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop6574mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['014'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop7584p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['015'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop7584mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['015'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop85op',
#   'moe': False,
#   'percent': True,
#   'estimate': ['016'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop85omp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['016'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop_u18p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['003', '004', '005', '006'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop_u18mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['003', '004', '005', '006'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1824p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['007', '008'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop1824mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['007', '008'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop2534p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['009', '010'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop2534mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['009', '010'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop3564p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['011', '012', '013'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop3564mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['011', '012', '013'],
#   'universe': ['001']},
#  {'table': 'b01001a_whi_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop65ovp',
#   'moe': False,
#   'percent': True,
#   'estimate': ['014', '015', '016'],
#   'universe': ['001']},
# ...
#   'universe': []},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop4564',
#   'moe': False,
#   'percent': False,
#   'estimate': ['012', '013'],
#   'universe': []},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'mpop4564m',
#   'moe': True,
#   'percent': False,
#   'estimate': ['012', '013'],
#   'universe': []},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_u5p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['003', '018'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_u5mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['003', '018'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_5_9p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['004', '019'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_5_9mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['004', '019'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1014p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['005', '020'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1014mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['005', '020'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1517p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['006', '021'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1517mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['006', '021'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1819p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['007', '022'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1819mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['007', '022'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2024p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['008', '023'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2024mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['008', '023'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2529p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['009', '024'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2529mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['009', '024'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3034p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['010', '025'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3034mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['010', '025'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3544p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['011', '026'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3544mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['011', '026'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop4554p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['012', '027'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop4554mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['012', '027'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop5564p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['013', '028'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop5564mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['013', '028'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop6574p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['014', '029'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop6574mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['014', '029'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop7584p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['015', '030'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop7584mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['015', '030'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop85op',
#   'moe': False,
#   'percent': True,
#   'estimate': ['016', '031'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop85omp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['016', '031'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_u18p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['003', '004', '005', '006', '018', '019', '020', '021'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop_u18mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['003', '004', '005', '006', '018', '019', '020', '021'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1824p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['007', '008', '022', '023'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1824mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['007', '008', '022', '023'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2534p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['009', '010', '024', '025'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop2534mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['009', '010', '024', '025'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3564p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['011', '012', '013', '026', '027', '028'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop3564mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['011', '012', '013', '026', '027', '028'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop65ovp',
#   'moe': False,
#   'percent': True,
#   'estimate': ['014', '015', '016', '029', '030', '031'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop65ovmp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['014', '015', '016', '029', '030', '031'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1834p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['007', '008', '009', '010', '022', '023', '024', '025'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop1834mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['007', '008', '009', '010', '022', '023', '024', '025'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop4564p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['012', '013', '027', '028'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'pop4564mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['012', '013', '027', '028'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['017'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['017'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_u5p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['018'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_u5mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['018'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_5_9p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['019'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_5_9mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['019'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1014p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['020'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1014mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['020'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1517p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['021'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1517mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['021'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1819p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['022'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1819mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['022'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop2024p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['023'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop2024mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['023'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop2529p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['024'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop2529mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['024'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3034p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['025'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3034mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['025'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3544p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['026'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3544mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['026'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop4554p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['027'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop4554mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['027'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop5564p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['028'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop5564mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['028'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop6574p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['029'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop6574mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['029'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop7584p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['030'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop7584mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['030'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop85op',
#   'moe': False,
#   'percent': True,
#   'estimate': ['031'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop85omp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['031'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_u18p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['018', '019', '020', '021'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop_u18mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['018', '019', '020', '021'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1824p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['022', '023'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop1824mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['022', '023'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop2534p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['024', '025'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop2534mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['024', '025'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3564p',
#   'moe': False,
#   'percent': True,
#   'estimate': ['026', '027', '028'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop3564mp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['026', '027', '028'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop65ovp',
#   'moe': False,
#   'percent': True,
#   'estimate': ['029', '030', '031'],
#   'universe': ['001']},
#  {'table': 'b01001d_as_population_by_age_gender_acs_m',
#   'group': 'b01001',
#   'col': 'fpop65ovmp',
#   'moe': True,
#   'percent': True,
#   'estimate': ['029', '030', '031'],
#   'universe': ['001']},
#  ...]

# %%
#table_ids = pd.DataFrame.from_dict(ids_dict, orient='index')
table_ids = pd.DataFrame.from_records(uni_dict)

# %%
table_ids
# Out:
#                                                  table   group        col  \
# 0           b01001a_whi_population_by_age_gender_acs_m  b01001        pop
# 1           b01001a_whi_population_by_age_gender_acs_m  b01001       popm
# 2           b01001a_whi_population_by_age_gender_acs_m  b01001     pop_u5
# 3           b01001a_whi_population_by_age_gender_acs_m  b01001    pop_u5m
# 4           b01001a_whi_population_by_age_gender_acs_m  b01001    pop_5_9
# ...                                                ...     ...        ...
# 7572  c18130_poverty_status_by_disability_status_acs_m  c18130    nd65omp
# 7573  c18130_poverty_status_by_disability_status_acs_m  c18130   nd65opvp
# 7574  c18130_poverty_status_by_disability_status_acs_m  c18130  nd65opvmp
# 7575  c18130_poverty_status_by_disability_status_acs_m  c18130  nd65onpvp
# 7576  c18130_poverty_status_by_disability_status_acs_m  c18130
#
#         moe  percent    estimate universe
# 0     False    False       [001]       []
# 1      True    False       [001]       []
# 2     False    False  [003, 018]       []
# 3      True    False  [003, 018]       []
# 4     False    False  [004, 019]       []
# ...     ...      ...         ...      ...
# 7572   True     True       [020]    [016]
# 7573  False     True       [021]    [020]
# 7574   True     True       [021]    [020]
# 7575  False     True       [022]    [020]
# 7576   True     True       [022]    [020]
#
# [7577 rows x 7 columns]

# %%
print(len(table_ids[(table_ids['table'] == 'b05003_citizenship_nativity_by_age_gender_acs_m')]['col'].values))
print(len(set([x for x in table_ids[(table_ids['table'] == 'b05003_citizenship_nativity_by_age_gender_acs_m')]['col'].values if not isinstance(x, list)])))
# Out:
# 65
# 65

# %%
table_ids[(table_ids['table'] == 'b05003_citizenship_nativity_by_age_gender_acs_m')]
# Out:
#                                                 table   group         col  \
# 2877  b05003_citizenship_nativity_by_age_gender_acs_m  b05003         pop
# 2878  b05003_citizenship_nativity_by_age_gender_acs_m  b05003      pop_me
# 2879  b05003_citizenship_nativity_by_age_gender_acs_m  b05003     pop_u18
# 2880  b05003_citizenship_nativity_by_age_gender_acs_m  b05003   pop_u18me
# 2881  b05003_citizenship_nativity_by_age_gender_acs_m  b05003     ntv_u18
# ...                                               ...     ...         ...
# 3001  b05003_citizenship_nativity_by_age_gender_acs_m  b05003    ffb18o_p
# 3002  b05003_citizenship_nativity_by_age_gender_acs_m  b05003   ffb18omep
# 3003  b05003_citizenship_nativity_by_age_gender_acs_m  b05003   fntr18o_p
# 3004  b05003_citizenship_nativity_by_age_gender_acs_m  b05003  fntr18omep
# 3005  b05003_citizenship_nativity_by_age_gender_acs_m  b05003   fnon18o_p
#
#         moe  percent    estimate universe
# 2877  False    False       [001]       []
# 2878   True    False       [001]       []
# 2879  False    False  [003, 014]       []
# 2880   True    False  [003, 014]       []
# 2881  False    False  [004, 015]       []
# ...     ...      ...         ...      ...
# 3001  False     True       [021]    [019]
# 3002   True     True       [021]    [019]
# 3003  False     True       [022]    [019]
# 3004   True     True       [022]    [019]
# 3005  False     True       [023]    [019]
#
# [129 rows x 7 columns]

# %%
table_ids.dropna(how='all')
table_ids.sort_index()
# Out:
#                                                  table   group        col  \
# 0           b01001a_whi_population_by_age_gender_acs_m  b01001        pop
# 1           b01001a_whi_population_by_age_gender_acs_m  b01001       popm
# 2           b01001a_whi_population_by_age_gender_acs_m  b01001     pop_u5
# 3           b01001a_whi_population_by_age_gender_acs_m  b01001    pop_u5m
# 4           b01001a_whi_population_by_age_gender_acs_m  b01001    pop_5_9
# ...                                                ...     ...        ...
# 7572  c18130_poverty_status_by_disability_status_acs_m  c18130    nd65omp
# 7573  c18130_poverty_status_by_disability_status_acs_m  c18130   nd65opvp
# 7574  c18130_poverty_status_by_disability_status_acs_m  c18130  nd65opvmp
# 7575  c18130_poverty_status_by_disability_status_acs_m  c18130  nd65onpvp
# 7576  c18130_poverty_status_by_disability_status_acs_m  c18130
#
#         moe  percent    estimate universe
# 0     False    False       [001]       []
# 1      True    False       [001]       []
# 2     False    False  [003, 018]       []
# 3      True    False  [003, 018]       []
# 4     False    False  [004, 019]       []
# ...     ...      ...         ...      ...
# 7572   True     True       [020]    [016]
# 7573  False     True       [021]    [020]
# 7574   True     True       [021]    [020]
# 7575  False     True       [022]    [020]
# 7576   True     True       [022]    [020]
#
# [7577 rows x 7 columns]

# %%
#table_ids.sort_index().index.values
table_ids.loc['b01001_population_by_age_gender_acs_m', 0]

# %%
new_table = column_ids.copy()
new_table['estimates'] = np.nan
new_table['universe'] = np.nan

for li in uni_dict:
    table, col, group = li['table'], li['col'], li['group']
    est, uni = li['estimate'], li['universe']
    moe, percent = li['moe'], li['percent']
    cond = 'table == @table and col == @col'
    new_table.loc[new_table.eval(cond), 'group'] = group
    new_table.loc[new_table.eval(cond), 'estimates'] = ",".join(est)
    new_table.loc[new_table.eval(cond), 'universe'] = ",".join(uni)
    new_table.loc[new_table.eval(cond), 'moe'] = moe
    new_table.loc[new_table.eval(cond), 'percent'] = percent

    
new_table
# Out:
#                                                   table        col   group  \
# 0       b25046_b25044_b01003_hh_vehicle_ownership_acs_m     occ_hu     NaN
# 1       b25046_b25044_b01003_hh_vehicle_ownership_acs_m  occ_hu_me     NaN
# 2       b25046_b25044_b01003_hh_vehicle_ownership_acs_m     no_car     NaN
# 3       b25046_b25044_b01003_hh_vehicle_ownership_acs_m  no_car_me     NaN
# 4       b25046_b25044_b01003_hh_vehicle_ownership_acs_m        car     NaN
# ...                                                 ...        ...     ...
# 11256  c18130_poverty_status_by_disability_status_acs_m     nd65op  c18130
# 11257  c18130_poverty_status_by_disability_status_acs_m    nd65omp  c18130
# 11258  c18130_poverty_status_by_disability_status_acs_m   nd65opvp  c18130
# 11259  c18130_poverty_status_by_disability_status_acs_m  nd65opvmp  c18130
# 11260  c18130_poverty_status_by_disability_status_acs_m  nd65onpvp  c18130
#
#                                                      ids    moe  percent  \
# 0                                                  {001}  False    False
# 1                                                  {001}   True    False
# 2                                             {010, 003}  False    False
# 3                                             {010, 003}   True    False
# 4      {015, 008, 005, 004, 012, 011, 006, 013, 007, ...  False    False
# ...                                                  ...    ...      ...
# 11256                                         {020, 016}  False     True
# 11257                                         {020, 016}   True     True
# 11258                                         {020, 021}  False     True
# 11259                                         {020, 021}   True     True
# 11260                                         {022, 020}  False     True
#
#       estimates universe
# 0           NaN      NaN
# 1           NaN      NaN
# 2           NaN      NaN
# 3           NaN      NaN
# 4           NaN      NaN
# ...         ...      ...
# 11256       020      016
# 11257       020      016
# 11258       021      020
# 11259       021      020
# 11260       022      020
#
# [11261 rows x 8 columns]

# %%
uni_dict

# %%
new_table[(new_table['table'] == 'b05003_citizenship_nativity_by_age_gender_acs_m')]
#mnonu18mep
#new_table[(new_table['col'] == 'mnonu18mep')]
# Out:
#                                                table         col   group  \
# 601  b05003_citizenship_nativity_by_age_gender_acs_m         pop  b05003
# 602  b05003_citizenship_nativity_by_age_gender_acs_m      pop_me  b05003
# 603  b05003_citizenship_nativity_by_age_gender_acs_m     pop_u18  b05003
# 604  b05003_citizenship_nativity_by_age_gender_acs_m   pop_u18me  b05003
# 605  b05003_citizenship_nativity_by_age_gender_acs_m     ntv_u18  b05003
# ..                                               ...         ...     ...
# 724  b05003_citizenship_nativity_by_age_gender_acs_m    ffb18o_p  b05003
# 725  b05003_citizenship_nativity_by_age_gender_acs_m   ffb18omep  b05003
# 726  b05003_citizenship_nativity_by_age_gender_acs_m   fntr18o_p  b05003
# 727  b05003_citizenship_nativity_by_age_gender_acs_m  fntr18omep  b05003
# 728  b05003_citizenship_nativity_by_age_gender_acs_m   fnon18o_p  b05003
#
#             ids    moe  percent estimates universe
# 601       {001}  False    False       001
# 602       {001}   True    False       001
# 603  {003, 014}  False    False   003,014
# 604  {003, 014}   True    False   003,014
# 605  {015, 004}  False    False   004,015
# ..          ...    ...      ...       ...      ...
# 724  {019, 021}  False     True       021      019
# 725  {019, 021}   True     True       021      019
# 726  {019, 022}  False     True       022      019
# 727  {019, 022}   True     True       022      019
# 728  {019, 023}  False     True       023      019
#
# [128 rows x 8 columns]

# %%
#new_table.loc[(new_table['table'] =='b01001_population_by_age_gender_acs_m')]
new_table.to_csv("csv/column_ids2.csv")
